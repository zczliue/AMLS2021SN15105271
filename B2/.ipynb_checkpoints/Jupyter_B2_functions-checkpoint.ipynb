# %%
# This is the function file for Task B2,
# which assess the performance between different classifiers, 
# by grid search with cross validation, including:

# SVM 
# Random Forest
# KNN
# MLP

# The assessment metrices for classifiers include:
# 1. Accuracy score between ytrue and ypred
# 2. Grid score for grid search tuning
# 


# To use this file, specify:
# 'image_folder' : a string in either 'celeba' or 'cartoon_set'
# 'label_name' :  a string that specifies the feature name, i.e. 'gender', 'smiling' as in labels.csv
# 'tuning_parameters' : a dictionary contains different kernels and settings
# 'cvfold': an int for K-fold cross validation

# return value: trained classifier with best parameter settings

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import keras
import sklearn
import cv2
import dlib
#import rewritten lab2 landmarks extraction 
import B2_preprocess as B2_prep
import itertools 
import datetime
import pickle
# Out:
# Using TensorFlow backend.

# %%
from itertools import cycle
from scipy import interp
from collections import OrderedDict

from sklearn import datasets, metrics, model_selection, svm
from sklearn.utils import shuffle
from sklearn.datasets import load_iris

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import roc_curve, auc

from keras.preprocessing import image
from keras.models import Sequential 
from keras.models import Sequential 
from keras.layers import Dense , Dropout 
from keras.optimizers import SGD
from keras.optimizers import RMSprop

# %%
# Set the parameters for Grid search
split_ratio = 0.75
cvfold = 5
image_folder = "cartoon_set"
label_name   = "eye_color"
num_epochs = 100


#n_colors is the number of dominant colours to be detected in the image, used in cv.kmeans
n_colors = 5
roi_margin = 20 #pixels


#SVM
#SVM_tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-2, 1e-1, 1, 10],'C': [0.01, 0.1, 1, 10]}]
#                        {'kernel': ['linear'], 'C': [0.01, 0.1, 1, 10]},
#                        {'kernel':['sigmoid'],'gamma': [1e-2, 1e-1, 1, 10],'C': [0.01, 0.1, 1, 10]}

SVM_tuned_parameters = {'kernel': ['rbf', 'linear', 'sigmoid'],
                        'C': [0.001, 0.01, 0.1, 1, 10],
                        'gamma': [1e-4, 1e-3, 1e-2, 1e-1]}

#SVM_tuned_parameters = {'kernel':['linear'], 'C':[1]}

#Logistic Regression
#LogReg_tuned_parameters = [{ 'solver':['lbfgs'], 'C':[0.01, 0.1, 1, 10]}, 
#                          {'solver':[ 'saga'], 'penalty':['l1'], 'C':[0.01, 0.1, 1, 10]}]

LogReg_tuned_parameters = {'solver':[ 'saga'], 'penalty':['l1', 'l2'], 'C':[1e-4, 1e-3, 1e-2, 1e-1, 1,10]}
                          

#Random Forest
RF_tuned_parameters = [{'n_estimators':[64, 128, 256, 512, 1024], 'max_depth':[64, 128, 256, 512, 1024]}]

#KNN parameter
KNN_tuned_parameters = [{'n_neighbors':[8,16,32,64,128]}]

#MLP parameter
MLP_tuned_parameters = [{'hidden_layer_sizes': [(128,256,128,), (128,256,128,), (128,),(256,),(512,)], 
                         'activation': ['logistic', 'tanh', 'relu'],
                         'learning_rate':['constant', 'adaptive']}]


Squential_model_parameters = [{'num_hidden_layer': 3,
                              'hidden_layer_activation' : ['relu','tanh','relu'],
                              'dropout':[0.5,0.25,0.125],
                              'last_activation':'softmax'},
                              
                              {'num_hidden_layer': 4,
                              'hidden_layer_activation' : ['relu','tanh','relu','tanh'],
                              'dropout':[0.5,0.25,0.125,0.0625],
                              'last_activation':'softmax'}]

# %%
# This is the dictionary contains dlib's 68-point facial landmark detector:
# copyright: https://github.com/jrosebr1/imutils/blob/master/imutils/face_utils/helpers.py
FACIAL_LANDMARKS_68_IDXS = OrderedDict([
	("mouth", (48, 68)),
	("inner_mouth", (60, 68)),
	("right_eyebrow", (17, 22)),
	("left_eyebrow", (22, 27)),
	("right_eye", (36, 41)),
	("left_eye", (42, 47)),
	("nose", (27, 36)),
	("jaw", (0, 17))
])

# %%
# This function is rewritten as follows:
# the input image_folder must be a string that specifies 'celeba' or 'cartoon_set'
# the input label_name must be a string that specifies the feature name, i.e. 'gender', 'smiling' as in labels.csv

def split_data(X, y, split_ratio):
    
    X, Y = shuffle(X,y)
    train_X, test_X, train_Y, test_Y = train_test_split(X, Y, train_size=split_ratio)
    
    
    #print(train_X.shape) - > num of samples, 3 (RGB value)
    #there is no need to reshape the dimension 
    tr_X = train_X
    te_X = test_X

    
    #normalisation
    x_scaler = StandardScaler()
    tr_X = x_scaler.fit_transform(tr_X)
    te_X = x_scaler.transform(te_X)
    
    #train_Y, test_Y are single valued Y (multi-class) 
    tr_Y = train_Y
    te_Y = test_Y

    
    #convert to category matrix. 
    cat_tr_Y = keras.utils.to_categorical(tr_Y)
    cat_te_Y = keras.utils.to_categorical(te_Y)

    return tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y

# %%
#return both predict prob and predict labels

def bulk_runtime_estimation(classifier, xtest):
    
    nsamp = xtest.shape[0]
    start = time.time()
    ypred = classifier.predict(xtest)
    ypred_prob = classifier.predict_proba(xtest)
    bulk_runtime = time.time() - start
    
    #average runtime per instance
    avg_runtime = bulk_runtime/nsamp
    
    return ypred, ypred_prob, bulk_runtime, avg_runtime

# %%
#Prediction with Grid search SVC Cross validation
def SVC_GridSearch_PredictionCV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold, num_class):
    # classifier
    clf = GridSearchCV(SVC(probability=True), tuning_parameters, cv = cvfold, return_train_score=True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("SVC Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'SVM')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'SVM')
    
    
    #return best classifier
    return clf.best_estimator_, pseudo_test_score

# %%
def RF_GridSearch_PredictionCV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold, num_class):

    clf = GridSearchCV(RandomForestClassifier() , tuning_parameters, cv = cvfold, return_train_score=True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("RF Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    
    #determine important features
    importances = clf.best_estimator_.feature_importances_
    indices = np.argsort(importances)
    plt.title('Feature Importances')
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), [i for i in indices])
    plt.xlabel('Relative Importance')
    plt.show()
    
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'Random Forest')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'Random Forest')
    

    #return classifier
    return clf.best_estimator_, pseudo_test_score, indices

# %%
def KNN_Grid_search_Prediction_CV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold, num_class):
    clf = GridSearchCV(KNeighborsClassifier() , tuning_parameters, cv = cvfold, return_train_score = True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred,ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("KNN Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'KNN')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'KNN')
    
    
    #return classifier
    return clf.best_estimator_, pseudo_test_score

# %%
def Sequential_Prediction_GridSearch_CV(xtrain, ytrain, xtest, ytest, grid_parameters, cvfold, num_class, num_epochs):
    
    learning_curve_dict_all_models = {}
    
    acc_all_models = []
    acc_std_all_models = []
    loss_all_models = []
    runtime_mean_all_models = []
    
    all_models = []
    
    #the para combination index in search grid
    model_idx = 0
    
    for model_parameters in grid_parameters:
        
        print()
        
        print('########################################')
        model, acc_mean, acc_std_mean, loss_mean, runtime_mean, learning_curve_dict = Sequential_Prediction_CV(xtrain, ytrain, xtest, ytest, model_parameters, cvfold, num_class, num_epochs, model_idx)
        
        #store returned values for each model
        acc_all_models.append(acc_mean)
        acc_std_all_models.append(acc_std_mean)
        loss_all_models.append(loss_mean)
        runtime_mean_all_models.append(runtime_mean)
        
        all_models.append(model)
        
        #store learning and loss curve
        learning_curve_dict_all_models[model_idx] = learning_curve_dict
        

        print('########################################')
        
        model_idx = model_idx + 1
        
        
       
        
    #find max acc value on pseudo test set and index
    max_acc_value = max(acc_all_models)
    max_acc_value_index = acc_all_models.index(max_acc_value)
    
    
    
    #plot learning and loss curve
    plot_avg_learning_curves_all_models(learning_curve_dict_all_models, 'accuracy')
    plot_avg_learning_curves_all_models(learning_curve_dict_all_models, 'loss')
    
        
        
        
        
    
    print('Opt model parameter found on the pseudo test set:')
    print()
    print(grid_parameters[max_acc_value_index])
    print()
    print('Best average pseudo test set accuracy score with the opt model: {}'.format(max_acc_value))
    print('Average runtime per test instance: {}'.format(runtime_mean_all_models[max_acc_value_index]))
    
    
    
    return all_models[max_acc_value_index], max_acc_value

# %%
def Sequential_Prediction_CV(xtrain, ytrain, xtest, ytest, model_parameters, cvfold, num_class, num_epochs, model_idx):
    
    #a dict to store learning curve and loss curves
    learning_curve_dict = {}
    
    # aggregate inputs and targets
    #inputs = np.concatenate((xtrain, xtest), axis=0)
    #targets = np.concatenate((ytrain, ytest), axis=0)
    inputs  = xtrain
    targets = ytrain
    
    fold_no = 1
    #instead of using GridsearchCV we apply a manual function
    kf = KFold(n_splits=cvfold, random_state=None, shuffle=True)
    #record accuracy and loss per fold
    acc_per_fold  = []
    loss_per_fold = []
    avg_runtime_per_fold = []

    #average history train and val acc across all folds
    avg_history_train_acc = np.zeros(num_epochs)
    avg_history_val_acc = np.zeros(num_epochs)
    avg_history_train_loss = np.zeros(num_epochs)
    avg_history_val_loss = np.zeros(num_epochs)
    
    #an empty array to store confusion matrix every fold
    cm_sum = np.zeros((num_class,num_class))
    
    #input feature shape 
    in_feature_shape = xtrain.shape[1]
    #number of class (labels)
    num_labels = num_class
    
    #kf.split divide inputs and targets into K folds and
    #train_idx, test_idx are the indices for training set and validation set
    for train_idx, test_idx in kf.split(inputs, targets):
        
        print('------------------------------------------------------------------------')
        print('Squential with Kfold CV: ')
        print('Training for fold {} ...'.format(fold_no))
        
        #reconstruct model for each fold
        model = design_sequential_model(model_parameters, in_feature_shape, num_class)

        #
        history = model.fit(inputs[train_idx], targets[train_idx],
                    batch_size=int(xtrain.shape[0]/10),
                    epochs=num_epochs,
                    validation_data=(inputs[test_idx], targets[test_idx]),
                    verbose=1)
        
        
        
        #evaluate pseudo test set (split from Dataset A)
        scores = model.evaluate(xtest, ytest, verbose=1)
                
        acc_per_fold.append(scores[1])
        loss_per_fold.append(scores[0])
        
        
        #save history
        avg_history_train_acc = avg_history_train_acc + history.history['accuracy']
        avg_history_val_acc = avg_history_val_acc + history.history['val_accuracy']
        avg_history_train_loss = avg_history_train_loss + history.history['loss']
        avg_history_val_loss = avg_history_val_loss + history.history['val_loss']
        
        
        #generate predictions
        #ypred = model.predict(xtest)
        #model.predict returns probability
        ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(model, xtest)
        
        #convert to single value labels
        #ypred_labels = np.argmax(ypred_prob, axis=1)
        #ytest_labels = np.argmax(ytest, axis=1)
        
        #ytrue, ypred = ytest_labels, ypred_labels
        
        avg_runtime_per_fold.append(avg_runtime)
        
        # confusion matrix 
        #plot_confusion_matrix(ytest, ypred_prob)
        cm_sum = cm_sum + confusion_matrix_per_fold(ytest, ypred_prob)        
        
        # ROC curve
        plot_ROC_curve(ytest, ypred_prob, num_class, 'MLP')
        
        #plot learning curve
        #plot_learning_curve(history, fold_no, model_idx)

        # Increase fold number
        fold_no = fold_no + 1
        
    # == Provide average scores ==
    print()
    mean_acc_per_fold = np.mean(acc_per_fold)
    std_acc_per_fold = np.std(acc_per_fold)
    mean_loss_per_fold = np.mean(loss_per_fold)
    
    mean_runtime_per_fold = np.mean(avg_runtime_per_fold)
    
    
    #plot average confusion matrix
    plot_avg_confusion_matrix_across_folds(cm_sum, cvfold, 'MLP')
    
    
    #plot avg learning curve accross all folds
    avg_history_train_acc = np.multiply(avg_history_train_acc, 1/cvfold)
    avg_history_val_acc = np.multiply(avg_history_val_acc, 1/cvfold)
    avg_history_train_loss = np.multiply(avg_history_train_loss, 1/cvfold)
    avg_history_val_loss = np.multiply(avg_history_val_loss, 1/cvfold)
    
    
    #plot learning curve
    plot_avg_learning_curve(avg_history_train_acc, avg_history_val_acc, model_idx, 'accuracy')
    #plot loss curve
    plot_avg_learning_curve(avg_history_train_loss, avg_history_val_loss, model_idx, 'loss')
    
    
    
    #append into dict
    learning_curve_dict['avg_history_train_acc'] = avg_history_train_acc
    learning_curve_dict['avg_history_val_acc'] = avg_history_val_acc
    learning_curve_dict['avg_history_train_loss'] = avg_history_train_loss
    learning_curve_dict['avg_history_val_loss'] = avg_history_val_loss
    
    
    
    print('Average scores for pesudo test set across all folds:')
    print(f'> Accuracy: {mean_acc_per_fold} (+- {std_acc_per_fold})')
    print(f'> Loss: {mean_loss_per_fold}')
    print(f'> Avg runtime per test instance: {mean_runtime_per_fold}')
    print('------------------------------------------------------------------------')
    
    return model, mean_acc_per_fold, std_acc_per_fold, mean_loss_per_fold, mean_runtime_per_fold, learning_curve_dict

# %%
#design a sequential model according to input parameter grid
#for multiclass the loss function should be category_crossentropy, not binary
def design_sequential_model(params, inshape, num_class):
    
    model = Sequential()
    num_hidden_layer = params['num_hidden_layer']
    
    # initial layer
    # we use 2^(hiddenlayer +1) as the output number of neuron 
    model.add(Dense(inshape*pow(2, num_hidden_layer+1) , input_shape=(inshape,),
                    activation='relu'))
    
    #If user has specify the output neuron at each hidden layer:
    if "hidden_neuron" in params:
        
        # hidden layers
        for i in range(num_hidden_layer):
            print('Adding layer '+str(i+1)+':')
        
            model.add(Dense(params['hidden_neuron'][i], activation=params['hidden_layer_activation'][i]))
            model.add(Dropout(params['dropout'][i]))
            
    
    #default output neuron at each hidden layer: descending at base 2
    else:
                # hidden layers
        for i in range(num_hidden_layer):
            print('Adding layer '+str(i+1)+':')
        
            model.add(Dense(inshape*pow(2, num_hidden_layer - i), activation=params['hidden_layer_activation'][i]))
            model.add(Dropout(params['dropout'][i]))
            
    
    ## final layer
    model.add(Dense(num_class, activation=params['last_activation']))

    model.summary()
    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])
    
    return model

# %%
#credit: https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#plot-roc-curves-for-the-multilabel-problem

def plot_ROC_curve(cat_ytrue, ypred_prob, num_class, model_name):
    
    #ytest_labels = np.argmax(cat_ytrue, axis=1)
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
        
    ytrue, ypred = cat_ytrue, ypred_prob
    n_classes = num_class
    
    fpr = {}
    tpr = {}
    roc_auc = {}
    
    #check if ypred contains any nan. 
    #If nan then the model intrinsically not suitable (i.e. MLP with too few layers)
    checknan = np.isnan(ypred).any()
    if checknan: return 
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(ytrue[:, i], ypred[:, i]) 
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])
        
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = metrics.roc_curve(ytrue.ravel(), ypred.ravel())
    roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])
    
    
    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    lw = 2
    plt.figure()
    plt.plot(fpr["micro"], tpr["micro"],
             label='micro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["micro"]),
             color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
             label='macro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["macro"]),
             color='navy', linestyle=':', linewidth=4)

    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'darkviolet'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(i, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(model_name +'ROC curve')
    plt.legend(loc="lower right")
    plt.savefig('ROC' + '_' + model_name + now + '.png')
    plt.show()

# %%
#This function is used for models other than Sequential:

def plot_confusion_matrix(cat_ytrue, ypred_prob, model_name):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    

    
    #convert category and prob matrix to single value labels
    ypred_labels = np.argmax(ypred_prob, axis=1)
    ytest_labels = np.argmax(cat_ytrue, axis=1)
        
    ytrue, ypred = ytest_labels, ypred_labels
    
    
    
    #print(ypred_labels)
    #print(ypred_prob)
    #print('---------')
    #print(ytest_labels)
    #print(cat_ytrue)
    
    

    cm = confusion_matrix(ytrue, ypred)
    
    plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(model_name + 'Confusion matrix')
    plt.colorbar()
    
    fmt = 'd' 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('CM' + '_' + model_name + now + '.png')
    plt.show()
    
    #return cm

# %%
def confusion_matrix_per_fold(cat_ytrue, ypred_prob):
    
    #convert category and prob matrix to single value labels
    ypred_labels = np.argmax(ypred_prob, axis=1)
    ytest_labels = np.argmax(cat_ytrue, axis=1)
        
    ytrue, ypred = ytest_labels, ypred_labels
    

    cm = confusion_matrix(ytrue, ypred)
    
    #plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    #plt.title('Confusion matrix per fold')
    #plt.colorbar()
    
    #fmt = 'd' 
    #thresh = cm.max() / 2.
    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    #    plt.text(j, i, format(cm[i, j], fmt),
    #             horizontalalignment="center",
    #             color="white" if cm[i, j] > thresh else "black")
    #plt.ylabel('True label')
    #plt.xlabel('Predicted label')
    #plt.show()
    
    return cm

# %%
def plot_avg_confusion_matrix_across_folds(cm_sum, cv_folds, model_name):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    avg_cm = np.multiply(cm_sum, 1/cv_folds)
    
    #convert to int
    cm = avg_cm.astype(int)
    
    
    
    plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('MLP Avg Confusion matrix across all folds')
    plt.colorbar()
    
    fmt = 'd' 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('CM' + '_' + model_name + now + '.png')
    plt.show()

# %%
# this is for sequential model
def plot_learning_curve(history, fold_no, model_idx):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy (per fold)')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('MLP learning_curve' + '_' + 'model'+ str(model_idx) + '_'+ now + '_'+'fold' + 'fold_no'+'.png')
    plt.show()

# %%
def plot_avg_learning_curve(avg_train_history, avg_val_history,model_idx, ylabel):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    plt.plot(avg_train_history)
    plt.plot(avg_val_history)
    plt.ylabel(ylabel)
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('MLP learning_curve' + '_' + 'model'+ str(model_idx) + '_'+ now +'.png')
    plt.show()

# %%
def plot_avg_learning_curves_all_models(learning_curve_dict_all_models, ylabel):
    
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    #colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'darkviolet'])
    linestyle=cycle(['-', '--', ':', '-.'])
    lw = 2
    
    if ylabel == 'accuracy':
            
        for key, linestyle in zip(learning_curve_dict_all_models, linestyle):
        
            avg_history_train_acc = learning_curve_dict_all_models[key]['avg_history_train_acc'] 
            avg_history_val_acc = learning_curve_dict_all_models[key]['avg_history_val_acc'] 
        
            plt.plot(avg_history_train_acc, lw=lw, linestyle = linestyle,
                     label='training acc of MLP para set {}'.format(key))
            plt.plot(avg_history_val_acc, lw=lw, linestyle = linestyle,
                     label='val acc of MLP para set {}'.format(key))

        plt.ylim([0.0, 1.05])
        plt.xlabel('epoch')
        plt.ylabel(ylabel)
        plt.title('MLP' +'learning curve all models')
        plt.legend(loc="lower right")
        plt.savefig('Learningcurve' + '_' + now + '.png')
        plt.show()
    
    #plot loss curve
    elif ylabel == 'loss':
        
        for key, linestyle in zip(learning_curve_dict_all_models, linestyle):
 
            avg_history_train_loss = learning_curve_dict_all_models[key]['avg_history_train_loss'] 
            avg_history_val_loss = learning_curve_dict_all_models[key]['avg_history_val_loss'] 
        
            plt.plot(avg_history_train_loss, lw=lw, linestyle = linestyle,
                     label='training loss of MLP para set {}'.format(key))
            plt.plot(avg_history_val_loss, lw=lw, linestyle = linestyle,
                     label='val loss of MLP para set {}'.format(key))

        plt.ylim([0.0, 1.05])
        plt.xlabel('epoch')
        plt.ylabel(ylabel)
        plt.title('MLP' +'loss curve all models')
        plt.legend(loc="lower right")
        plt.savefig('Losscurve' + '_' + now + '.png')
        plt.show()
        
    else:
        return

# %%
def save_model_to_disk(model, filename):
    #pickle.dump(model, open(filename, 'wb'))
    with open(filename, 'wb') as file:
        pickle.dump(model, file)

# %%
#preprocess the dataset to extract dominant rgb, landmarks and labels

#return 68 feature contents (from image), corresponding label (from csv), the image name where dlib cannot extract features
#the file names that can be detected by dlib
#and dominant rgb colour for eyes in each image
landmark_features, label_contents, no_features_sets, identified_file_sets, dominant_rgbs  =  B2_prep.extract_features_labels_and_dominant_colour(image_folder, label_name, roi_margin, n_colors)

#number of unique classes to be predicted
num_class = len(np.unique(label_contents))

# %%
#instead of using 68*2 = 136 features we are now only using 3 features (rgb) value for each sample
tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y  = split_data(dominant_rgbs, label_contents, split_ratio)

# %%
# Logistic regression may not be approporiate since sklearn LR by default does not support multi-labe classification 
# Skip instead
#Logclf, LR_pseudo_test_score = LogReg_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, LogReg_tuned_parameters, cvfold)

# %%
# SVM result:
SVMclf, SVM_pseudo_test_score = SVC_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, SVM_tuned_parameters, cvfold, num_class)

save_model_to_disk(SVMclf, "TaskB2_SVMclf.sav")
# Out:
# -------------------------------------------------
# SVC Grid search CV on Dataset A:
#
# Training scores:
#
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.844 (+/-0.005) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.844 (+/-0.005) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.844 (+/-0.005) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.206 (+/-0.001) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.844 (+/-0.005) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
# 0.206 (+/-0.001) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.528 (+/-0.003) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# 0.205 (+/-0.001) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.845 (+/-0.005) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
# 0.842 (+/-0.005) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.843 (+/-0.006) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.530 (+/-0.003) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.843 (+/-0.006) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.205 (+/-0.001) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.846 (+/-0.004) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.843 (+/-0.006) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.844 (+/-0.005) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.846 (+/-0.005) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.843 (+/-0.006) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.843 (+/-0.005) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.530 (+/-0.003) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.205 (+/-0.001) for {'C': 1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.846 (+/-0.005) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.844 (+/-0.005) for {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.844 (+/-0.005) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.843 (+/-0.005) for {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.846 (+/-0.004) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.841 (+/-0.006) for {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.846 (+/-0.005) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.844 (+/-0.005) for {'C': 10, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.843 (+/-0.005) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.843 (+/-0.005) for {'C': 10, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.843 (+/-0.006) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
# 0.843 (+/-0.006) for {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.847 (+/-0.005) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.843 (+/-0.005) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
# 0.833 (+/-0.005) for {'C': 10, 'gamma': 0.1, 'kernel': 'sigmoid'}
#
# Validation scores:
#
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.844 (+/-0.017) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.844 (+/-0.017) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.844 (+/-0.017) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.206 (+/-0.004) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.844 (+/-0.017) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
# 0.206 (+/-0.005) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.528 (+/-0.012) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# 0.205 (+/-0.003) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.845 (+/-0.018) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
# 0.843 (+/-0.018) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.206 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.842 (+/-0.020) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.206 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.529 (+/-0.011) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.842 (+/-0.020) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.205 (+/-0.003) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.846 (+/-0.018) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.842 (+/-0.020) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.844 (+/-0.017) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.846 (+/-0.018) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.842 (+/-0.020) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.843 (+/-0.020) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.530 (+/-0.012) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.843 (+/-0.020) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.205 (+/-0.003) for {'C': 1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.846 (+/-0.018) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.843 (+/-0.020) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.844 (+/-0.017) for {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.844 (+/-0.020) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.843 (+/-0.020) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.843 (+/-0.019) for {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.845 (+/-0.019) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.843 (+/-0.020) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.840 (+/-0.018) for {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.846 (+/-0.018) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.844 (+/-0.017) for {'C': 10, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.843 (+/-0.021) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.843 (+/-0.019) for {'C': 10, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.842 (+/-0.021) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
# 0.842 (+/-0.020) for {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.846 (+/-0.019) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.843 (+/-0.019) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
# 0.835 (+/-0.022) for {'C': 10, 'gamma': 0.1, 'kernel': 'sigmoid'}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86       386
#            1       0.99      0.81      0.89       424
#            2       0.98      0.81      0.89       405
#            3       0.96      0.79      0.86       410
#            4       0.58      0.96      0.72       398
#
#     accuracy                           0.83      2023
#    macro avg       0.88      0.84      0.84      2023
# weighted avg       0.89      0.83      0.85      2023
#
# Accuracy: 0.8348986653484923
#
# Best parameters found on Dataset A:
#
# {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
#
# Average runtime per test instance: 6.064765240022939e-05
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# Random Forest result:
RFclf, RF_pseudo_test_score, RF_importance_indices = RF_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, RF_tuned_parameters, cvfold, num_class)


save_model_to_disk(RFclf, "TaskB2_RFclf.sav")
# Out:
# -------------------------------------------------
# RF Grid search CV on Dataset A:
#
# Training scores:
#
# 0.935 (+/-0.003) for {'max_depth': 64, 'n_estimators': 64}
# 0.935 (+/-0.003) for {'max_depth': 64, 'n_estimators': 128}
# 0.935 (+/-0.003) for {'max_depth': 64, 'n_estimators': 256}
# 0.935 (+/-0.003) for {'max_depth': 64, 'n_estimators': 512}
# 0.935 (+/-0.003) for {'max_depth': 64, 'n_estimators': 1024}
# 0.935 (+/-0.003) for {'max_depth': 128, 'n_estimators': 64}
# 0.935 (+/-0.003) for {'max_depth': 128, 'n_estimators': 128}
# 0.935 (+/-0.003) for {'max_depth': 128, 'n_estimators': 256}
# 0.935 (+/-0.003) for {'max_depth': 128, 'n_estimators': 512}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       386
#            1       0.89      0.87      0.88       424
#            2       0.87      0.88      0.87       405
#            3       0.82      0.85      0.83       410
#            4       0.86      0.85      0.85       398
#
#     accuracy                           0.86      2023
#    macro avg       0.86      0.86      0.86      2023
# weighted avg       0.86      0.86      0.86      2023
#
# Accuracy: 0.861097380128522
#
# Best parameters found on Dataset A:
#
# {'max_depth': 128, 'n_estimators': 64}
#
# Average runtime per test instance: 1.8415271911771947e-05
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# KNN result:

KNNclf, KNN_pseudo_test_score = KNN_Grid_search_Prediction_CV(tr_X, tr_Y, te_X, te_Y, KNN_tuned_parameters, cvfold, num_class)


save_model_to_disk(KNNclf, "TaskB2_KNNclf.sav")
# Out:
# -------------------------------------------------
# KNN Grid search CV on Dataset A:
#
# Training scores:
#
# 0.880 (+/-0.005) for {'n_neighbors': 8}
# 0.868 (+/-0.003) for {'n_neighbors': 16}
# 0.860 (+/-0.005) for {'n_neighbors': 32}
# 0.851 (+/-0.005) for {'n_neighbors': 64}
# 0.844 (+/-0.003) for {'n_neighbors': 128}
#
# Validation scores:
#
# 0.858 (+/-0.013) for {'n_neighbors': 8}
# 0.850 (+/-0.011) for {'n_neighbors': 16}
# 0.842 (+/-0.019) for {'n_neighbors': 32}
# 0.838 (+/-0.022) for {'n_neighbors': 64}
# 0.838 (+/-0.018) for {'n_neighbors': 128}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       386
#            1       0.82      0.88      0.85       424
#            2       0.95      0.86      0.90       405
#            3       0.90      0.79      0.84       410
#            4       0.80      0.89      0.84       398
#
#     accuracy                           0.86      2023
#    macro avg       0.86      0.86      0.86      2023
# weighted avg       0.86      0.86      0.86      2023
#
# Accuracy: 0.8561542263964409
#
# Best parameters found on Dataset A:
#
# {'n_neighbors': 8}
#
# Average runtime per test instance: 3.4509645613832046e-05
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
Seqmodel, Seq_pseudo_test_score = Sequential_Prediction_GridSearch_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)

save_model_to_disk(Seqmodel, "TaskB2_Seqclf.sav")
# Out:
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 48)                192
# _________________________________________________________________
# dense_31 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_32 (Dense)             (None, 12)                300
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_33 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_34 (Dense)             (None, 5)                 35
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4853 samples, validate on 1214 samples
# Epoch 1/100
# 4853/4853 [==============================] - 2s 383us/step - loss: 1.5901 - accuracy: 0.2530 - val_loss: 1.5041 - val_accuracy: 0.3583
# Epoch 2/100
# 4853/4853 [==============================] - 0s 21us/step - loss: 1.5183 - accuracy: 0.3225 - val_loss: 1.4516 - val_accuracy: 0.6689
# Epoch 3/100
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.5115 - accuracy: 0.8348 - val_loss: 0.4601 - val_accuracy: 0.8566
# Epoch 88/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5121 - accuracy: 0.8362 - val_loss: 0.4460 - val_accuracy: 0.8566
# Epoch 89/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5053 - accuracy: 0.8352 - val_loss: 0.4418 - val_accuracy: 0.8574
# Epoch 90/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5056 - accuracy: 0.8335 - val_loss: 0.4450 - val_accuracy: 0.8541
# Epoch 91/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5082 - accuracy: 0.8321 - val_loss: 0.4490 - val_accuracy: 0.8566
# Epoch 92/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5055 - accuracy: 0.8335 - val_loss: 0.4467 - val_accuracy: 0.8549
# Epoch 93/100
# 4854/4854 [==============================] - 0s 28us/step - loss: 0.5024 - accuracy: 0.8292 - val_loss: 0.4406 - val_accuracy: 0.8541
# Epoch 94/100
# 4854/4854 [==============================] - 0s 29us/step - loss: 0.5075 - accuracy: 0.8300 - val_loss: 0.4517 - val_accuracy: 0.8541
# Epoch 95/100
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.5118 - accuracy: 0.8292 - val_loss: 0.4414 - val_accuracy: 0.8557
# Epoch 96/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.4998 - accuracy: 0.8286 - val_loss: 0.4395 - val_accuracy: 0.8549
# Epoch 97/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.4986 - accuracy: 0.8302 - val_loss: 0.4480 - val_accuracy: 0.8549
# Epoch 98/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5035 - accuracy: 0.8323 - val_loss: 0.4423 - val_accuracy: 0.8574
# Epoch 99/100
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.4895 - accuracy: 0.8313 - val_loss: 0.4365 - val_accuracy: 0.8557
# Epoch 100/100
# 4854/4854 [==============================] - 0s 28us/step - loss: 0.4978 - accuracy: 0.8296 - val_loss: 0.4349 - val_accuracy: 0.8533
# 2023/2023 [==============================] - 0s 64us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.8345032095909118 (+- 0.0019119034969606412)
# > Loss: 0.47419911653937763
# > Avg runtime per test instance: 0.0003898417896642227
# ------------------------------------------------------------------------
# ########################################
# Opt model parameter found on the pseudo test set:
#
# {'num_hidden_layer': 4, 'hidden_layer_activation': ['relu', 'tanh', 'relu', 'tanh'], 'dropout': [0.5, 0.25, 0.125, 0.0625], 'last_activation': 'softmax'}
#
# Best average pseudo test set accuracy score with the opt model: 0.8345032095909118
# Average runtime per test instance: 0.0003898417896642227

# %%
#save models
save_model_to_disk(SVMclf, "TaskB2_SVMclf.sav")

save_model_to_disk(RFclf, "TaskB2_RFclf.sav")

save_model_to_disk(KNNclf, "TaskB2_KNNclf.sav")

save_model_to_disk(Seqmodel, "TaskB2_Seqclf.sav")

# %%
save_model_to_disk(SVMclf, "TaskB2_SVMclf.pkl")

save_model_to_disk(RFclf, "TaskB2_RFclf.pkl")

save_model_to_disk(KNNclf, "TaskB2_KNNclf.pkl")

save_model_to_disk(Seqmodel, "TaskB2_Seqclf.pkl")

# %%
#landmark_features, label_contents, no_features_sets, identified_file_sets, dominant_rgbs

save_model_to_disk(dominant_rgbs, "TaskB2_dominant_rgbs.pickle")

# %%
save_model_to_disk(landmark_features, "TaskB2_landmark_features.pickle")
save_model_to_disk(label_contents, "TaskB2_label_contents.pickle")
save_model_to_disk(no_features_sets, "TaskB2_no_features_sets.pickle")
save_model_to_disk(identified_file_sets, "TaskB2_identified_file_sets.pickle")

# %%
with open("TaskB2_Seqclf.pkl", 'rb') as file:
    pickle_model = pickle.load(file)

# %%
pickle_model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_79 (Dense)             (None, 96)                384
# _________________________________________________________________
# dense_80 (Dense)             (None, 48)                4656
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 48)                0
# _________________________________________________________________
# dense_81 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_82 (Dense)             (None, 12)                300
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_83 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_84 (Dense)             (None, 5)                 35
# =================================================================
# Total params: 6,629
# Trainable params: 6,629
# Non-trainable params: 0
# _________________________________________________________________

# %%
with open('B2_preprocessed_data/TaskB2_dominant_rgbs.pickle', 'rb') as f:
    dominant_rgbs = pickle.load(f)

with open('B2_preprocessed_data/TaskB2_label_contents.pickle', 'rb') as f:
    label_contents = pickle.load(f)

    
#number of unique classes to be predicted
num_class = len(np.unique(label_contents))
    
num_epochs = 50    
    
tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y  = split_data(dominant_rgbs, label_contents, split_ratio)



Seqmodel_epoch50, LCSeq_pseudo_test_score_epoch50 = Sequential_Prediction_GridSearch_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)


save_model_to_disk(Seqmodel_epoch50, "TaskB2_Seqclf_epoch50.pkl")

save_model_to_disk(Seqmodel_epoch50, "TaskB2_Seqclf_epoch50.sav")
# Out:
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 48)                192
# _________________________________________________________________
# dense_57 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_58 (Dense)             (None, 12)                300
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_59 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_60 (Dense)             (None, 5)                 35
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4853 samples, validate on 1214 samples
# Epoch 1/50
# 4853/4853 [==============================] - 1s 307us/step - loss: 1.5925 - accuracy: 0.2802 - val_loss: 1.5304 - val_accuracy: 0.5173
# Epoch 2/50
# 4853/4853 [==============================] - 0s 21us/step - loss: 1.5349 - accuracy: 0.3728 - val_loss: 1.4755 - val_accuracy: 0.6689
# Epoch 3/50
# 4853/4853 [==============================] - 0s 25us/step - loss: 1.4963 - accuracy: 0.4177 - val_loss: 1.4329 - val_accuracy: 0.5140
# Epoch 4/50
# 4853/4853 [==============================] - 0s 23us/step - loss: 1.4594 - accuracy: 0.4412 - val_loss: 1.3932 - val_accuracy: 0.5132
# Epoch 5/50
# 4853/4853 [==============================] - 0s 23us/step - loss: 1.4295 - accuracy: 0.4787 - val_loss: 1.3412 - val_accuracy: 0.6722
# Epoch 6/50
# 4853/4853 [==============================] - 0s 22us/step - loss: 1.3997 - accuracy: 0.4892 - val_loss: 1.2957 - val_accuracy: 0.6763
50
# 4853/4853 [==============================] - 0s 19us/step - loss: 0.7853 - accuracy: 0.7437 - val_loss: 0.5974 - val_accuracy: 0.8328
# Epoch 46/50
# 4853/4853 [==============================] - 0s 21us/step - loss: 0.7787 - accuracy: 0.7435 - val_loss: 0.5948 - val_accuracy: 0.8320
# Epoch 47/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 0.7724 - accuracy: 0.7531 - val_loss: 0.5931 - val_accuracy: 0.8320
# Epoch 48/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 0.7771 - accuracy: 0.7447 - val_loss: 0.5908 - val_accuracy: 0.8320
# Epoch 49/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 0.7733 - accuracy: 0.7484 - val_loss: 0.5882 - val_accuracy: 0.8320
# Epoch 50/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 0.7896 - accuracy: 0.7416 - val_loss: 0.5864 - val_accuracy: 0.8320
# 2023/2023 [==============================] - 0s 51us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 2 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_61 (Dense)             (None, 48)                192
# _________________________________________________________________
# dense_62 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 12)                300
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_64 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_65 (Dense)             (None, 5)                 35
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4853 samples, validate on 1214 samples
# Epoch 1/50
# 4853/4853 [==============================] - 2s 317us/step - loss: 1.6040 - accuracy: 0.2366 - val_loss: 1.5523 - val_accuracy: 0.3451
# Epoch 2/50
# 4853/4853 [==============================] - 0s 18us/step - loss: 1.5445 - accuracy: 0.3079 - val_loss: 1.5082 - val_accuracy: 0.5066
# Epoch 3/50
# 4853/4853 [==============================] - 0s 18us/step - loss: 1.5113 - accuracy: 0.3344 - val_loss: 1.4687 - val_accuracy: 0.3534
# Epoch 4/50
# 4853/4853 [==============================] - 0s 18us/step - loss: 1.4787 - accuracy: 0.3627 - val_loss: 1.4328 - val_accuracy: 0.3509
# Epoch 5/50
# 4853/4853 [==============================] - 0s 18us/step - loss: 1.4524 - accuracy: 0.3882 - val_loss: 1.3913 - val_accuracy: 0.5165
# Epoch 6/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.4123 - accuracy: 0.4255 - val_loss: 1.3482 - val_accuracy: 0.6771
# Epoch 7/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.3880 - accuracy: 0.4527 - val_loss: 1.3039 - val_accuracy: 0.6689
# Epoch 8/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.3471 - accuracy: 0.4939 - val_loss: 1.2622 - val_accuracy: 0.6787
# Epoch 9/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.3158 - accuracy: 0.5189 - val_loss: 1.2275 - val_accuracy: 0.6647
# Epoch 10/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.2933 - accuracy: 0.5298 - val_loss: 1.1847 - val_accuracy: 0.6787
# Epoch 11/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.2657 - accuracy: 0.5518 - val_loss: 1.1406 - val_accuracy: 0.6787
# Epoch 12/50
# 4853/4853 [==============================] - 0s 18us/step - loss: 1.2352 - accuracy: 0.5551 - val_loss: 1.1024 - val_accuracy: 0.6787
# Epoch 13/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.2074 - accuracy: 0.5687 - val_loss: 1.0613 - val_accuracy: 0.6771
# Epoch 14/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.1762 - accuracy: 0.5887 - val_loss: 1.0292 - val_accuracy: 0.6787
# Epoch 15/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.1603 - accuracy: 0.5939 - val_loss: 0.9947 - val_accuracy: 0.8402
# Epoch 16/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1.1318 - accuracy: 0.6149 - val_loss: 0.9576 - val_accuracy: 0.8468
# Epoch 17/50
# 4853/4853 [==============================] - 0s 19us/step - loss: 1
50
# 4854/4854 [==============================] - 0s 20us/step - loss: 0.8005 - accuracy: 0.7225 - val_loss: 0.5242 - val_accuracy: 0.8508
# Epoch 44/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7711 - accuracy: 0.7344 - val_loss: 0.5208 - val_accuracy: 0.8508
# Epoch 45/50
# 4854/4854 [==============================] - 0s 18us/step - loss: 0.7894 - accuracy: 0.7239 - val_loss: 0.5170 - val_accuracy: 0.8508
# Epoch 46/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7809 - accuracy: 0.7359 - val_loss: 0.5242 - val_accuracy: 0.8508
# Epoch 47/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7771 - accuracy: 0.7351 - val_loss: 0.5145 - val_accuracy: 0.8508
# Epoch 48/50
# 4854/4854 [==============================] - 0s 20us/step - loss: 0.7750 - accuracy: 0.7357 - val_loss: 0.5140 - val_accuracy: 0.8516
# Epoch 49/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7395 - accuracy: 0.7450 - val_loss: 0.5121 - val_accuracy: 0.8516
# Epoch 50/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7522 - accuracy: 0.7415 - val_loss: 0.5170 - val_accuracy: 0.8516
# 2023/2023 [==============================] - 0s 51us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 4 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_71 (Dense)             (None, 48)                192
# _________________________________________________________________
# dense_72 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_73 (Dense)             (None, 12)                300
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_74 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_75 (Dense)             (None, 5)                 35
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4854 samples, validate on 1213 samples
# Epoch 1/50
# 4854/4854 [==============================] - 2s 319us/step - loss: 1.6125 - accuracy: 0.2138 - val_loss: 1.5334 - val_accuracy: 0.3430
# Epoch 2/50
# 4854/4854 [==============================] - 0s 18us/step - loss: 1.5338 - accuracy: 0.2862 - val_loss: 1.4739 - val_accuracy: 0.3397
# Epoch 3/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.4811 - accuracy: 0.3193 - val_loss: 1.4233 - val_accuracy: 0.3405
# Epoch 4/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.4400 - accuracy: 0.3556 - val_loss: 1.3820 - val_accuracy: 0.3405
# Epoch 5/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.4072 - accuracy: 0.3593 - val_loss: 1.3479 - val_accuracy: 0.3446
# Epoch 6/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.3837 - accuracy: 0.3731 - val_loss: 1.3185 - val_accuracy: 0.5070
# Epoch 7/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.3519 - accuracy: 0.3931 - val_loss: 1.2874 - val_accuracy: 0.5070
# Epoch 8/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.3412 - accuracy: 0.3991 - val_loss: 1.2675 - val_accuracy: 0.5062
# Epoch 9/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.3150 - accuracy: 0.4287 - val_loss: 1.2423 - val_accuracy: 0.5062
# Epoch 10/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.2967 - accuracy: 0.4415 - val_loss: 1.2218 - val_accuracy: 0.5062
# Epoch 11/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.2816 - accuracy: 0.4576 - val_loss: 1.2034 - val_accuracy: 0.5062
# Epoch 12/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.2616 - accuracy: 0.4664 - val_loss: 1.1855 - val_accuracy: 0.5062
# Epoch 13/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.2527 - accuracy: 0.4784 - val_loss: 1.1642 - val_accuracy: 0.5070
# Epoch 14/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.2356 - accuracy: 0.4806 - val_loss: 1.1462 - val_accuracy: 0.5070
# Epoch 15/50
# 4854/4854 [==============================] - 0s 20us/step - loss: 1.2100 - accuracy: 0.4986 - val_loss: 1.1283 - val_accuracy: 0.5070
# Epoch 16/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.1962 - accuracy: 0.4996 - val_loss: 1.1102 - val_accuracy: 0.5062
# Epoch 17/50
# 4854/4854 [==============================] - 0s 20us/step - loss:
50
# 4854/4854 [==============================] - 0s 20us/step - loss: 0.9007 - accuracy: 0.7291 - val_loss: 0.7391 - val_accuracy: 0.8277
# Epoch 47/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.8847 - accuracy: 0.7316 - val_loss: 0.7375 - val_accuracy: 0.8293
# Epoch 48/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.8644 - accuracy: 0.7406 - val_loss: 0.7305 - val_accuracy: 0.8277
# Epoch 49/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.8677 - accuracy: 0.7392 - val_loss: 0.7254 - val_accuracy: 0.8285
# Epoch 50/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.8755 - accuracy: 0.7309 - val_loss: 0.7201 - val_accuracy: 0.8277
# 2023/2023 [==============================] - 0s 52us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 5 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_76 (Dense)             (None, 48)                192
# _________________________________________________________________
# dense_77 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_78 (Dense)             (None, 12)                300
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_79 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_80 (Dense)             (None, 5)                 35
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4854 samples, validate on 1213 samples
# Epoch 1/50
# 4854/4854 [==============================] - 2s 328us/step - loss: 1.6338 - accuracy: 0.2235 - val_loss: 1.5524 - val_accuracy: 0.5243
# Epoch 2/50
# 4854/4854 [==============================] - 0s 18us/step - loss: 1.5460 - accuracy: 0.3026 - val_loss: 1.4313 - val_accuracy: 0.5260
# Epoch 3/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.4665 - accuracy: 0.3892 - val_loss: 1.3456 - val_accuracy: 0.5276
# Epoch 4/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.3957 - accuracy: 0.4637 - val_loss: 1.2665 - val_accuracy: 0.7659
# Epoch 5/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.3427 - accuracy: 0.5016 - val_loss: 1.2012 - val_accuracy: 0.8475
# Epoch 6/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.3098 - accuracy: 0.5192 - val_loss: 1.1495 - val_accuracy: 0.8475
# Epoch 7/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.2721 - accuracy: 0.5470 - val_loss: 1.0950 - val_accuracy: 0.8475
# Epoch 8/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.2305 - accuracy: 0.5816 - val_loss: 1.0379 - val_accuracy: 0.8483
# Epoch 9/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.1997 - accuracy: 0.5779 - val_loss: 0.9953 - val_accuracy: 0.8483
# Epoch 10/50
# 4854/4854 [==============================] - 0s 18us/step - loss: 1.1699 - accuracy: 0.6057 - val_loss: 0.9452 - val_accuracy: 0.8483
# Epoch 11/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.1310 - accuracy: 0.6102 - val_loss: 0.8999 - val_accuracy: 0.8483
# Epoch 12/50
# 4854/4854 [==============================] - 0s 18us/step - loss: 1.1053 - accuracy: 0.6308 - val_loss: 0.8630 - val_accuracy: 0.8483
# Epoch 13/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.0753 - accuracy: 0.6275 - val_loss: 0.8327 - val_accuracy: 0.8475
# Epoch 14/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.0610 - accuracy: 0.6384 - val_loss: 0.7903 - val_accuracy: 0.8475
# Epoch 15/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.0355 - accuracy: 0.6543 - val_loss: 0.7616 - val_accuracy: 0.8475
# Epoch 16/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 1.0180 - accuracy: 0.6514 - val_loss: 0.7358 - val_accuracy: 0.8475
# Epoch 17/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.9898 - accuracy: 0.6687 - val_loss: 0.7102 - val_accuracy: 0.8475
# Epoch 18/50
# 4854/4854 [==============================] - 0s 20us/step - loss: 0.9657 - accuracy: 0.6683 - val_loss: 0.6845 - val_accuracy: 0.8458
# Epoch 19/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.
50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7492 - accuracy: 0.7371 - val_loss: 0.5117 - val_accuracy: 0.8467
# Epoch 49/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7432 - accuracy: 0.7456 - val_loss: 0.5095 - val_accuracy: 0.8467
# Epoch 50/50
# 4854/4854 [==============================] - 0s 19us/step - loss: 0.7454 - accuracy: 0.7388 - val_loss: 0.5094 - val_accuracy: 0.8467
# 2023/2023 [==============================] - 0s 54us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.8388531684875489 (+- 0.001594118214319857)
# > Loss: 0.5730553698492592
# > Avg runtime per test instance: 0.00035429057424397263
# ------------------------------------------------------------------------
# ########################################
#
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Adding layer 4:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 96)                384
# _________________________________________________________________
# dense_82 (Dense)             (None, 48)                4656
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 48)                0
# _________________________________________________________________
# dense_83 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dropout_52 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_84 (Dense)             (None, 12)                300
# _________________________________________________________________
# dropout_53 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_85 (Dense)             (None, 6)                 78
# _________________________________________________________________
# dropout_54 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_86 (Dense)             (None, 5)                 35
# ...
# Epoch 13/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.9039 - accuracy: 0.7709 - val_loss: 0.7349 - val_accuracy: 0.8508
# Epoch 14/50
# 4854/4854 [==============================] - 0s 31us/step - loss: 0.8844 - accuracy: 0.7835 - val_loss: 0.7160 - val_accuracy: 0.8508
# Epoch 15/50
# 4854/4854 [==============================] - 0s 28us/step - loss: 0.8726 - accuracy: 0.7827 - val_loss: 0.7029 - val_accuracy: 0.8500
# Epoch 16/50
# 4854/4854 [==============================] - 0s 38us/step - loss: 0.8525 - accuracy: 0.7899 - val_loss: 0.6872 - val_accuracy: 0.8516
# Epoch 17/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.8351 - accuracy: 0.7952 - val_loss: 0.6736 - val_accuracy: 0.8508
# Epoch 18/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.8166 - accuracy: 0.7903 - val_loss: 0.6619 - val_accuracy: 0.8508
# Epoch 19/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.8011 - accuracy: 0.7954 - val_loss: 0.6519 - val_accuracy: 0.8508
# Epoch 20/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.7975 - accuracy: 0.8030 - val_loss: 0.6372 - val_accuracy: 0.8516
# Epoch 21/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.7776 - accuracy: 0.8047 - val_loss: 0.6340 - val_accuracy: 0.8516
# Epoch 22/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.7649 - accuracy: 0.8094 - val_loss: 0.6185 - val_accuracy: 0.8516
# Epoch 23/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.7498 - accuracy: 0.8101 - val_loss: 0.6114 - val_accuracy: 0.8508
# Epoch 24/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.7506 - accuracy: 0.8084 - val_loss: 0.5974 - val_accuracy: 0.8524
# Epoch 25/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.7334 - accuracy: 0.8109 - val_loss: 0.5921 - val_accuracy: 0.8516
# Epoch 26/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.7219 - accuracy: 0.8133 - val_loss: 0.5863 - val_accuracy: 0.8516
# Epoch 27/50
# 4854/4854 [==============================] - 0s 25us/step - loss: 0.7154 - accuracy: 0.8140 - val_loss: 0.5835 - val_accuracy: 0.8524
# Epoch 28/50
# 4854/4854 [==============================] - 0s 25us/step - loss: 0.6993 - accuracy: 0.8199 - val_loss: 0.5717 - val_accuracy: 0.8524
# Epoch 29/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0
/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 5 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Adding layer 4:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_105 (Dense)            (None, 96)                384
# _________________________________________________________________
# dense_106 (Dense)            (None, 48)                4656
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 48)                0
# _________________________________________________________________
# dense_107 (Dense)            (None, 24)                1176
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 24)                0
# _________________________________________________________________
# dense_108 (Dense)            (None, 12)                300
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_109 (Dense)            (None, 6)                 78
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 6)                 0
# _________________________________________________________________
# dense_110 (Dense)            (None, 5)                 35
# =================================================================
# Total params: 6,629
# Trainable params: 6,629
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4854 samples, validate on 1213 samples
# Epoch 1/50
# 4854/4854 [==============================] - 3s 550us/step - loss: 1.5476 - accuracy: 0.2824 - val_loss: 1.4046 - val_accuracy: 0.6851
# Epoch 2/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 1.4069 - accuracy: 0.4953 - val_loss: 1.2691 - val_accuracy: 0.5812
# Epoch 3/50
# 4854/4854 [==============================] - 0s 31us/step - loss: 1.3156 - accuracy: 0.5391 - val_loss: 1.1746 - val_accuracy: 0.6867
# Epoch 4/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 1.2344 - accuracy: 0.5622 - val_loss: 1.1004 - val_accuracy: 0.6859
# Epoch 5/50
# 4854/4854 [==============================] - 0s 44us/step - loss: 1.1749 - accuracy: 0.5902 - val_loss: 1.0396 - val_accuracy: 0.6843
# Epoch 6/50
# 4854/4854 [==============================] - 0s 47us/step - loss: 1.1210 - accuracy: 0.5966 - val_loss: 0.9956 - val_accuracy: 0.6843
# Epoch 7/50
# 4854/4854 [==============================] - 0s 50us/step - loss: 1.0806 - accuracy: 0.6187 - val_loss: 0.9568 - val_accuracy: 0.6834
# Epoch 8/50
# 4854/4854 [==============================] - 0s 38us/step - loss: 1.0517 - accuracy: 0.6506 - val_loss: 0.9220 - val_accuracy: 0.6876
# Epoch 9/50
# 4854/4854 [==============================] - 0s 28us/step - loss: 1.0146 - accuracy: 0.6776 - val_loss: 0.8902 - val_accuracy: 0.8335
# Epoch 10/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.9826 - accuracy: 0.7110 - val_loss: 0.8595 - val_accuracy: 0.8335
# Epoch 11/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.9608 - accuracy: 0.7258 - val_loss: 0.8285 - val_accuracy: 0.8318
# Epoch 12/50
# 4854/4854 [==============================] - 0s 25us/step - loss: 0.9297 - accuracy: 0.7365 - val_loss: 0.8018 - val_accuracy: 0.8318
# Epoch 13/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.9037 - accuracy: 0.7536 - val_loss: 0.7825 - val_accuracy: 0.8318
# Epoch 14/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0
50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.6279 - accuracy: 0.8253 - val_loss: 0.5866 - val_accuracy: 0.8195
# Epoch 36/50
# 4854/4854 [==============================] - 0s 33us/step - loss: 0.6270 - accuracy: 0.8232 - val_loss: 0.5825 - val_accuracy: 0.8318
# Epoch 37/50
# 4854/4854 [==============================] - 0s 36us/step - loss: 0.6144 - accuracy: 0.8304 - val_loss: 0.5723 - val_accuracy: 0.8326
# Epoch 38/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.6084 - accuracy: 0.8261 - val_loss: 0.5686 - val_accuracy: 0.8326
# Epoch 39/50
# 4854/4854 [==============================] - 0s 31us/step - loss: 0.6058 - accuracy: 0.8274 - val_loss: 0.5662 - val_accuracy: 0.8203
# Epoch 40/50
# 4854/4854 [==============================] - 0s 47us/step - loss: 0.5974 - accuracy: 0.8284 - val_loss: 0.5605 - val_accuracy: 0.8293
# Epoch 41/50
# 4854/4854 [==============================] - 0s 52us/step - loss: 0.5906 - accuracy: 0.8317 - val_loss: 0.5610 - val_accuracy: 0.8318
# Epoch 42/50
# 4854/4854 [==============================] - 0s 42us/step - loss: 0.5957 - accuracy: 0.8286 - val_loss: 0.5529 - val_accuracy: 0.8244
# Epoch 43/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5774 - accuracy: 0.8337 - val_loss: 0.5533 - val_accuracy: 0.8219
# Epoch 44/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5804 - accuracy: 0.8313 - val_loss: 0.5474 - val_accuracy: 0.8318
# Epoch 45/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5758 - accuracy: 0.8311 - val_loss: 0.5478 - val_accuracy: 0.8219
# Epoch 46/50
# 4854/4854 [==============================] - 0s 33us/step - loss: 0.5671 - accuracy: 0.8344 - val_loss: 0.5470 - val_accuracy: 0.8318
# Epoch 47/50
# 4854/4854 [==============================] - 0s 27us/step - loss: 0.5687 - accuracy: 0.8321 - val_loss: 0.5462 - val_accuracy: 0.8318
# Epoch 48/50
# 4854/4854 [==============================] - 0s 29us/step - loss: 0.5635 - accuracy: 0.8372 - val_loss: 0.5447 - val_accuracy: 0.8310
# Epoch 49/50
# 4854/4854 [==============================] - 0s 26us/step - loss: 0.5570 - accuracy: 0.8352 - val_loss: 0.5408 - val_accuracy: 0.8269
# Epoch 50/50
# 4854/4854 [==============================] - 0s 29us/step - loss: 0.5608 - accuracy: 0.8313 - val_loss: 0.5384 - val_accuracy: 0.8310
# 2023/2023 [==============================] - 0s 73us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.839347505569458 (+- 0.0009886264802462825)
# > Loss: 0.5274854640286274
# > Avg runtime per test instance: 0.0005732796537481318
# ------------------------------------------------------------------------
# ########################################
# Opt model parameter found on the pseudo test set:
#
# {'num_hidden_layer': 4, 'hidden_layer_activation': ['relu', 'tanh', 'relu', 'tanh'], 'dropout': [0.5, 0.25, 0.125, 0.0625], 'last_activation': 'softmax'}
#
# Best average pseudo test set accuracy score with the opt model: 0.839347505569458
# Average runtime per test instance: 0.0005732796537481318

# %%
# KNN result:

#KNNclf_testcm, KNN_pseudo_test_score_testcm = KNN_Grid_search_Prediction_CV(tr_X, tr_Y, te_X, te_Y, KNN_tuned_parameters, cvfold, num_class)

# %%
#Sequential_Prediction_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)
