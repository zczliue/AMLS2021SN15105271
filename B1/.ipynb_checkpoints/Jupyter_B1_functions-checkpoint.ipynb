# %%
# This is the function file for Task B1,
# which assess the performance between different classifiers, 
# by grid search with cross validation, including:

# Logistic Regression
# SVM 
# Random Forest
# KNN
# MLP

# The assessment metrices for classifiers include:
# 1. Accuracy score between ytrue and ypred
# 2. Grid score for grid search tuning
# 


# To use this file, specify:
# 'image_folder' : a string in either 'celeba' or 'cartoon_set'
# 'label_name' :  a string that specifies the feature name, i.e. 'gender', 'smiling' as in labels.csv
# 'tuning_parameters' : a dictionary contains different kernels and settings
# 'cvfold': an int for K-fold cross validation

# return value: trained classifier with best parameter settings

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import keras
import sklearn
import cv2
import dlib
#import rewritten lab2 landmarks extraction 
import B1_extract_landmarks as B1_extract
import itertools 
import datetime
import pickle
# Out:
# Using TensorFlow backend.

# %%
from itertools import cycle
from scipy import interp

from sklearn import datasets, metrics, model_selection, svm
from sklearn.utils import shuffle
from sklearn.datasets import load_iris

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import roc_curve, auc

from keras.preprocessing import image
from keras.models import Sequential 
from keras.models import Sequential 
from keras.layers import Dense , Dropout 
from keras.optimizers import SGD
from keras.optimizers import RMSprop

# %%
# Set the parameters for Grid search
split_ratio = 0.75
cvfold = 5
image_folder = 'cartoon_set'
label_name   = 'face_shape'
num_epochs = 100



#SVM
#SVM_tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-2, 1e-1, 1, 10],'C': [0.01, 0.1, 1, 10]}]
#                        {'kernel': ['linear'], 'C': [0.01, 0.1, 1, 10]},
#                        {'kernel':['sigmoid'],'gamma': [1e-2, 1e-1, 1, 10],'C': [0.01, 0.1, 1, 10]}

SVM_tuned_parameters = {'kernel': ['rbf', 'linear', 'sigmoid'],
                        'C': [0.001, 0.01, 0.1, 1, 10],
                        'gamma': [1e-4, 1e-3, 1e-2, 1e-1]}

#SVM_tuned_parameters = {'kernel':['linear'], 'C':[1]}

#Logistic Regression
#LogReg_tuned_parameters = [{ 'solver':['lbfgs'], 'C':[0.01, 0.1, 1, 10]}, 
#                          {'solver':[ 'saga'], 'penalty':['l1'], 'C':[0.01, 0.1, 1, 10]}]

LogReg_tuned_parameters = {'solver':[ 'saga'], 'penalty':['l1', 'l2'], 'C':[1e-4, 1e-3, 1e-2, 1e-1, 1,10]}
                          

#Random Forest
RF_tuned_parameters = [{'n_estimators':[64, 128, 256, 512, 1024], 'max_depth':[64, 128, 256, 512, 1024]}]

#KNN parameter
KNN_tuned_parameters = [{'n_neighbors':[8,16,32,64,128]}]

#MLP parameter
MLP_tuned_parameters = [{'hidden_layer_sizes': [(128,256,128,), (128,256,128,), (128,),(256,),(512,)], 
                         'activation': ['logistic', 'tanh', 'relu'],
                         'learning_rate':['constant', 'adaptive']}]


Squential_model_parameters = [{'num_hidden_layer': 3,
                              'hidden_layer_activation' : ['relu','tanh','relu'],
                              'dropout':[0.5,0.25,0.125],
                              'last_activation':'softmax'},
                              
                              {'num_hidden_layer': 4,
                              'hidden_layer_activation' : ['relu','tanh','relu','tanh'],
                              'dropout':[0.5,0.25,0.125,0.0625],
                              'last_activation':'softmax'}]

# %%
# This function is rewritten as follows:
# the input image_folder must be a string that specifies 'celeba' or 'cartoon_set'
# the input label_name must be a string that specifies the feature name, i.e. 'gender', 'smiling' as in labels.csv

def split_data(X, y, split_ratio):
    
    X, Y = shuffle(X,y)
    train_X, test_X, train_Y, test_Y = train_test_split(X, Y, train_size=split_ratio)
    
    #reshape into appropriate dimensions
    tr_X = train_X.reshape((train_X.shape[0], train_X.shape[1]*2))
    te_X = test_X.reshape((test_X.shape[0], test_X.shape[1]*2))
    
    
    #normalisation
    x_scaler = StandardScaler()
    tr_X = x_scaler.fit_transform(tr_X)
    te_X = x_scaler.transform(te_X)
    
    #train_Y, test_Y are single valued Y (multi-class) 
    tr_Y = train_Y
    te_Y = test_Y

    
    #convert to category matrix. 
    cat_tr_Y = keras.utils.to_categorical(tr_Y)
    cat_te_Y = keras.utils.to_categorical(te_Y)

    return tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y

# %%
# In Task B1 we use predict proba instead of predict (as in previous tasks)

def bulk_runtime_estimation(classifier, xtest):
    
    nsamp = xtest.shape[0]
    start = time.time()
    ypred = classifier.predict(xtest)
    ypred_prob = classifier.predict_proba(xtest)
    bulk_runtime = time.time() - start
    
    #average runtime per instance
    avg_runtime = bulk_runtime/nsamp
    
    return ypred, ypred_prob, bulk_runtime, avg_runtime

# %%
#Prediction with Grid search SVC Cross validation
def SVC_GridSearch_PredictionCV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold, num_class):
    # classifier
    clf = GridSearchCV(SVC(probability=True), tuning_parameters, cv = cvfold, return_train_score=True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("SVC Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'SVM')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'SVM')
    
    #return best classifier
    return clf.best_estimator_, pseudo_test_score

# %%
def RF_GridSearch_PredictionCV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold, num_class):

    clf = GridSearchCV(RandomForestClassifier() , tuning_parameters, cv = cvfold, return_train_score=True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("RF Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    
    #determine important features
    importances = clf.best_estimator_.feature_importances_
    indices = np.argsort(importances)
    plt.title('Feature Importances')
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), [i for i in indices])
    plt.xlabel('Relative Importance')
    plt.show()
    
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'Random Forest')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'Random Forest')

    #return classifier
    return clf.best_estimator_, pseudo_test_score, indices

# %%
def KNN_Grid_search_Prediction_CV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold, num_class):
    clf = GridSearchCV(KNeighborsClassifier() , tuning_parameters, cv = cvfold, return_train_score = True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred,ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("KNN Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'KNN')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'KNN')
    
    #return classifier
    return clf.best_estimator_, pseudo_test_score

# %%
def Sequential_Prediction_GridSearch_CV(xtrain, ytrain, xtest, ytest, grid_parameters, cvfold, num_class, num_epochs):
    
    learning_curve_dict_all_models = {}
    
    acc_all_models = []
    acc_std_all_models = []
    loss_all_models = []
    runtime_mean_all_models = []
    
    all_models = []
    
    #the para combination index in search grid
    model_idx = 0
    
    for model_parameters in grid_parameters:
        
        print()
        
        print('########################################')
        model, acc_mean, acc_std_mean, loss_mean, runtime_mean, learning_curve_dict = Sequential_Prediction_CV(xtrain, ytrain, xtest, ytest, model_parameters, cvfold, num_class, num_epochs, model_idx)
        
        #store returned values for each model
        acc_all_models.append(acc_mean)
        acc_std_all_models.append(acc_std_mean)
        loss_all_models.append(loss_mean)
        runtime_mean_all_models.append(runtime_mean)
        
        all_models.append(model)
        
        #store learning and loss curve
        learning_curve_dict_all_models[model_idx] = learning_curve_dict
        

        print('########################################')
        
        model_idx = model_idx + 1
        
        
       
        
    #find max acc value on pseudo test set and index
    max_acc_value = max(acc_all_models)
    max_acc_value_index = acc_all_models.index(max_acc_value)
    
    
    
    #plot learning and loss curve
    plot_avg_learning_curves_all_models(learning_curve_dict_all_models, 'accuracy')
    plot_avg_learning_curves_all_models(learning_curve_dict_all_models, 'loss')
    
        
        
        
        
    
    print('Opt model parameter found on the pseudo test set:')
    print()
    print(grid_parameters[max_acc_value_index])
    print()
    print('Best average pseudo test set accuracy score with the opt model: {}'.format(max_acc_value))
    print('Average runtime per test instance: {}'.format(runtime_mean_all_models[max_acc_value_index]))
    
    
    
    return all_models[max_acc_value_index], max_acc_value

# %%
def Sequential_Prediction_CV(xtrain, ytrain, xtest, ytest, model_parameters, cvfold, num_class, num_epochs, model_idx):
    
    #a dict to store learning curve and loss curves
    learning_curve_dict = {}
    
    # aggregate inputs and targets
    #inputs = np.concatenate((xtrain, xtest), axis=0)
    #targets = np.concatenate((ytrain, ytest), axis=0)
    inputs  = xtrain
    targets = ytrain
    
    fold_no = 1
    #instead of using GridsearchCV we apply a manual function
    kf = KFold(n_splits=cvfold, random_state=None, shuffle=True)
    #record accuracy and loss per fold
    acc_per_fold  = []
    loss_per_fold = []
    avg_runtime_per_fold = []

    #average history train and val acc across all folds
    avg_history_train_acc = np.zeros(num_epochs)
    avg_history_val_acc = np.zeros(num_epochs)
    avg_history_train_loss = np.zeros(num_epochs)
    avg_history_val_loss = np.zeros(num_epochs)
    
    #an empty array to store confusion matrix every fold
    cm_sum = np.zeros((num_class,num_class))
    
    #input feature shape 
    in_feature_shape = xtrain.shape[1]
    #number of class (labels)
    num_labels = num_class
    
    #kf.split divide inputs and targets into K folds and
    #train_idx, test_idx are the indices for training set and validation set
    for train_idx, test_idx in kf.split(inputs, targets):
        
        print('------------------------------------------------------------------------')
        print('Squential with Kfold CV: ')
        print('Training for fold {} ...'.format(fold_no))
        
        #reconstruct model for each fold
        model = design_sequential_model(model_parameters, in_feature_shape, num_class)

        #
        history = model.fit(inputs[train_idx], targets[train_idx],
                    batch_size=int(xtrain.shape[0]/10),
                    epochs=num_epochs,
                    validation_data=(inputs[test_idx], targets[test_idx]),
                    verbose=1)
        
        
        
        #evaluate pseudo test set (split from Dataset A)
        scores = model.evaluate(xtest, ytest, verbose=1)
                
        acc_per_fold.append(scores[1])
        loss_per_fold.append(scores[0])
        
        
        #save history
        avg_history_train_acc = avg_history_train_acc + history.history['accuracy']
        avg_history_val_acc = avg_history_val_acc + history.history['val_accuracy']
        avg_history_train_loss = avg_history_train_loss + history.history['loss']
        avg_history_val_loss = avg_history_val_loss + history.history['val_loss']
        
        
        #generate predictions
        #ypred = model.predict(xtest)
        #model.predict returns probability
        ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(model, xtest)
        
        #convert to single value labels
        #ypred_labels = np.argmax(ypred_prob, axis=1)
        #ytest_labels = np.argmax(ytest, axis=1)
        
        #ytrue, ypred = ytest_labels, ypred_labels
        
        avg_runtime_per_fold.append(avg_runtime)
        
        # confusion matrix 
        #plot_confusion_matrix(ytest, ypred_prob)
        cm_sum = cm_sum + confusion_matrix_per_fold(ytest, ypred_prob)        
        
        # ROC curve
        plot_ROC_curve(ytest, ypred_prob, num_class, 'MLP')
        
        #plot learning curve
        #plot_learning_curve(history, fold_no, model_idx)

        # Increase fold number
        fold_no = fold_no + 1
        
    # == Provide average scores ==
    print()
    mean_acc_per_fold = np.mean(acc_per_fold)
    std_acc_per_fold = np.std(acc_per_fold)
    mean_loss_per_fold = np.mean(loss_per_fold)
    
    mean_runtime_per_fold = np.mean(avg_runtime_per_fold)
    
    
    #plot average confusion matrix
    plot_avg_confusion_matrix_across_folds(cm_sum, cvfold, 'MLP')
    
    
    #plot avg learning curve accross all folds
    avg_history_train_acc = np.multiply(avg_history_train_acc, 1/cvfold)
    avg_history_val_acc = np.multiply(avg_history_val_acc, 1/cvfold)
    avg_history_train_loss = np.multiply(avg_history_train_loss, 1/cvfold)
    avg_history_val_loss = np.multiply(avg_history_val_loss, 1/cvfold)
    
    
    #plot learning curve
    plot_avg_learning_curve(avg_history_train_acc, avg_history_val_acc, model_idx, 'accuracy')
    #plot loss curve
    plot_avg_learning_curve(avg_history_train_loss, avg_history_val_loss, model_idx, 'loss')
    
    
    
    #append into dict
    learning_curve_dict['avg_history_train_acc'] = avg_history_train_acc
    learning_curve_dict['avg_history_val_acc'] = avg_history_val_acc
    learning_curve_dict['avg_history_train_loss'] = avg_history_train_loss
    learning_curve_dict['avg_history_val_loss'] = avg_history_val_loss
    
    
    
    print('Average scores for pesudo test set across all folds:')
    print(f'> Accuracy: {mean_acc_per_fold} (+- {std_acc_per_fold})')
    print(f'> Loss: {mean_loss_per_fold}')
    print(f'> Avg runtime per test instance: {mean_runtime_per_fold}')
    print('------------------------------------------------------------------------')
    
    return model, mean_acc_per_fold, std_acc_per_fold, mean_loss_per_fold, mean_runtime_per_fold, learning_curve_dict

# %%
#design a sequential model according to input parameter grid
#for multiclass the loss function should be category_crossentropy, not binary
def design_sequential_model(params, inshape, num_class):
    
    model = Sequential()
    num_hidden_layer = params['num_hidden_layer']
    
    # initial layer
    # we use 2^(hiddenlayer +1) as the output number of neuron 
    model.add(Dense(inshape*pow(2, num_hidden_layer+1) , input_shape=(inshape,),
                    activation='relu'))
    
    #If user has specify the output neuron at each hidden layer:
    if "hidden_neuron" in params:
        
        # hidden layers
        for i in range(num_hidden_layer):
            print('Adding layer '+str(i+1)+':')
        
            model.add(Dense(params['hidden_neuron'][i], activation=params['hidden_layer_activation'][i]))
            model.add(Dropout(params['dropout'][i]))
            
    
    #default output neuron at each hidden layer: descending at base 2
    else:
                # hidden layers
        for i in range(num_hidden_layer):
            print('Adding layer '+str(i+1)+':')
        
            model.add(Dense(inshape*pow(2, num_hidden_layer - i), activation=params['hidden_layer_activation'][i]))
            model.add(Dropout(params['dropout'][i]))
            
    
    ## final layer
    model.add(Dense(num_class, activation=params['last_activation']))

    model.summary()
    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])
    
    return model

# %%
#credit: https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#plot-roc-curves-for-the-multilabel-problem

def plot_ROC_curve(cat_ytrue, ypred_prob, num_class, model_name):
    
    #ytest_labels = np.argmax(cat_ytrue, axis=1)
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
        
    ytrue, ypred = cat_ytrue, ypred_prob
    n_classes = num_class
    
    fpr = {}
    tpr = {}
    roc_auc = {}
    
    #check if ypred contains any nan. 
    #If nan then the model intrinsically not suitable (i.e. MLP with too few layers)
    checknan = np.isnan(ypred).any()
    if checknan: return 
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = metrics.roc_curve(ytrue[:, i], ypred[:, i]) 
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])
        
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = metrics.roc_curve(ytrue.ravel(), ypred.ravel())
    roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])
    
    
    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    lw = 2
    plt.figure()
    plt.plot(fpr["micro"], tpr["micro"],
             label='micro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["micro"]),
             color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
             label='macro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["macro"]),
             color='navy', linestyle=':', linewidth=4)

    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'darkviolet'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(i, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(model_name +'ROC curve')
    plt.legend(loc="lower right")
    plt.savefig('ROC' + '_' + model_name + now + '.png')
    plt.show()

# %%
#This function is used for models other than Sequential:

def plot_confusion_matrix(cat_ytrue, ypred_prob, model_name):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    #convert category and prob matrix to single value labels
    ypred_labels = np.argmax(ypred_prob, axis=1)
    ytest_labels = np.argmax(cat_ytrue, axis=1)
        
    ytrue, ypred = ytest_labels, ypred_labels
    

    cm = confusion_matrix(ytrue, ypred)
    
    plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(model_name + 'Confusion matrix')
    plt.colorbar()
    
    fmt = 'd' 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('CM' + '_' + model_name + now + '.png')
    plt.show()
    
    #return cm

# %%
def confusion_matrix_per_fold(cat_ytrue, ypred_prob):
    
    #convert category and prob matrix to single value labels
    ypred_labels = np.argmax(ypred_prob, axis=1)
    ytest_labels = np.argmax(cat_ytrue, axis=1)
        
    ytrue, ypred = ytest_labels, ypred_labels
    

    cm = confusion_matrix(ytrue, ypred)
    
    #plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    #plt.title('Confusion matrix per fold')
    #plt.colorbar()
    
    #fmt = 'd' 
    #thresh = cm.max() / 2.
    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    #    plt.text(j, i, format(cm[i, j], fmt),
    #             horizontalalignment="center",
    #             color="white" if cm[i, j] > thresh else "black")
    #plt.ylabel('True label')
    #plt.xlabel('Predicted label')
    #plt.show()
    
    return cm

# %%
def plot_avg_confusion_matrix_across_folds(cm_sum, cv_folds, model_name):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    avg_cm = np.multiply(cm_sum, 1/cv_folds)
    
    #convert to int
    cm = avg_cm.astype(int)
    
    
    
    plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('MLP Avg Confusion matrix across all folds')
    plt.colorbar()
    
    fmt = 'd' 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('CM' + '_' + model_name + now + '.png')
    plt.show()

# %%
# this is for sequential model
def plot_learning_curve(history, fold_no, model_idx):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy (per fold)')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('MLP learning_curve' + '_' + 'model'+ str(model_idx) + '_'+ now + '_'+'fold' + 'fold_no'+'.png')
    plt.show()

# %%
def plot_avg_learning_curve(avg_train_history, avg_val_history,model_idx, ylabel):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    plt.plot(avg_train_history)
    plt.plot(avg_val_history)
    plt.ylabel(ylabel)
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('MLP learning_curve' + '_' + 'model'+ str(model_idx) + '_'+ now +'.png')
    plt.show()

# %%
def plot_avg_learning_curves_all_models(learning_curve_dict_all_models, ylabel):
    
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    #colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'darkviolet'])
    linestyle=cycle(['-', '--', ':', '-.'])
    lw = 2
    
    if ylabel == 'accuracy':
            
        for key, linestyle in zip(learning_curve_dict_all_models, linestyle):
        
            avg_history_train_acc = learning_curve_dict_all_models[key]['avg_history_train_acc'] 
            avg_history_val_acc = learning_curve_dict_all_models[key]['avg_history_val_acc'] 
        
            plt.plot(avg_history_train_acc, lw=lw, linestyle = linestyle,
                     label='training acc of MLP para set {}'.format(key))
            plt.plot(avg_history_val_acc, lw=lw, linestyle = linestyle,
                     label='val acc of MLP para set {}'.format(key))

        plt.ylim([0.0, 1.05])
        plt.xlabel('epoch')
        plt.ylabel(ylabel)
        plt.title('MLP' +'learning curve all models')
        plt.legend(loc="lower right")
        plt.savefig('Learningcurve' + '_' + now + '.png')
        plt.show()
    
    #plot loss curve
    elif ylabel == 'loss':
        
        for key, linestyle in zip(learning_curve_dict_all_models, linestyle):
 
            avg_history_train_loss = learning_curve_dict_all_models[key]['avg_history_train_loss'] 
            avg_history_val_loss = learning_curve_dict_all_models[key]['avg_history_val_loss'] 
        
            plt.plot(avg_history_train_loss, lw=lw, linestyle = linestyle,
                     label='training loss of MLP para set {}'.format(key))
            plt.plot(avg_history_val_loss, lw=lw, linestyle = linestyle,
                     label='val loss of MLP para set {}'.format(key))

        plt.ylim([0.0, 1.05])
        plt.xlabel('epoch')
        plt.ylabel(ylabel)
        plt.title('MLP' +'loss curve all models')
        plt.legend(loc="lower right")
        plt.savefig('Losscurve' + '_' + now + '.png')
        plt.show()
        
    else:
        return

# %%
def save_model_to_disk(model, filename):
    #pickle.dump(model, open(filename, 'wb'))
    with open(filename, 'wb') as file:
        pickle.dump(model, file)

# %%
#68 feature contents (from image), corresponding label (from csv), the image name where dlib cannot extract features
landmark_features, label_contents, no_features_sets = B1_extract.extract_features_labels(image_folder, label_name)

# %%
#number of unique classes to be predicted
num_class = len(np.unique(label_contents))

# %%
tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y  = split_data(landmark_features, label_contents, split_ratio)

# %%
# Logistic regression may not be approporiate since sklearn LR by default does not support multi-labe classification 
# Skip instead
#Logclf, LR_pseudo_test_score = LogReg_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, LogReg_tuned_parameters, cvfold)

# %%
# SVM result:
SVMclf, SVM_pseudo_test_score = SVC_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, SVM_tuned_parameters, cvfold, num_class)
# Out:
# -------------------------------------------------
# SVC Grid search CV on Dataset A:
#
# Training scores:
#
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.596 (+/-0.002) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.596 (+/-0.002) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.596 (+/-0.002) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.596 (+/-0.002) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.737 (+/-0.005) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.737 (+/-0.005) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.283 (+/-0.021) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.737 (+/-0.005) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# 0.420 (+/-0.010) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.737 (+/-0.005) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
# 0.444 (+/-0.005) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.771 (+/-0.006) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.470 (+/-0.020) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.771 (+/-0.006) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.423 (+/-0.012) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.611 (+/-0.011) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.771 (+/-0.006) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.543 (+/-0.012) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.213 (+/-0.001) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.771 (+/-0.006) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.266 (+/-0.009) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.470 (+/-0.012) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.777 (+/-0.006) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.423 (+/-0.013) for {'C': 1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.682 (+/-0.006) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.777 (+/-0.006) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.593 (+/-0.008) for {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.857 (+/-0.007) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.777 (+/-0.006) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.402 (+/-0.016) for {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 1.000 (+/-0.000) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.777 (+/-0.006) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.265 (+/-0.014) for {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.666 (+/-0.006) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.776 (+/-0.010) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.596 (+/-0.003) for {'C': 10, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.813 (+/-0.003) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.776 (+/-0.010) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.677 (+/-0.019) for {'C': 10, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.986 (+/-0.002) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.776 (+/-0.010) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
# 0.387 (+/-0.020) for {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 1.000 (+/-0.000) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.776 (+/-0.010) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
# 0.269 (+/-0.020) for {'C': 10, 'gamma': 0.1, 'kernel': 'sigmoid'}
#
# Validation scores:
#
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.586 (+/-0.024) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.586 (+/-0.024) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.586 (+/-0.024) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.586 (+/-0.024) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.721 (+/-0.016) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.721 (+/-0.016) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.280 (+/-0.024) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.721 (+/-0.016) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# 0.419 (+/-0.017) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.213 (+/-0.000) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.721 (+/-0.016) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
# 0.450 (+/-0.028) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.212 (+/-0.001) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.743 (+/-0.017) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.213 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.463 (+/-0.010) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.743 (+/-0.017) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.422 (+/-0.019) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.562 (+/-0.026) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.743 (+/-0.017) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.545 (+/-0.013) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.213 (+/-0.001) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.743 (+/-0.017) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.286 (+/-0.024) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.461 (+/-0.016) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.728 (+/-0.015) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.422 (+/-0.016) for {'C': 1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.658 (+/-0.014) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.728 (+/-0.015) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.581 (+/-0.017) for {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.715 (+/-0.026) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.728 (+/-0.015) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.405 (+/-0.029) for {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.523 (+/-0.021) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.728 (+/-0.015) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.283 (+/-0.024) for {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.652 (+/-0.017) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.714 (+/-0.011) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.588 (+/-0.023) for {'C': 10, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.757 (+/-0.027) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.714 (+/-0.011) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.668 (+/-0.026) for {'C': 10, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.736 (+/-0.024) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.714 (+/-0.011) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
# 0.390 (+/-0.034) for {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.538 (+/-0.025) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.714 (+/-0.011) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
# 0.284 (+/-0.035) for {'C': 10, 'gamma': 0.1, 'kernel': 'sigmoid'}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78       383
#            1       0.73      0.69      0.71       362
#            2       0.71      0.82      0.76       410
#            3       0.77      0.73      0.75       401
#            4       0.80      0.82      0.81       398
#
#     accuracy                           0.76      1954
#    macro avg       0.77      0.76      0.76      1954
# weighted avg       0.77      0.76      0.76      1954
#
# Accuracy: 0.7645854657113613
#
# Best parameters found on Dataset A:
#
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Average runtime per test instance: 0.001293848578493085
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# Random Forest result:
RFclf, RF_pseudo_test_score, RF_importance_indices = RF_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, RF_tuned_parameters, cvfold, num_class)
# Out:
# -------------------------------------------------
# RF Grid search CV on Dataset A:
#
# Training scores:
#
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 1024}
#
# Validation scores:
#
# 0.707 (+/-0.031) for {'max_depth': 64, 'n_estimators': 64}
# 0.710 (+/-0.021) for {'max_depth': 64, 'n_estimators': 128}
# 0.716 (+/-0.026) for {'max_depth': 64, 'n_estimators': 256}
# 0.715 (+/-0.022) for {'max_depth': 64, 'n_estimators': 512}
# 0.718 (+/-0.029) for {'max_depth': 64, 'n_estimators': 1024}
# 0.704 (+/-0.022) for {'max_depth': 128, 'n_estimators': 64}
# 0.716 (+/-0.023) for {'max_depth': 128, 'n_estimators': 128}
# 0.713 (+/-0.033) for {'max_depth': 128, 'n_estimators': 256}
# 0.719 (+/-0.022) for {'max_depth': 128, 'n_estimators': 512}
# 0.717 (+/-0.029) for {'max_depth': 128, 'n_estimators': 1024}
# 0.704 (+/-0.019) for {'max_depth': 256, 'n_estimators': 64}
# 0.719 (+/-0.030) for {'max_depth': 256, 'n_estimators': 128}
# 0.716 (+/-0.025) for {'max_depth': 256, 'n_estimators': 256}
# 0.722 (+/-0.026) for {'max_depth': 256, 'n_estimators': 512}
# 0.719 (+/-0.019) for {'max_depth': 256, 'n_estimators': 1024}
# 0.708 (+/-0.027) for {'max_depth': 512, 'n_estimators': 64}
# 0.711 (+/-0.024) for {'max_depth': 512, 'n_estimators': 128}
# 0.715 (+/-0.026) for {'max_depth': 512, 'n_estimators': 256}
# 0.717 (+/-0.023) for {'max_depth': 512, 'n_estimators': 512}
# 0.720 (+/-0.028) for {'max_depth': 512, 'n_estimators': 1024}
# 0.704 (+/-0.017) for {'max_depth': 1024, 'n_estimators': 64}
# 0.714 (+/-0.031) for {'max_depth': 1024, 'n_estimators': 128}
# 0.715 (+/-0.030) for {'max_depth': 1024, 'n_estimators': 256}
# 0.718 (+/-0.026) for {'max_depth': 1024, 'n_estimators': 512}
# 0.719 (+/-0.019) for {'max_depth': 1024, 'n_estimators': 1024}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75       383
#            1       0.73      0.62      0.67       362
#            2       0.67      0.82      0.73       410
#            3       0.68      0.72      0.70       401
#            4       0.82      0.83      0.82       398
#
#     accuracy                           0.74      1954
#    macro avg       0.74      0.73      0.73      1954
# weighted avg       0.74      0.74      0.74      1954
#
# Accuracy: 0.7364380757420675
#
# Best parameters found on Dataset A:
#
# {'max_depth': 256, 'n_estimators': 512}
#
# Average runtime per test instance: 0.0002641217857446739
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# KNN result:

KNNclf, KNN_pseudo_test_score = KNN_Grid_search_Prediction_CV(tr_X, tr_Y, te_X, te_Y, KNN_tuned_parameters, cvfold, num_class)
# Out:
# -------------------------------------------------
# KNN Grid search CV on Dataset A:
#
# Training scores:
#
# 0.642 (+/-0.009) for {'n_neighbors': 8}
# 0.603 (+/-0.008) for {'n_neighbors': 16}
# 0.573 (+/-0.009) for {'n_neighbors': 32}
# 0.546 (+/-0.006) for {'n_neighbors': 64}
# 0.530 (+/-0.009) for {'n_neighbors': 128}
#
# Validation scores:
#
# 0.495 (+/-0.032) for {'n_neighbors': 8}
# 0.506 (+/-0.021) for {'n_neighbors': 16}
# 0.505 (+/-0.010) for {'n_neighbors': 32}
# 0.499 (+/-0.022) for {'n_neighbors': 64}
# 0.502 (+/-0.008) for {'n_neighbors': 128}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#            0       0.48      0.48      0.48       383
#            1       0.36      0.41      0.38       362
#            2       0.54      0.64      0.58       410
#            3       0.44      0.41      0.43       401
#            4       0.78      0.59      0.67       398
#
#     accuracy                           0.51      1954
#    macro avg       0.52      0.50      0.51      1954
# weighted avg       0.52      0.51      0.51      1954
#
# Accuracy: 0.5076765609007164
#
# Best parameters found on Dataset A:
#
# {'n_neighbors': 16}
#
# Average runtime per test instance: 0.003254457042307546
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:30: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
Seqmodel, Seq_pseudo_test_score = Sequential_Prediction_GridSearch_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)
# Out:
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 2176)              298112
# _________________________________________________________________
# dense_47 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_48 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_50 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4688 samples, validate on 1173 samples
# Epoch 1/50
# 4688/4688 [==============================] - 6s 1ms/step - loss: 2.1416 - accuracy: 0.2803 - val_loss: 1.4609 - val_accuracy: 0.3546
# Epoch 2/50
# 4688/4688 [==============================] - 3s 565us/step - loss: 1.3157 - accuracy: 0.4405 - val_loss: 1.2610 - val_accuracy: 0.4382
# Epoch 3/50
# 4688/4688 [==============================] - 2s 472us/step - loss: 1.1628 - accuracy: 0.5128 - val_loss: 1.0181 - val_accuracy: 0.5754
# Epoch 4/50
# 4688/4688 [==============================] - 2s 524us/step - loss: 1.0470 - accuracy: 0.5774 - val_loss: 0.9075 - val_accuracy: 0.6547
# Epoch 5/50
# 4688/4688 [==============================] - 2s 441us/step - loss: 0.9327 - accuracy: 0.6293 - val_loss: 1.1449 - val_accuracy: 0.5064
# Epoch 6/50
# 4688/4688 [==============================] - 2s 461us/step - loss: 0.9451 - accuracy: 0.6237 - val_loss: 0.9465 - val_accuracy: 0.5763
# Epoch 7/50
# 4688/4688 [==============================] - 2s 504us/step - loss: 0.8886 - accuracy: 0.6457 - val_loss: 0.7827 - val_accuracy: 0.6931
# Epoch 8/50
# 4688/4688 [==============================] - 2s 445us/step - loss: 0.8486 - accuracy: 0.6724 - val_loss: 0.8519 - val_accuracy: 0.6769
# Epoch 9/50
# Epoch 48/50
# 4688/4688 [==============================] - 2s 476us/step - loss: 0.3453 - accuracy: 0.8767 - val_loss: 0.7381 - val_accuracy: 0.7843
# Epoch 49/50
# 4688/4688 [==============================] - 2s 448us/step - loss: 0.2415 - accuracy: 0.9061 - val_loss: 0.8640 - val_accuracy: 0.7698
# Epoch 50/50
# 4688/4688 [==============================] - 2s 443us/step - loss: 0.2951 - accuracy: 0.8942 - val_loss: 1.0001 - val_accuracy: 0.6701
# 1954/1954 [==============================] - 0s 220us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 2 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_51 (Dense)             (None, 2176)              298112
# _________________________________________________________________
# dense_52 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_53 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_54 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/50
# 4689/4689 [==============================] - 5s 983us/step - loss: 2.2721 - accuracy: 0.2668 - val_loss: 1.5236 - val_accuracy: 0.3592
# Epoch 2/50
# 4689/4689 [==============================] - 3s 539us/step - loss: 1.3174 - accuracy: 0.4395 - val_loss: 1.5169 - val_accuracy: 0.4181
# Epoch 3/50
# 4689/4689 [==============================] - 2s 526us/step - loss: 1.2217 - accuracy: 0.5120 - val_loss: 1.3560 - val_accuracy: 0.4369
# Epoch 4/50
# 4689/4689 [==============================] - 3s 549us/step - loss: 1.0969 - accuracy: 0.5577 - val_loss: 1.0446 - val_accuracy: 0.5589
# Epoch 5/50
# 4689/4689 [==============================] - 2s 456us/step - loss: 0.9913 - accuracy: 0.5939 - val_loss: 1.3963 - val_accuracy: 0.5307
# Epoch 6/50
# 4689/4689 [==============================] - 2s 476us/step - loss: 0.9804 - accuracy: 0.6185 - val_loss: 1.3019 - val_accuracy: 0.5546
# Epoch 7/50
# 4689/4689 [==============================] - 3s 538us/step - loss: 1.0195 - accuracy: 0.5944 - val_loss: 0.9539 - val_accuracy: 0.6323
# Epoch 8/50
# 4689/4689 [==============================] - 2s 507us/step - loss: 0.8355 - accuracy: 0.6748 - val_loss: 1.0497 - val_accuracy: 0.6229
# Epoch 9/50
# 4689/4689 [==============================] - 3s 543us/step - loss: 0.8461 - accuracy: 0.6679 - val_loss: 1.0887 - val_accuracy: 0.6212
# Epoch 10/50
# 4689/4689 [==============================] - 2s 479us/step - loss: 0.8411 - accuracy: 0.6771 - val_loss: 1.1365 - val_accuracy: 0.6049
# Epoch 11/50
# 4689/4689 [==============================] - 2s 478us/step - loss: 0.8254 - accuracy: 0.6827 - val_loss: 0.9608 - val_accuracy: 0.6357
# Epoch 12/50
# 4689/4689 [==============================] - 2s 467us/step - loss: 0.7482 - accuracy: 0.7134 - val_loss: 0.8127 - val_accuracy: 0.7039
# Epoch 13/50
# 4689/4689 [==============================] - 2s 509us/step - loss: 0.7367 - accuracy: 0.7100 - val_loss: 0.8557 - val_accuracy: 0.6843
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_58 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/50
# 4689/4689 [==============================] - 4s 930us/step - loss: 2.1925 - accuracy: 0.2527 - val_loss: 1.4877 - val_accuracy: 0.3157
# Epoch 2/50
# 4689/4689 [==============================] - 3s 581us/step - loss: 1.3421 - accuracy: 0.4308 - val_loss: 1.3150 - val_accuracy: 0.4488
# Epoch 3/50
# 4689/4689 [==============================] - 3s 578us/step - loss: 1.1626 - accuracy: 0.5042 - val_loss: 1.3746 - val_accuracy: 0.4906
# Epoch 4/50
# 4689/4689 [==============================] - 2s 487us/step - loss: 1.1208 - accuracy: 0.5517 - val_loss: 1.1127 - val_accuracy: 0.5427
# Epoch 5/50
# 4689/4689 [==============================] - 2s 463us/step - loss: 0.9729 - accuracy: 0.6099 - val_loss: 1.0333 - val_accuracy: 0.6451
# Epoch 6/50
# 4689/4689 [==============================] - 2s 469us/step - loss: 1.0046 - accuracy: 0.6097 - val_loss: 1.1963 - val_accuracy: 0.5026
# Epoch 7/50
# 4689/4689 [==============================] - 2s 462us/step - loss: 0.8993 - accuracy: 0.6421 - val_loss: 1.4651 - val_accuracy: 0.5017
# Epoch 8/50
# 4689/4689 [==============================] - 2s 462us/step - loss: 0.9348 - accuracy: 0.6426 - val_loss: 1.0297 - val_accuracy: 0.5887
# Epoch 9/50
# 4689/4689 [==============================] - 2s 483us/step - loss: 0.8560 - accuracy: 0.6613 - val_loss: 0.9002 - val_accuracy: 0.6502
# Epoch 10/50
# 4689/4689 [==============================] - 3s 596us/step - loss: 0.8283 - accuracy: 0.6716 - val_loss: 1.0572 - val_accuracy: 0.6425
# Epoch 11/50
# 4689/4689 [==============================] - 2s 510us/step - loss: 0.7787 - accuracy: 0.6978 - val_loss: 1.1613 - val_accuracy: 0.4966
# Epoch 12/50
# 4689/4689 [==============================] - 2s 468us/step - loss: 0.7949 - accuracy: 0.6812 - val_loss: 0.9748 - val_accuracy: 0.6203
# Epoch 13/50
# 4689/4689 [==============================] - 2s 469us/step - loss: 0.7666 - accuracy: 0.7006 - val_loss: 0.8568 - val_accuracy: 0.6741
# Epoch 14/50
# 4689/4689 [==============================] - 2s 477us/step - loss: 0.7136 - accuracy: 0.7223 - val_loss: 1.1804 - val_accuracy: 0.6263
# Epoch 15/50
# 4689/4689 [==============================] - 2s 457us/step - loss: 0.7292 - accuracy: 0.7196 - val_loss: 0.8458 - val_accuracy: 0.6843
# Epoch 16/50
# 4689/4689 [==============================] - 2s 461us/step - loss: 0.7167 - accuracy: 0.7221 - val_loss: 0.9878 - val_accuracy: 0.6391
# Epoch 17/50
# 4689/4689 [==============================] - 2s 514us/step - loss: 0.6950 - accuracy: 0.7274 - val_loss: 1.1015 - val_accuracy: 0.6903
# Epoch 18/50
# 4689/4689 [==============================] - 3s 533us/step - loss: 0.5006 - accuracy: 0.8070 - val_loss: 0.8709 - val_accuracy: 0.7039
# Epoch 38/50
# 4689/4689 [==============================] - 2s 476us/step - loss: 0.4713 - accuracy: 0.8172 - val_loss: 0.7327 - val_accuracy: 0.7312
# Epoch 39/50
# 4689/4689 [==============================] - 2s 473us/step - loss: 0.4488 - accuracy: 0.8279 - val_loss: 1.0052 - val_accuracy: 0.7005
# Epoch 40/50
# 4689/4689 [==============================] - 2s 470us/step - loss: 0.4970 - accuracy: 0.8123 - val_loss: 0.7906 - val_accuracy: 0.7278
# Epoch 41/50
# 4689/4689 [==============================] - 2s 468us/step - loss: 0.4397 - accuracy: 0.8281 - val_loss: 0.7530 - val_accuracy: 0.7509
# Epoch 42/50
# 4689/4689 [==============================] - 2s 469us/step - loss: 0.4721 - accuracy: 0.8290 - val_loss: 1.3291 - val_accuracy: 0.6749
# Epoch 43/50
# 4689/4689 [==============================] - 2s 461us/step - loss: 0.4680 - accuracy: 0.8332 - val_loss: 0.9224 - val_accuracy: 0.7338
# Epoch 44/50
# 4689/4689 [==============================] - 2s 484us/step - loss: 0.4322 - accuracy: 0.8394 - val_loss: 0.7342 - val_accuracy: 0.7449
# Epoch 45/50
# 4689/4689 [==============================] - 2s 468us/step - loss: 0.4600 - accuracy: 0.8311 - val_loss: 0.7775 - val_accuracy: 0.7321
# Epoch 46/50
# 4689/4689 [==============================] - 2s 532us/step - loss: 0.3751 - accuracy: 0.8578 - val_loss: 0.8035 - val_accuracy: 0.7321
# Epoch 47/50
# 4689/4689 [==============================] - 2s 469us/step - loss: 0.3789 - accuracy: 0.8560 - val_loss: 1.0794 - val_accuracy: 0.6519
# Epoch 48/50
# 4689/4689 [==============================] - 2s 468us/step - loss: 0.4006 - accuracy: 0.8439 - val_loss: 0.9809 - val_accuracy: 0.6860
# Epoch 49/50
# 4689/4689 [==============================] - 2s 466us/step - loss: 0.4025 - accuracy: 0.8492 - val_loss: 0.8384 - val_accuracy: 0.7449
# Epoch 50/50
# 4689/4689 [==============================] - 2s 472us/step - loss: 0.3299 - accuracy: 0.8693 - val_loss: 0.8580 - val_accuracy: 0.7491
# 1954/1954 [==============================] - 0s 229us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 4 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_61 (Dense)             (None, 2176)              298112
# _________________________________________________________________
# dense_62 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_63 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/50
# 4689/4689 [==============================] - 4s 920us/step - loss: 2.3632 - accuracy: 0.2749 - val_loss: 1.6370 - val_accuracy: 0.3464
# Epoch 2/50
# 4689/4689 [==============================] - 3s 539us/step - loss: 1.2866 - accuracy: 0.4726 - val_loss: 1.3136 - val_accuracy: 0.4522
# Epoch 3/50
# Epoch 42/50
# 4689/4689 [==============================] - 2s 509us/step - loss: 0.4672 - accuracy: 0.8247 - val_loss: 0.9492 - val_accuracy: 0.6860
# Epoch 43/50
# 4689/4689 [==============================] - 2s 480us/step - loss: 0.4105 - accuracy: 0.8398 - val_loss: 0.7690 - val_accuracy: 0.7167
# Epoch 44/50
# 4689/4689 [==============================] - 3s 542us/step - loss: 0.4438 - accuracy: 0.8241 - val_loss: 0.6763 - val_accuracy: 0.7739
# Epoch 45/50
# 4689/4689 [==============================] - 2s 477us/step - loss: 0.3752 - accuracy: 0.8537 - val_loss: 0.6853 - val_accuracy: 0.7654
# Epoch 46/50
# 4689/4689 [==============================] - 2s 495us/step - loss: 0.3609 - accuracy: 0.8618 - val_loss: 1.0982 - val_accuracy: 0.7372
# Epoch 47/50
# 4689/4689 [==============================] - 2s 510us/step - loss: 0.4454 - accuracy: 0.8507 - val_loss: 0.7156 - val_accuracy: 0.7551
# Epoch 48/50
# 4689/4689 [==============================] - 2s 503us/step - loss: 0.3689 - accuracy: 0.8603 - val_loss: 0.6844 - val_accuracy: 0.7645
# Epoch 49/50
# 4689/4689 [==============================] - 2s 478us/step - loss: 0.3521 - accuracy: 0.8627 - val_loss: 0.7231 - val_accuracy: 0.7671
# Epoch 50/50
# 4689/4689 [==============================] - 2s 514us/step - loss: 0.3573 - accuracy: 0.8669 - val_loss: 0.7722 - val_accuracy: 0.7551
# 1954/1954 [==============================] - 0s 186us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 5 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 2176)              298112
# _________________________________________________________________
# dense_67 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_68 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/50
# 4689/4689 [==============================] - 4s 895us/step - loss: 2.5091 - accuracy: 0.2634 - val_loss: 1.7098 - val_accuracy: 0.3063
# Epoch 2/50
# 4689/4689 [==============================] - 3s 536us/step - loss: 1.3273 - accuracy: 0.4604 - val_loss: 1.1751 - val_accuracy: 0.5068
# Epoch 3/50
# 4689/4689 [==============================] - 2s 492us/step - loss: 1.1899 - accuracy: 0.5234 - val_loss: 1.2484 - val_accuracy: 0.4744
# Epoch 4/50
# 4689/4689 [==============================] - 2s 478us/step - loss: 1.0474 - accuracy: 0.5779 - val_loss: 1.3092 - val_accuracy: 0.4838
# Epoch 5/50
# 4689/4689 [==============================] - 3s 633us/step - loss: 1.0600 - accuracy: 0.5799 - val_loss: 1.5347 - val_accuracy: 0.4940
# Epoch 6/50
# 4689/4689 [==============================] - 3s 537us/step - loss: 0.9981 - accuracy: 0.6163 - val_loss: 1.2028 - val_accuracy: 0.4974
# Epoch 7/50
# 4689/4689 [==============================] - 3s 609us/step - loss: 0.9187 - accuracy: 0.6383 - val_loss: 1.1671 - val_accuracy: 0.6041
# 4689/4689 [==============================] - 2s 440us/step - loss: 0.3455 - accuracy: 0.8633 - val_loss: 1.0971 - val_accuracy: 0.7398
# Epoch 47/50
# 4689/4689 [==============================] - 2s 442us/step - loss: 0.3455 - accuracy: 0.8740 - val_loss: 0.8152 - val_accuracy: 0.7500
# Epoch 48/50
# 4689/4689 [==============================] - 2s 442us/step - loss: 0.3655 - accuracy: 0.8646 - val_loss: 1.3452 - val_accuracy: 0.6630
# Epoch 49/50
# 4689/4689 [==============================] - 2s 440us/step - loss: 0.4087 - accuracy: 0.8635 - val_loss: 1.2847 - val_accuracy: 0.7150
# Epoch 50/50
# 4689/4689 [==============================] - 2s 440us/step - loss: 0.3764 - accuracy: 0.8744 - val_loss: 1.1192 - val_accuracy: 0.7406
# 1954/1954 [==============================] - 0s 191us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.7320368528366089 (+- 0.04453475028905758)
# > Loss: 0.9785256784794157
# > Avg runtime per test instance: 0.0006414400030426993
# ------------------------------------------------------------------------
# ########################################
#
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Adding layer 4:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_71 (Dense)             (None, 4352)              596224
# _________________________________________________________________
# dense_72 (Dense)             (None, 2176)              9472128
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 2176)              0
# _________________________________________________________________
# dense_73 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_74 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 272)               148240
# ...
# Epoch 12/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.9017 - accuracy: 0.6545 - val_loss: 1.5828 - val_accuracy: 0.5145
# Epoch 13/50
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.9683 - accuracy: 0.6564 - val_loss: 1.2359 - val_accuracy: 0.6246
# Epoch 14/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.8915 - accuracy: 0.6650 - val_loss: 1.1811 - val_accuracy: 0.5853
# Epoch 15/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.8524 - accuracy: 0.6765 - val_loss: 0.8049 - val_accuracy: 0.7108
# Epoch 16/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.8461 - accuracy: 0.6786 - val_loss: 0.7157 - val_accuracy: 0.7253
# Epoch 17/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.7782 - accuracy: 0.7083 - val_loss: 1.1326 - val_accuracy: 0.6237
# Epoch 18/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.8661 - accuracy: 0.6801 - val_loss: 0.9866 - val_accuracy: 0.6451
# Epoch 19/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.7846 - accuracy: 0.7100 - val_loss: 0.7742 - val_accuracy: 0.7022
# Epoch 20/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.7972 - accuracy: 0.6963 - val_loss: 1.1213 - val_accuracy: 0.5956
# Epoch 21/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.7781 - accuracy: 0.7053 - val_loss: 1.2583 - val_accuracy: 0.5964
# Epoch 22/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.7706 - accuracy: 0.7166 - val_loss: 0.9647 - val_accuracy: 0.6587
# Epoch 23/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.7949 - accuracy: 0.6942 - val_loss: 0.9454 - val_accuracy: 0.6323
# Epoch 24/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.7048 - accuracy: 0.7294 - val_loss: 0.6972 - val_accuracy: 0.7389
# Epoch 25/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.6806 - accuracy: 0.7462 - val_loss: 0.8079 - val_accuracy: 0.7389
# Epoch 26/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.7279 - accuracy: 0.7309 - val_loss: 0.8114 - val_accuracy: 0.7210
# Epoch 27/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.6792 - accuracy: 0.7445 - val_loss: 0.9627 - val_accuracy: 0.6937
# Epoch 28/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.6967 - accuracy: 0.7471 - val_loss: 0.6772 - val_accuracy: 0.7381
# Epoch 29/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.6764 - accuracy: 0.7364 - val_loss: 1.1858 - val_accuracy: 0.6297
# Epoch 30/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6973 - accuracy: 0.7409 - val_loss: 0.7868 - val_accuracy: 0.7363
# Epoch 31/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6729 - accuracy: 0.7558 - val_loss: 0.9758 - val_accuracy: 0.6118
# Epoch 32/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6552 - accuracy: 0.7454 - val_loss: 0.7509 - val_accuracy: 0.7415
# Epoch 33/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.6563 - accuracy: 0.7603 - val_loss: 0.8391 - val_accuracy: 0.7406
# Epoch 34/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.6126 - accuracy: 0.7765 - val_loss: 0.6504 - val_accuracy: 0.7713
# Epoch 35/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5912 - accuracy: 0.7771 - val_loss: 1.1354 - val_accuracy: 0.6834
# Epoch 36/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.6712 - accuracy: 0.7588 - val_loss: 0.8570 - val_accuracy: 0.6724
# Epoch 37/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5873 - accuracy: 0.7791 - val_loss: 0.9254 - val_accuracy: 0.6860
# Epoch 38/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.5792 - accuracy: 0.7756 - val_loss: 0.7146 - val_accuracy: 0.7730
# Epoch 39/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5884 - accuracy: 0.7806 - val_loss: 0.6503 - val_accuracy: 0.7534
# Epoch 40/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.6132 - accuracy: 0.7654 - val_loss: 0.8417 - val_accuracy: 0.7022
# Epoch 41/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5626 - accuracy: 0.7878 - val_loss: 0.6871 - val_accuracy: 0.7423
# Epoch 42/50
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.5112 - accuracy: 0.8021 - val_loss: 0.8743 - val_accuracy: 0.7611
# Epoch 43/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.5571 - accuracy: 0.7948 - val_loss: 0.7690 - val_accuracy: 0.7534
# Epoch 44/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5706 - accuracy: 0.7739 - val_loss: 0.6416 - val_accuracy: 0.7585
# Epoch 45/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5210 - accuracy: 0.7963 - val_loss: 1.1589 - val_accuracy: 0.7099
# Epoch 46/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5644 - accuracy: 0.7936 - val_loss: 0.7518 - val_accuracy: 0.7457
# Epoch 47/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.5237 - accuracy: 0.7931 - val_loss: 0.8227 - val_accuracy: 0.7466
# Epoch 48/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.5391 - accuracy: 0.7925 - val_loss: 0.7109 - val_accuracy: 0.7688
# Epoch 49/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.5054 - accuracy: 0.8051 - val_loss: 0.6676 - val_accuracy: 0.7594
# Epoch 50/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.5752 - accuracy: 0.7872 - val_loss: 0.6897 - val_accuracy: 0.7543
# 1954/1954 [==============================] - 1s 455us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 5 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Adding layer 4:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_95 (Dense)             (None, 4352)              596224
# _________________________________________________________________
# dense_96 (Dense)             (None, 2176)              9472128
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 2176)              0
# _________________________________________________________________
# dense_97 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_98 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_99 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_100 (Dense)            (None, 5)                 1365
# =================================================================
# Total params: 13,178,949
# Trainable params: 13,178,949
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/50
# 4689/4689 [==============================] - 10s 2ms/step - loss: 4.1492 - accuracy: 0.2122 - val_loss: 2.3710 - val_accuracy: 0.1852
# Epoch 2/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 1.7777 - accuracy: 0.1973 - val_loss: 1.8684 - val_accuracy: 0.2005
# Epoch 3/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 1.7013 - accuracy: 0.2286 - val_loss: 2.0236 - val_accuracy: 0.2184
# Epoch 4/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 1.6342 - accuracy: 0.3169 - val_loss: 1.5702 - val_accuracy: 0.3055
# Epoch 5/50
# 4689/4689 [==============================] - 7s 2ms/step - loss: 1.4288 - accuracy: 0.4084 - val_loss: 1.2040 - val_accuracy: 0.5307
# Epoch 6/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 1.2563 - accuracy: 0.4681 - val_loss: 1.3703 - val_accuracy: 0.4940
# Epoch 7/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 1.1654 - accuracy: 0.5165 - val_loss: 1.5676 - val_accuracy: 0.3200
# Epoch 8/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.1111 - accuracy: 0.5376 - val_loss: 1.3505 - val_accuracy: 0.4232
# Epoch 9/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 1.1082 - accuracy: 0.5513 - val_loss: 1.8236 - val_accuracy: 0.3635
# Epoch 10/50
# 4689/4689 [==============================] - 8s 2ms/step - loss: 1.0506 - accuracy: 0.5884 - val_loss: 1.3593 - val_accuracy: 0.5811
# Epoch 11/50
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.9705 - accuracy: 0.6251 - val_loss: 1.5343 - val_accuracy: 0.4428
# Epoch 12/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.9917 - accuracy: 0.6157 - val_loss: 0.9699 - val_accuracy: 0.6254
# Epoch 13/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.9626 - accuracy: 0.6261 - val_loss: 1.0168 - val_accuracy: 0.6203
# Epoch 14/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.9015 - accuracy: 0.6413 - val_loss: 0.9725 - val_accuracy: 0.5785
# Epoch 15/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.8446 - accuracy: 0.6707 - val_loss: 1.4449 - val_accuracy: 0.5478
# Epoch 16/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.9645 - accuracy: 0.6434 - val_loss: 1.1182 - val_accuracy: 0.5666
# Epoch 17/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.8642 - accuracy: 0.6605 - val_loss: 0.8725 - val_accuracy: 0.6425
# Epoch 18/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.8036 - accuracy: 0.6839 - val_loss: 0.8320 - val_accuracy: 0.6681
# Epoch 19/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.7927 - accuracy: 0.6903 - val_loss: 0.9961 - val_accuracy: 0.7031
# Epoch 20/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.9421 - accuracy: 0.6607 - val_loss: 1.5040 - val_accuracy: 0.5922
# Epoch 21/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.8654 - accuracy: 0.6959 - val_loss: 1.0561 - val_accuracy: 0.6570
# Epoch 22/50
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.7601 - accuracy: 0.7125 - val_loss: 0.8153 - val_accuracy: 0.6869
# Epoch 23/50
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0
/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.7322415590286255 (+- 0.029017703080534384)
# > Loss: 0.8578536524459291
# > Avg runtime per test instance: 0.001393441216850476
# ------------------------------------------------------------------------
# ########################################
# Opt model parameter found on the pseudo test set:
#
# {'num_hidden_layer': 4, 'hidden_layer_activation': ['relu', 'tanh', 'relu', 'tanh'], 'dropout': [0.5, 0.25, 0.125, 0.0625], 'last_activation': 'softmax'}
#
# Best average pseudo test set accuracy score with the opt model: 0.7322415590286255
# Average runtime per test instance: 0.001393441216850476

# %%
#save models
save_model_to_disk(SVMclf, "TaskB1_SVMclf.sav")

save_model_to_disk(RFclf, "TaskB1_RFclf.sav")

save_model_to_disk(KNNclf, "TaskB1_KNNclf.sav")

save_model_to_disk(Seqmodel, "TaskB1_Seqclf.sav")

# %%
save_model_to_disk(SVMclf, "TaskB1_SVMclf.pkl")

save_model_to_disk(RFclf, "TaskB1_RFclf.pkl")

save_model_to_disk(KNNclf, "TaskB1_KNNclf.pkl")

save_model_to_disk(Seqmodel, "TaskB1_Seqclf.pkl")

# %%
save_model_to_disk(landmark_features, "TaskB1_landmark_features.pickle")
save_model_to_disk(label_contents, "TaskB1_label_contents.pickle")
save_model_to_disk(no_features_sets, "TaskB1_no_features_sets.pickle")

# %%
with open('B1_preprocessed_data/TaskB1_landmark_features.pickle', 'rb') as f:
    landmark_features = pickle.load(f)

with open('B1_preprocessed_data/TaskB1_label_contents.pickle', 'rb') as f:
    label_contents = pickle.load(f)

    
#number of unique classes to be predicted
num_class = len(np.unique(label_contents))
    
tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y  = split_data(landmark_features, label_contents, split_ratio)

#learning curve
LCSeqmodel, LCSeq_pseudo_test_score = Sequential_Prediction_GridSearch_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)
# Out:
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 2176)              298112
# _________________________________________________________________
# dense_57 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_58 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4688 samples, validate on 1173 samples
# Epoch 1/100
# 4688/4688 [==============================] - 4s 886us/step - loss: 2.2594 - accuracy: 0.2651 - val_loss: 1.4230 - val_accuracy: 0.4416
# Epoch 2/100
# 4688/4688 [==============================] - 2s 458us/step - loss: 1.3043 - accuracy: 0.4552 - val_loss: 1.1408 - val_accuracy: 0.5575
# Epoch 3/100
# 4688/4688 [==============================] - 3s 574us/step - loss: 1.1486 - accuracy: 0.5375 - val_loss: 1.2468 - val_accuracy: 0.4288
# Epoch 4/100
# 4688/4688 [==============================] - 3s 593us/step - loss: 1.0386 - accuracy: 0.5702 - val_loss: 0.9421 - val_accuracy: 0.6573
# Epoch 5/100
# 4688/4688 [==============================] - 3s 541us/step - loss: 1.0038 - accuracy: 0.6011 - val_loss: 1.0687 - val_accuracy: 0.5806
# Epoch 6/100
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/100
# 4689/4689 [==============================] - 4s 750us/step - loss: 2.2437 - accuracy: 0.2796 - val_loss: 1.7520 - val_accuracy: 0.3063
# Epoch 2/100
# 4689/4689 [==============================] - 2s 438us/step - loss: 1.3073 - accuracy: 0.4630 - val_loss: 1.8479 - val_accuracy: 0.3643
# Epoch 3/100
# 4689/4689 [==============================] - 2s 436us/step - loss: 1.2377 - accuracy: 0.5191 - val_loss: 1.1561 - val_accuracy: 0.5000
# Epoch 4/100
# 4689/4689 [==============================] - 2s 438us/step - loss: 1.0353 - accuracy: 0.5694 - val_loss: 1.2494 - val_accuracy: 0.4821
# Epoch 5/100
# 4689/4689 [==============================] - 2s 442us/step - loss: 1.0170 - accuracy: 0.5848 - val_loss: 0.9976 - val_accuracy: 0.6109
# Epoch 6/100
# 4689/4689 [==============================] - 2s 478us/step - loss: 0.9629 - accuracy: 0.6089 - val_loss: 1.3944 - val_accuracy: 0.5205
# Epoch 7/100
# 4689/4689 [==============================] - 2s 460us/step - loss: 0.9151 - accuracy: 0.6494 - val_loss: 1.6512 - val_accuracy: 0.5341
# Epoch 8/100
# 4689/4689 [==============================] - 2s 444us/step - loss: 0.9418 - accuracy: 0.6509 - val_loss: 1.0609 - val_accuracy: 0.6485
# Epoch 9/100
# 4689/4689 [==============================] - 2s 454us/step - loss: 0.8998 - accuracy: 0.6530 - val_loss: 1.0443 - val_accuracy: 0.6109
# Epoch 10/100
# 4689/4689 [==============================] - 2s 444us/step - loss: 0.7920 - accuracy: 0.7008 - val_loss: 0.9670 - val_accuracy: 0.6203
# Epoch 11/100
# 4689/4689 [==============================] - 2s 479us/step - loss: 0.7959 - accuracy: 0.6965 - val_loss: 1.1565 - val_accuracy: 0.5998
# Epoch 12/100
# 4689/4689 [==============================] - 2s 470us/step - loss: 0.7818 - accuracy: 0.6993 - val_loss: 0.7841 - val_accuracy: 0.6945
# Epoch 13/100
# 4689/4689 [==============================] - 2s 436us/step - loss: 0.7001 - accuracy: 0.7272 - val_loss: 1.1952 - val_accuracy: 0.5708
# Epoch 14/100
# 4689/4689 [==============================] - 2s 446us/step - loss: 0.7127 - accuracy: 0.7302 - val_loss: 1.0526 - val_accuracy: 0.6596
# Epoch 15/100
# 4689/4689 [==============================] - 2s 437us/step - loss: 0.7362 - accuracy: 0.7172 - val_loss: 1.1709 - val_accuracy: 0.6596
# Epoch 16/100
# 4689/4689 [==============================] - 2s 438us/step - loss: 0.7277 - accuracy: 0.7228 - val_loss: 1.3297 - val_accuracy: 0.6502
# Epoch 17/100
# 4689/4689 [==============================] - 2s 438us/step - loss: 0.6904 - accuracy: 0.7462 - val_loss: 0.7163 - val_accuracy: 0.7312
# Epoch 18/100
# 4689/4689 [==============================] - 2s 473us/step - loss: 0.2179 - accuracy: 0.9251 - val_loss: 1.0500 - val_accuracy: 0.7585
# Epoch 96/100
# 4689/4689 [==============================] - 2s 459us/step - loss: 0.1138 - accuracy: 0.9561 - val_loss: 1.1418 - val_accuracy: 0.7688
# Epoch 97/100
# 4689/4689 [==============================] - 2s 455us/step - loss: 0.1795 - accuracy: 0.9382 - val_loss: 1.3594 - val_accuracy: 0.6920
# Epoch 98/100
# 4689/4689 [==============================] - 2s 454us/step - loss: 0.1886 - accuracy: 0.9324 - val_loss: 1.1145 - val_accuracy: 0.7662
# Epoch 99/100
# 4689/4689 [==============================] - 2s 496us/step - loss: 0.1469 - accuracy: 0.9454 - val_loss: 1.1948 - val_accuracy: 0.7585
# Epoch 100/100
# 4689/4689 [==============================] - 2s 463us/step - loss: 0.1764 - accuracy: 0.9354 - val_loss: 1.0801 - val_accuracy: 0.7363
# 1954/1954 [==============================] - 0s 208us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 3 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 2176)              298112
# _________________________________________________________________
# dense_67 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_68 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 5)                 1365
# =================================================================
# Total params: 3,408,709
# Trainable params: 3,408,709
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/100
# 4689/4689 [==============================] - 4s 813us/step - loss: 2.4646 - accuracy: 0.2553 - val_loss: 1.7758 - val_accuracy: 0.3080
# Epoch 2/100
# 4689/4689 [==============================] - 2s 450us/step - loss: 1.3849 - accuracy: 0.4195 - val_loss: 1.4012 - val_accuracy: 0.4104
# Epoch 3/100
# 4689/4689 [==============================] - 2s 449us/step - loss: 1.1897 - accuracy: 0.5120 - val_loss: 1.6305 - val_accuracy: 0.4804
# Epoch 4/100
# 4689/4689 [==============================] - 2s 451us/step - loss: 1.1023 - accuracy: 0.5575 - val_loss: 1.5249 - val_accuracy: 0.5009
# Epoch 5/100
# 4689/4689 [==============================] - 2s 453us/step - loss: 1.0714 - accuracy: 0.5782 - val_loss: 1.6015 - val_accuracy: 0.5640
# Epoch 6/100
# 4689/4689 [==============================] - 2s 489us/step - loss: 1.0082 - accuracy: 0.6176 - val_loss: 1.3445 - val_accuracy: 0.5179
# Epoch 7/100
# 4689/4689 [==============================] - 2s 455us/step - loss: 0.9598 - accuracy: 0.6270 - val_loss: 1.2123 - val_accuracy: 0.5717
# Epoch 8/100
# 4689/4689 [==============================] - 2s 452us/step - loss: 0.9056 - accuracy: 0.6434 - val_loss: 1.0026 - val_accuracy: 0.6365
# Epoch 9/100
# 4689/4689 [==============================] - 2s 447us/step - loss: 0.8888 - accuracy: 0.6490 - val_loss: 0.7888 - val_accuracy: 0.7133
# Epoch 10/100
# 4689/4689 [==============================] - 2s 473us/step - loss: 0.7930 - accuracy: 0.6839 - val_loss: 1.2615 - val_accuracy: 0.6032
# Epoch 11/100
# Epoch 69/100
# 4689/4689 [==============================] - 3s 577us/step - loss: 0.3526 - accuracy: 0.8705 - val_loss: 0.8087 - val_accuracy: 0.7227
# Epoch 70/100
# 4689/4689 [==============================] - 3s 593us/step - loss: 0.2317 - accuracy: 0.9132 - val_loss: 0.8166 - val_accuracy: 0.7705
# Epoch 71/100
# 4689/4689 [==============================] - 3s 539us/step - loss: 0.2148 - accuracy: 0.9147 - val_loss: 0.7779 - val_accuracy: 0.7884
# Epoch 72/100
# 4689/4689 [==============================] - 2s 476us/step - loss: 0.2438 - accuracy: 0.9106 - val_loss: 1.1415 - val_accuracy: 0.7201
# Epoch 73/100
# 4689/4689 [==============================] - 2s 466us/step - loss: 0.2605 - accuracy: 0.9077 - val_loss: 0.8021 - val_accuracy: 0.7679
# Epoch 74/100
# 4689/4689 [==============================] - 2s 463us/step - loss: 0.2082 - accuracy: 0.9181 - val_loss: 1.1365 - val_accuracy: 0.7585
# Epoch 75/100
# 4689/4689 [==============================] - 2s 472us/step - loss: 0.2470 - accuracy: 0.9070 - val_loss: 0.8143 - val_accuracy: 0.7816
# Epoch 76/100
# 4689/4689 [==============================] - 2s 492us/step - loss: 0.2074 - accuracy: 0.9271 - val_loss: 1.0629 - val_accuracy: 0.7381
# Epoch 77/100
# 4689/4689 [==============================] - 2s 459us/step - loss: 0.1998 - accuracy: 0.9264 - val_loss: 1.3419 - val_accuracy: 0.7423
# Epoch 78/100
# 4689/4689 [==============================] - 2s 511us/step - loss: 0.3073 - accuracy: 0.8902 - val_loss: 0.9549 - val_accuracy: 0.7799
# Epoch 79/100
# 4689/4689 [==============================] - 2s 494us/step - loss: 0.1715 - accuracy: 0.9339 - val_loss: 0.8143 - val_accuracy: 0.7875
# Epoch 80/100
# 4689/4689 [==============================] - 3s 604us/step - loss: 0.3188 - accuracy: 0.8993 - val_loss: 0.7528 - val_accuracy: 0.7645
# Epoch 81/100
# 4689/4689 [==============================] - 2s 477us/step - loss: 0.1859 - accuracy: 0.9332 - val_loss: 0.9500 - val_accuracy: 0.7568
# Epoch 82/100
# 4689/4689 [==============================] - 2s 477us/step - loss: 0.2268 - accuracy: 0.9170 - val_loss: 1.0949 - val_accuracy: 0.7560
# Epoch 83/100
# 4689/4689 [==============================] - 2s 477us/step - loss: 0.2318 - accuracy: 0.9192 - val_loss: 0.8881 - val_accuracy: 0.7765
# Epoch 84/100
# 4689/4689 [==============================] - 2s 511us/step - loss: 0.1718 - accuracy: 0.9354 - val_loss: 1.0538 - val_accuracy: 0.7713
# Epoch 85/100
# 4689/4689 [==============================] - 2s 501us/step - loss: 0.2139 - accuracy: 0.9224 - val_loss: 0.9784 - val_accuracy: 0.7790
# Epoch 86/100
# 4689/4689 [==============================] - 2s 490us/step - loss: 0.3041 - accuracy: 0.8961 - val_loss: 1.0089 - val_accuracy: 0.7474
# Epoch 87/100
# 4689/4689 [==============================] - 2s 484us/step - loss: 0.1975 - accuracy: 0.9320 - val_loss: 1.0286 - val_accuracy: 0.7713
# Epoch 88/100
# ...
# dropout_70 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_110 (Dense)            (None, 5)                 1365
# =================================================================
# Total params: 13,178,949
# Trainable params: 13,178,949
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4689 samples, validate on 1172 samples
# Epoch 1/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 4.2370 - accuracy: 0.2077 - val_loss: 2.2659 - val_accuracy: 0.2039
# Epoch 2/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.7296 - accuracy: 0.2265 - val_loss: 1.9858 - val_accuracy: 0.1826
# Epoch 3/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.6434 - accuracy: 0.3028 - val_loss: 1.5497 - val_accuracy: 0.3805
# Epoch 4/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.3477 - accuracy: 0.4348 - val_loss: 1.4486 - val_accuracy: 0.4599
# Epoch 5/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.2344 - accuracy: 0.4833 - val_loss: 1.7016 - val_accuracy: 0.4727
# Epoch 6/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.2911 - accuracy: 0.4816 - val_loss: 1.2804 - val_accuracy: 0.4770
# Epoch 7/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.1023 - accuracy: 0.5566 - val_loss: 0.9928 - val_accuracy: 0.6007
# Epoch 8/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 1.0082 - accuracy: 0.5809 - val_loss: 1.0861 - val_accuracy: 0.5623
# Epoch 9/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.9487 - accuracy: 0.6212 - val_loss: 1.5631 - val_accuracy: 0.5034
# Epoch 10/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 1.1468 - accuracy: 0.5856 - val_loss: 0.9845 - val_accuracy: 0.6186
# Epoch 11/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.9524 - accuracy: 0.6276 - val_loss: 1.8144 - val_accuracy: 0.4317
# Epoch 12/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 1.0111 - accuracy: 0.6180 - val_loss: 1.1496 - val_accuracy: 0.5657
# Epoch 13/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.9327 - accuracy: 0.6276 - val_loss: 1.2047 - val_accuracy: 0.5913
# Epoch 14/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.9196 - accuracy: 0.6475 - val_loss: 0.8631 - val_accuracy: 0.6792
# Epoch 15/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.8685 - accuracy: 0.6613 - val_loss: 1.4884 - val_accuracy: 0.5580
# Epoch 16/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.9051 - accuracy: 0.6613 - val_loss: 0.8178 - val_accuracy: 0.6894
# Epoch 17/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.7548 - accuracy: 0.7038 - val_loss: 1.1968 - val_accuracy: 0.6101
# Epoch 18/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.8466 - accuracy: 0.6805 - val_loss: 1.3187 - val_accuracy: 0.5981
# Epoch 19/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.8205 - accuracy: 0.7108 - val_loss: 0.9783 - val_accuracy: 0.6596
# Epoch 20/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.8434 - accuracy: 0.6763 - val_loss: 0.7604 - val_accuracy: 0.7244
# Epoch 21/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.7391 - accuracy: 0.7225 - val_loss: 1.0433 - val_accuracy: 0.6621
# Epoch 22/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.8553 - accuracy: 0.6769 - val_loss: 1.0214 - val_accuracy: 0.6783
# Epoch 23/100
# 4689/4689 [==============================] - 10s 2ms/step - loss: 0.7899 - accuracy: 0.7108 - val_loss: 1.1031 - val_accuracy: 0.6544
# Epoch 24/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.7125 - accuracy: 0.7443 - val_loss: 0.7922 - val_accuracy: 0.7176
# Epoch 25/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.7271 - accuracy: 0.7219 - val_loss: 1.1574 - val_accuracy: 0.6775
# Epoch 26/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.7727 - accuracy: 0.7234 - val_loss: 0.8427 - val_accuracy: 0.6749
# Epoch 27/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.7102 - accuracy: 0.7302 - val_loss: 0.8325 - val_accuracy: 0.6903
# Epoch 28/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.6485 - accuracy: 0.7537 - val_loss: 0.7223 - val_accuracy: 0.7338
# Epoch 29/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.6870 - accuracy: 0.7477 - val_loss: 1.1349 - val_accuracy: 0.5913
# Epoch 30/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.7090 - accuracy: 0.7370 - val_loss: 0.7424 - val_accuracy: 0.7381
# Epoch 31/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.6468 - accuracy: 0.7518 - val_loss: 0.7999 - val_accuracy: 0.7270
# Epoch 32/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.6200 - accuracy: 0.7707 - val_loss: 1.0169 - val_accuracy: 0.6493
# Epoch 33/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.6643 - accuracy: 0.7460 - val_loss: 0.9575 - val_accuracy: 0.6852
# Epoch 34/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6743 - accuracy: 0.7494 - val_loss: 0.6946 - val_accuracy: 0.7432
# Epoch 35/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6231 - accuracy: 0.7622 - val_loss: 1.3713 - val_accuracy: 0.6920
# Epoch 36/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.6710 - accuracy: 0.7733 - val_loss: 0.9039 - val_accuracy: 0.6698
# Epoch 37/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6034 - accuracy: 0.7733 - val_loss: 0.6634 - val_accuracy: 0.7602
# Epoch 38/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.5924 - accuracy: 0.7795 - val_loss: 1.2491 - val_accuracy: 0.6843
# Epoch 39/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6617 - accuracy: 0.7705 - val_loss: 1.0748 - val_accuracy: 0.6954
# Epoch 40/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.6118 - accuracy: 0.7771 - val_loss: 1.0924 - val_accuracy: 0.6749
# Epoch 41/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.5873 - accuracy: 0.7887 - val_loss: 0.8880 - val_accuracy: 0.7432
# Epoch 42/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.5718 - accuracy: 0.7846 - val_loss: 0.7739 - val_accuracy: 0.7491
# Epoch 43/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.5967 - accuracy: 0.7746 - val_loss: 0.7800 - val_accuracy: 0.7449
# Epoch 44/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.5513 - accuracy: 0.7861 - val_loss: 0.9700 - val_accuracy: 0.6621
# Epoch 45/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.5566 - accuracy: 0.7863 - val_loss: 1.1656 - val_accuracy: 0.7014
# Epoch 46/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5606 - accuracy: 0.7985 - val_loss: 0.9184 - val_accuracy: 0.7244
# Epoch 47/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.5283 - accuracy: 0.8004 - val_loss: 0.9235 - val_accuracy: 0.7073
# Epoch 48/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.5293 - accuracy: 0.7972 - val_loss: 0.8926 - val_accuracy: 0.7474
# Epoch 49/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.5177 - accuracy: 0.8008 - val_loss: 0.8503 - val_accuracy: 0.7201
# Epoch 50/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.4569 - accuracy: 0.8228 - val_loss: 0.8175 - val_accuracy: 0.7474
# Epoch 51/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.4987 - accuracy: 0.8091 - val_loss: 1.2195 - val_accuracy: 0.6553
# Epoch 52/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.5617 - accuracy: 0.7895 - val_loss: 0.8210 - val_accuracy: 0.7176
# Epoch 53/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.3463 - accuracy: 0.8703 - val_loss: 0.8772 - val_accuracy: 0.7628
# Epoch 85/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.3997 - accuracy: 0.8537 - val_loss: 0.9580 - val_accuracy: 0.7474
# Epoch 86/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.3592 - accuracy: 0.8710 - val_loss: 0.8436 - val_accuracy: 0.7645
# Epoch 87/100
# 4689/4689 [==============================] - 6s 1ms/step - loss: 0.3317 - accuracy: 0.8752 - val_loss: 0.9410 - val_accuracy: 0.7176
# Epoch 88/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.3349 - accuracy: 0.8693 - val_loss: 1.0561 - val_accuracy: 0.7312
# Epoch 89/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.3354 - accuracy: 0.8714 - val_loss: 0.9811 - val_accuracy: 0.7543
# Epoch 90/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.3633 - accuracy: 0.8680 - val_loss: 0.8978 - val_accuracy: 0.7312
# Epoch 91/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.2987 - accuracy: 0.8848 - val_loss: 0.8435 - val_accuracy: 0.7696
# Epoch 92/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.3442 - accuracy: 0.8703 - val_loss: 0.9874 - val_accuracy: 0.7389
# Epoch 93/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.3655 - accuracy: 0.8592 - val_loss: 0.9743 - val_accuracy: 0.7654
# Epoch 94/100
# 4689/4689 [==============================] - 9s 2ms/step - loss: 0.3271 - accuracy: 0.8787 - val_loss: 0.8689 - val_accuracy: 0.7577
# Epoch 95/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.3481 - accuracy: 0.8682 - val_loss: 0.9225 - val_accuracy: 0.7381
# Epoch 96/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.3112 - accuracy: 0.8765 - val_loss: 1.2178 - val_accuracy: 0.7474
# Epoch 97/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.3466 - accuracy: 0.8816 - val_loss: 0.8391 - val_accuracy: 0.7713
# Epoch 98/100
# 4689/4689 [==============================] - 7s 1ms/step - loss: 0.3389 - accuracy: 0.8697 - val_loss: 0.9210 - val_accuracy: 0.7457
# Epoch 99/100
# 4689/4689 [==============================] - 8s 2ms/step - loss: 0.2850 - accuracy: 0.8872 - val_loss: 0.9906 - val_accuracy: 0.7509
# Epoch 100/100
# 4689/4689 [==============================] - 7s 2ms/step - loss: 0.2736 - accuracy: 0.8936 - val_loss: 1.1809 - val_accuracy: 0.7406
# 1954/1954 [==============================] - 1s 459us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.7501535296440125 (+- 0.01025788642511308)
# > Loss: 1.004684346270659
# > Avg runtime per test instance: 0.001315207125098581
# ------------------------------------------------------------------------
# ########################################
# Opt model parameter found on the pseudo test set:
#
# {'num_hidden_layer': 4, 'hidden_layer_activation': ['relu', 'tanh', 'relu', 'tanh'], 'dropout': [0.5, 0.25, 0.125, 0.0625], 'last_activation': 'softmax'}
#
# Best average pseudo test set accuracy score with the opt model: 0.7501535296440125
# Average runtime per test instance: 0.001315207125098581

# %%
#Sequential_Prediction_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)
