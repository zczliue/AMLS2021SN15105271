# %%
# This is the function file for Task A1,
# which assess the performance between different classifiers, 
# by grid search with cross validation, including:

# Logistic Regression
# SVM 
# Random Forest
# KNN
# Squential

# The assessment metrices for classifiers include:
# 1. Accuracy score between ytrue and ypred
# 2. Grid score for grid search tuning
# 


# To use this file, specify:
# 'image_folder' : a string in either 'celeba' or 'cartoon_set'
# 'label_name' :  a string that specifies the feature name, i.e. 'gender', 'smiling' as in labels.csv
# 'tuning_parameters' : a dictionary contains different kernels and settings
# 'cvfold': an int for K-fold cross validation

# return value: trained classifier with best parameter settings

# %%
import os
import tensorflow
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import keras
import sklearn
import cv2
import dlib
#import rewritten lab2 landmarks extraction 
import A1_extract_landmarks as A1_extract
import itertools 
import datetime
import pickle
# Out:
# Using TensorFlow backend.

# %%
from itertools import cycle
from scipy import interp

from sklearn import datasets, metrics, model_selection, svm
from sklearn.utils import shuffle
from sklearn.datasets import load_iris

from sklearn.model_selection import learning_curve
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import roc_curve, auc

from keras.preprocessing import image
from keras.models import Sequential 
from keras.models import Sequential 
from keras.layers import Dense , Dropout 
from keras.optimizers import SGD
from keras.optimizers import RMSprop

# %%
# Set the parameters for Grid search
split_ratio = 0.75
cvfold = 5
image_folder = 'celeba'
label_name   = 'gender'
num_epochs = 50



#SVM
#SVM_tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-2, 1e-1, 1, 10],'C': [0.01, 0.1, 1, 10]}]
#                        {'kernel': ['linear'], 'C': [0.01, 0.1, 1, 10]},
#                        {'kernel':['sigmoid'],'gamma': [1e-2, 1e-1, 1, 10],'C': [0.01, 0.1, 1, 10]}
SVM_tuned_parameters = {'kernel': ['rbf', 'linear', 'sigmoid'],
                        'C': [0.001, 0.01, 0.1, 1, 10],
                        'gamma': [1e-4, 1e-3, 1e-2, 1e-1]}


#Logistic Regression
#LogReg_tuned_parameters = [{ 'solver':['lbfgs'], 'C':[0.01, 0.1, 1, 10]}, 
#                          {'solver':[ 'saga'], 'penalty':['l1'], 'C':[0.01, 0.1, 1, 10]}]

LogReg_tuned_parameters = {'solver':[ 'saga'], 'penalty':['l1', 'l2'], 'C':[1e-4, 1e-3, 1e-2, 1e-1, 1,10]}
                          

#Random Forest
RF_tuned_parameters = [{'n_estimators':[64, 128, 256, 512, 1024], 'max_depth':[64, 128, 256, 512, 1024]}]

#KNN parameter
KNN_tuned_parameters = [{'n_neighbors':[8,16,32,64,128]}]

#MLP parameter
MLP_tuned_parameters = [{'hidden_layer_sizes': [(128,256,128,), (128,256,128,), (128,),(256,),(512,)], 
                         'activation': ['logistic', 'tanh', 'relu'],
                         'learning_rate':['constant', 'adaptive']}]


Squential_model_parameters = [{'num_hidden_layer': 3,
                              'hidden_layer_activation' : ['relu','tanh','relu'],
                              'dropout':[0.5,0.25,0.125],
                              'last_activation':'softmax'},
                              
                              {'num_hidden_layer': 4,
                              'hidden_layer_activation' : ['relu','tanh','relu','tanh'],
                              'dropout':[0.5,0.25,0.125,0.0625],
                              'last_activation':'softmax'}]

# %%
# This function is rewritten as follows:
# the input image_folder must be a string that specifies 'celeba' or 'cartoon_set'
# the input label_name must be a string that specifies the feature name, i.e. 'gender', 'smiling' as in labels.csv

 # This function is rewritten as follows:
# the input image_folder must be a string that specifies 'celeba' or 'cartoon_set'
# the input label_name must be a string that specifies the feature name, i.e. 'gender', 'smiling' as in labels.csv

def split_data(X, y, split_ratio):
    
    X, Y = shuffle(X,y)
    train_X, test_X, train_Y, test_Y = train_test_split(X, Y, train_size=split_ratio)
    
    #reshape into appropriate dimensions
    tr_X = train_X.reshape((train_X.shape[0], train_X.shape[1]*2))
    te_X = test_X.reshape((test_X.shape[0], test_X.shape[1]*2))
    
    
    #normalisation
    x_scaler = StandardScaler()
    tr_X = x_scaler.fit_transform(tr_X)
    te_X = x_scaler.transform(te_X)
    
    #train_Y, test_Y are single valued Y 
    tr_Y = train_Y
    te_Y = test_Y

    
    #convert to category matrix. 
    cat_tr_Y = keras.utils.to_categorical(tr_Y)
    cat_te_Y = keras.utils.to_categorical(te_Y)

    return tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y

# %%
def bulk_runtime_estimation(classifier, xtest):
    
    nsamp = xtest.shape[0]
    start = time.time()
    ypred = classifier.predict(xtest)
    ypred_prob = classifier.predict_proba(xtest)
    bulk_runtime = time.time() - start
    
    #average runtime per instance
    avg_runtime = bulk_runtime/nsamp
    
    return ypred, ypred_prob, bulk_runtime, avg_runtime

# %%
#Prediction with Grid Search Cross validation Logistic Regression
# Compare between L1 or L2 regularization
def LogReg_GridSearch_PredictionCV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold):
    clf = GridSearchCV(LogisticRegression(max_iter=8000), tuning_parameters, cv = cvfold, return_train_score=True)
    clf.fit(xtrain, ytrain)
        
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("Logistic Regression Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'LR')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'LR')
    
    #return best classifier
    return clf.best_estimator_, pseudo_test_score

# %%
#Prediction with Grid search SVC Cross validation
def SVC_GridSearch_PredictionCV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold):
    # classifier
    clf = GridSearchCV(SVC(probability=True), tuning_parameters, cv = cvfold, return_train_score=True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("SVM Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'SVM')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'SVM')
    
    #return best classifier
    return clf.best_estimator_, pseudo_test_score

# %%
def RF_GridSearch_PredictionCV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold):

    clf = GridSearchCV(RandomForestClassifier() , tuning_parameters, cv = cvfold, return_train_score=True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("RF Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    
    #determine important features
    importances = clf.best_estimator_.feature_importances_
    indices = np.argsort(importances)
    plt.title('Feature Importances')
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), [i for i in indices])
    plt.xlabel('Relative Importance')
    plt.show()
    
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'Random Forest')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'Random Forest')

    #return classifier
    return clf.best_estimator_, pseudo_test_score, indices

# %%
def KNN_Grid_search_Prediction_CV(xtrain, ytrain, xtest, ytest, tuning_parameters, cvfold):
    clf = GridSearchCV(KNeighborsClassifier() , tuning_parameters, cv = cvfold, return_train_score = True)
    clf.fit(xtrain, ytrain)
    
    means_train = clf.cv_results_['mean_train_score']
    stds_train  = clf.cv_results_['std_train_score']    
        
    means_val = clf.cv_results_['mean_test_score']
    stds_val = clf.cv_results_['std_test_score'] 
    
    #Prediction on a pseudo test set (split from Dataset A) using the best estimator
    ypred,ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(clf.best_estimator_, xtest)
    ytrue, ypred = ytest, ypred
        
    print()
    print('-------------------------------------------------')
    print("KNN Grid search CV on Dataset A:")
    print()
    print("Training scores:")
    print()
    #print training scores
    for mean, std, params in zip(means_train, stds_train, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    
    #print validation scores
    print("Validation scores:")
    print()
    #print grid search validation table
    for mean, std, params in zip(means_val, stds_val, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
    print()
    

    print("Prediction on a pseudo test set (split from Dataset A):")
    print(classification_report(ytrue, ypred))
    pseudo_test_score = accuracy_score(ytrue, ypred)
    print("Accuracy:", pseudo_test_score)
    print()
    print("Best parameters found on Dataset A:")
    print()
    print(clf.best_params_)
    print()
    print('Average runtime per test instance:', avg_runtime)
    print('-------------------------------------------------')
    print()
    print()
    
    cat_ytrue = keras.utils.to_categorical(ytest)
    # confusion matrix
    plot_confusion_matrix(cat_ytrue, ypred_prob, 'KNN')
    # ROC curve
    plot_ROC_curve(cat_ytrue, ypred_prob, num_class, 'KNN')
    
    #return classifier
    return clf.best_estimator_, pseudo_test_score

# %%
def Sequential_Prediction_GridSearch_CV(xtrain, ytrain, xtest, ytest, grid_parameters, cvfold, num_class, num_epochs):
    
    learning_curve_dict_all_models = {}
    
    acc_all_models = []
    acc_std_all_models = []
    loss_all_models = []
    runtime_mean_all_models = []
    
    all_models = []
    
    #the para combination index in search grid
    model_idx = 0
    
    for model_parameters in grid_parameters:
        
        print()
        
        print('########################################')
        model, acc_mean, acc_std_mean, loss_mean, runtime_mean, learning_curve_dict = Sequential_Prediction_CV(xtrain, ytrain, xtest, ytest, model_parameters, cvfold, num_class, num_epochs, model_idx)
        
        #store returned values for each model
        acc_all_models.append(acc_mean)
        acc_std_all_models.append(acc_std_mean)
        loss_all_models.append(loss_mean)
        runtime_mean_all_models.append(runtime_mean)
        
        all_models.append(model)
        
        #store learning and loss curve
        learning_curve_dict_all_models[model_idx] = learning_curve_dict
        

        print('########################################')
        
        model_idx = model_idx + 1
        
        
       
        
    #find max acc value on pseudo test set and index
    max_acc_value = max(acc_all_models)
    max_acc_value_index = acc_all_models.index(max_acc_value)
    
    
    
    #plot learning and loss curve
    plot_avg_learning_curves_all_models(learning_curve_dict_all_models, 'accuracy')
    plot_avg_learning_curves_all_models(learning_curve_dict_all_models, 'loss')
    
        
        
        
        
    
    print('Opt model parameter found on the pseudo test set:')
    print()
    print(grid_parameters[max_acc_value_index])
    print()
    print('Best average pseudo test set accuracy score with the opt model: {}'.format(max_acc_value))
    print('Average runtime per test instance: {}'.format(runtime_mean_all_models[max_acc_value_index]))
    
    
    
    return all_models[max_acc_value_index], max_acc_value

# %%
def Sequential_Prediction_CV(xtrain, ytrain, xtest, ytest, model_parameters, cvfold, num_class, num_epochs, model_idx):
    
    #a dict to store learning curve and loss curves
    learning_curve_dict = {}
    
    # aggregate inputs and targets
    #inputs = np.concatenate((xtrain, xtest), axis=0)
    #targets = np.concatenate((ytrain, ytest), axis=0)
    inputs  = xtrain
    targets = ytrain
    
    fold_no = 1
    #instead of using GridsearchCV we apply a manual function
    kf = KFold(n_splits=cvfold, random_state=None, shuffle=True)
    #record accuracy and loss per fold
    acc_per_fold  = []
    loss_per_fold = []
    avg_runtime_per_fold = []

    #average history train and val acc across all folds
    avg_history_train_acc = np.zeros(num_epochs)
    avg_history_val_acc = np.zeros(num_epochs)
    avg_history_train_loss = np.zeros(num_epochs)
    avg_history_val_loss = np.zeros(num_epochs)
    
    #an empty array to store confusion matrix every fold
    cm_sum = np.zeros((num_class,num_class))
    
    #input feature shape 
    in_feature_shape = xtrain.shape[1]
    #number of class (labels)
    num_labels = num_class
    
    #kf.split divide inputs and targets into K folds and
    #train_idx, test_idx are the indices for training set and validation set
    for train_idx, test_idx in kf.split(inputs, targets):
        
        print('------------------------------------------------------------------------')
        print('Squential with Kfold CV: ')
        print('Training for fold {} ...'.format(fold_no))
        
        #reconstruct model for each fold
        model = design_sequential_model(model_parameters, in_feature_shape, num_class)

        #
        history = model.fit(inputs[train_idx], targets[train_idx],
                    batch_size=int(xtrain.shape[0]/10),
                    epochs=num_epochs,
                    validation_data=(inputs[test_idx], targets[test_idx]),
                    verbose=1)
        
        
        
        #evaluate pseudo test set (split from Dataset A)
        scores = model.evaluate(xtest, ytest, verbose=1)
                
        acc_per_fold.append(scores[1])
        loss_per_fold.append(scores[0])
        
        
        #save history
        avg_history_train_acc = avg_history_train_acc + history.history['accuracy']
        avg_history_val_acc = avg_history_val_acc + history.history['val_accuracy']
        avg_history_train_loss = avg_history_train_loss + history.history['loss']
        avg_history_val_loss = avg_history_val_loss + history.history['val_loss']
        
        
        #generate predictions
        #ypred = model.predict(xtest)
        #model.predict returns probability
        ypred, ypred_prob, bulk_runtime, avg_runtime = bulk_runtime_estimation(model, xtest)
        
        #convert to single value labels
        #ypred_labels = np.argmax(ypred_prob, axis=1)
        #ytest_labels = np.argmax(ytest, axis=1)
        
        #ytrue, ypred = ytest_labels, ypred_labels
        
        avg_runtime_per_fold.append(avg_runtime)
        
        # confusion matrix 
        #plot_confusion_matrix(ytest, ypred_prob)
        cm_sum = cm_sum + confusion_matrix_per_fold(ytest, ypred_prob)        
        
        # ROC curve
        plot_ROC_curve(ytest, ypred_prob, num_class, 'MLP')
        
        #plot learning curve
        #plot_learning_curve(history, fold_no, model_idx)

        # Increase fold number
        fold_no = fold_no + 1
        
    # == Provide average scores ==
    print()
    mean_acc_per_fold = np.mean(acc_per_fold)
    std_acc_per_fold = np.std(acc_per_fold)
    mean_loss_per_fold = np.mean(loss_per_fold)
    
    mean_runtime_per_fold = np.mean(avg_runtime_per_fold)
    
    
    #plot average confusion matrix
    plot_avg_confusion_matrix_across_folds(cm_sum, cvfold, 'MLP')
    
    
    #plot avg learning curve accross all folds
    avg_history_train_acc = np.multiply(avg_history_train_acc, 1/cvfold)
    avg_history_val_acc = np.multiply(avg_history_val_acc, 1/cvfold)
    avg_history_train_loss = np.multiply(avg_history_train_loss, 1/cvfold)
    avg_history_val_loss = np.multiply(avg_history_val_loss, 1/cvfold)
    
    
    #plot learning curve
    plot_avg_learning_curve(avg_history_train_acc, avg_history_val_acc, model_idx, 'accuracy')
    #plot loss curve
    plot_avg_learning_curve(avg_history_train_loss, avg_history_val_loss, model_idx, 'loss')
    
    
    
    #append into dict
    learning_curve_dict['avg_history_train_acc'] = avg_history_train_acc
    learning_curve_dict['avg_history_val_acc'] = avg_history_val_acc
    learning_curve_dict['avg_history_train_loss'] = avg_history_train_loss
    learning_curve_dict['avg_history_val_loss'] = avg_history_val_loss
    
    
    
    print('Average scores for pesudo test set across all folds:')
    print(f'> Accuracy: {mean_acc_per_fold} (+- {std_acc_per_fold})')
    print(f'> Loss: {mean_loss_per_fold}')
    print(f'> Avg runtime per test instance: {mean_runtime_per_fold}')
    print('------------------------------------------------------------------------')
    
    return model, mean_acc_per_fold, std_acc_per_fold, mean_loss_per_fold, mean_runtime_per_fold, learning_curve_dict

# %%
#design a sequential model according to input parameter grid
#for multiclass the loss function should be category_crossentropy, not binary
def design_sequential_model(params, inshape, num_class):
    
    model = Sequential()
    num_hidden_layer = params['num_hidden_layer']
    
    # initial layer
    # we use 2^(hiddenlayer +1) as the output number of neuron 
    model.add(Dense(inshape*pow(2, num_hidden_layer+1) , input_shape=(inshape,),
                    activation='relu'))
    
    #If user has specify the output neuron at each hidden layer:
    if "hidden_neuron" in params:
        
        # hidden layers
        for i in range(num_hidden_layer):
            print('Adding layer '+str(i+1)+':')
        
            model.add(Dense(params['hidden_neuron'][i], activation=params['hidden_layer_activation'][i]))
            model.add(Dropout(params['dropout'][i]))
            
    
    #default output neuron at each hidden layer: descending at base 2
    else:
                # hidden layers
        for i in range(num_hidden_layer):
            print('Adding layer '+str(i+1)+':')
        
            model.add(Dense(inshape*pow(2, num_hidden_layer - i), activation=params['hidden_layer_activation'][i]))
            model.add(Dropout(params['dropout'][i]))
            
    
    ## final layer
    model.add(Dense(num_class, activation=params['last_activation']))

    model.summary()
    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(),
                  metrics=['accuracy'])
    
    return model

# %%
#credit: https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html#plot-roc-curves-for-the-multilabel-problem

def plot_ROC_curve(cat_ytrue, ypred_prob, num_class, model_name):
    
    #ytest_labels = np.argmax(cat_ytrue, axis=1)
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
        
    ytrue, ypred = cat_ytrue, ypred_prob
    n_classes = num_class
    
    fpr = {}
    tpr = {}
    roc_auc = {}
    
    #check if ypred contains any nan. 
    #If nan then the model intrinsically not suitable (i.e. MLP with too few layers)
    checknan = np.isnan(ypred).any()
    if checknan: return 
    
    for i in range(n_classes):

        
        fpr[i], tpr[i], _ = metrics.roc_curve(ytrue[:, i], ypred[:, i]) 
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])
        

        
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = metrics.roc_curve(ytrue.ravel(), ypred.ravel())
    roc_auc["micro"] = metrics.auc(fpr["micro"], tpr["micro"])
    
    
    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    lw = 2
    plt.figure()
    plt.plot(fpr["micro"], tpr["micro"],
             label='micro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["micro"]),
             color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
             label='macro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["macro"]),
             color='navy', linestyle=':', linewidth=4)

    colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'darkviolet'])
    for i, color in zip(range(n_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=lw,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                 ''.format(i, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(model_name +'ROC curve')
    plt.legend(loc="lower right")
    plt.savefig('ROC' + '_' + model_name + now + '.png')
    plt.show()

# %%
#This function is used for models other than Sequential:

def plot_confusion_matrix(cat_ytrue, ypred_prob, model_name):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    

    
    
    #convert category and prob matrix to single value labels
    ypred_labels = np.argmax(ypred_prob, axis=1)
    ytest_labels = np.argmax(cat_ytrue, axis=1)
        
    ytrue, ypred = ytest_labels, ypred_labels
    

    #print(ypred_labels)
    #print(ypred_prob)
    #print('---------')
    #print(ytest_labels)
    #print(cat_ytrue)
    
    cm = confusion_matrix(ytrue, ypred)
    
    plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(model_name + 'Confusion matrix')
    plt.colorbar()
    
    fmt = 'd' 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('CM' + '_' + model_name + now + '.png')
    plt.show()
    
    #return cm

# %%
def confusion_matrix_per_fold(cat_ytrue, ypred_prob):
    
    #convert category and prob matrix to single value labels
    ypred_labels = np.argmax(ypred_prob, axis=1)
    ytest_labels = np.argmax(cat_ytrue, axis=1)
        
    ytrue, ypred = ytest_labels, ypred_labels
    

    cm = confusion_matrix(ytrue, ypred)
    
    #plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    #plt.title('Confusion matrix per fold')
    #plt.colorbar()
    
    #fmt = 'd' 
    #thresh = cm.max() / 2.
    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    #    plt.text(j, i, format(cm[i, j], fmt),
    #             horizontalalignment="center",
    #             color="white" if cm[i, j] > thresh else "black")
    #plt.ylabel('True label')
    #plt.xlabel('Predicted label')
    #plt.show()
    
    return cm

# %%
def plot_avg_confusion_matrix_across_folds(cm_sum, cv_folds, model_name):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    avg_cm = np.multiply(cm_sum, 1/cv_folds)
    
    #convert to int
    cm = avg_cm.astype(int)
    
    
    
    plt.matshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('MLP Avg Confusion matrix across all folds')
    plt.colorbar()
    
    fmt = 'd' 
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig('CM' + '_' + model_name + now + '.png')
    plt.show()

# %%
# this is for sequential model
def plot_learning_curve(history, fold_no, model_idx):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy (per fold)')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('MLP learning_curve' + '_' + 'model'+ str(model_idx) + '_'+ now + '_'+'fold' + 'fold_no'+'.png')
    plt.show()

# %%
def plot_avg_learning_curve(avg_train_history, avg_val_history,model_idx, ylabel):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    plt.plot(avg_train_history)
    plt.plot(avg_val_history)
    plt.ylabel(ylabel)
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.savefig('MLP learning_curve' + '_' + 'model'+ str(model_idx) + '_'+ now +'.png')
    plt.show()

# %%
def plot_avg_learning_curves_all_models(learning_curve_dict_all_models, ylabel):
    
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    
    #colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'darkgreen', 'darkviolet'])
    linestyle=cycle(['-', '--', ':', '-.'])
    lw = 2
    
    if ylabel == 'accuracy':
            
        for key, linestyle in zip(learning_curve_dict_all_models, linestyle):
        
            avg_history_train_acc = learning_curve_dict_all_models[key]['avg_history_train_acc'] 
            avg_history_val_acc = learning_curve_dict_all_models[key]['avg_history_val_acc'] 
        
            plt.plot(avg_history_train_acc, lw=lw, linestyle = linestyle,
                     label='training acc of MLP para set {}'.format(key))
            plt.plot(avg_history_val_acc, lw=lw, linestyle = linestyle,
                     label='val acc of MLP para set {}'.format(key))

        plt.ylim([0.0, 1.05])
        plt.xlabel('epoch')
        plt.ylabel(ylabel)
        plt.title('MLP' +'learning curve all models')
        plt.legend(loc="lower right")
        plt.savefig('Learningcurve' + '_' + now + '.png')
        plt.show()
    
    #plot loss curve
    elif ylabel == 'loss':
        
        for key, linestyle in zip(learning_curve_dict_all_models, linestyle):
 
            avg_history_train_loss = learning_curve_dict_all_models[key]['avg_history_train_loss'] 
            avg_history_val_loss = learning_curve_dict_all_models[key]['avg_history_val_loss'] 
        
            plt.plot(avg_history_train_loss, lw=lw, linestyle = linestyle,
                     label='training loss of MLP para set {}'.format(key))
            plt.plot(avg_history_val_loss, lw=lw, linestyle = linestyle,
                     label='val loss of MLP para set {}'.format(key))

        plt.ylim([0.0, 1.05])
        plt.xlabel('epoch')
        plt.ylabel(ylabel)
        plt.title('MLP' +'loss curve all models')
        plt.legend(loc="lower right")
        plt.savefig('Losscurve' + '_' + now + '.png')
        plt.show()
        
    else:
        return

# %%
def plot_learning_curves_other(train_scores, valid_scores, model_name):
    
    now = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    train_scores_mean = np.mean(train_scores, axis=1)
    valid_scores_mean = np.mean(valid_scores, axis=1)
    
    plt.figure()    
    plt.grid()
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    plt.plot(train_sizes, valid_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    plt.legend(loc="best")
    plt.xlabel('training examples')
    plt.ylabel('score')
    plt.title('Learningcurve'+ model_name)
    plt.savefig('Learningcurve' + '_' + now + model_name +'.png')
    plt.show()

# %%
def save_model_to_disk(model, filename):
    #pickle.dump(model, open(filename, 'wb'))
    with open(filename, 'wb') as file:
        pickle.dump(model, file)

# %%
#68 feature contents (from image), corresponding label (from csv), the image name where dlib cannot extract features
landmark_features, label_contents, no_features_sets = A1_extract.extract_features_labels(image_folder, label_name)
#number of unique classes to be predicted
num_class = len(np.unique(label_contents))

# %%
tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y  = split_data(landmark_features, label_contents, split_ratio)

# %%
# Logistic regression result:
Logclf, LR_pseudo_test_score = LogReg_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, LogReg_tuned_parameters, cvfold)
# Out:
# -------------------------------------------------
# Logistic Regression Grid search CV on Dataset A:
#
# Training scores:
#
# 0.506 (+/-0.015) for {'C': 0.0001, 'penalty': 'l1', 'solver': 'saga'}
# 0.833 (+/-0.007) for {'C': 0.0001, 'penalty': 'l2', 'solver': 'saga'}
# 0.509 (+/-0.000) for {'C': 0.001, 'penalty': 'l1', 'solver': 'saga'}
# 0.877 (+/-0.005) for {'C': 0.001, 'penalty': 'l2', 'solver': 'saga'}
# 0.860 (+/-0.004) for {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# 0.909 (+/-0.002) for {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}
# 0.920 (+/-0.002) for {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# 0.926 (+/-0.002) for {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}
# 0.932 (+/-0.006) for {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
# 0.932 (+/-0.007) for {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# 0.933 (+/-0.006) for {'C': 10, 'penalty': 'l1', 'solver': 'saga'}
# 0.933 (+/-0.006) for {'C': 10, 'penalty': 'l2', 'solver': 'saga'}
#
# Validation scores:
#
# 0.506 (+/-0.015) for {'C': 0.0001, 'penalty': 'l1', 'solver': 'saga'}
# 0.831 (+/-0.032) for {'C': 0.0001, 'penalty': 'l2', 'solver': 'saga'}
# 0.509 (+/-0.001) for {'C': 0.001, 'penalty': 'l1', 'solver': 'saga'}
# 0.876 (+/-0.013) for {'C': 0.001, 'penalty': 'l2', 'solver': 'saga'}
# 0.858 (+/-0.021) for {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# 0.906 (+/-0.008) for {'C': 0.01, 'penalty': 'l2', 'solver': 'saga'}
# 0.913 (+/-0.013) for {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# 0.918 (+/-0.010) for {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}
# 0.923 (+/-0.014) for {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
# 0.922 (+/-0.013) for {'C': 1, 'penalty': 'l2', 'solver': 'saga'}
# 0.922 (+/-0.013) for {'C': 10, 'penalty': 'l1', 'solver': 'saga'}
# 0.922 (+/-0.014) for {'C': 10, 'penalty': 'l2', 'solver': 'saga'}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.92      0.91       596
#          1.0       0.92      0.90      0.91       604
#
#     accuracy                           0.91      1200
#    macro avg       0.91      0.91      0.91      1200
# weighted avg       0.91      0.91      0.91      1200
#
# Accuracy: 0.9108333333333334
#
# Best parameters found on Dataset A:
#
# {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
#
# Average runtime per test instance: 4.925330479939779e-07
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# SVM result:
SVMclf, SVM_pseudo_test_score = SVC_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, SVM_tuned_parameters, cvfold)
# Out:
# -------------------------------------------------
# SVM Grid search CV on Dataset A:
#
# Training scores:
#
# 0.509 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.895 (+/-0.003) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.509 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.509 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.895 (+/-0.003) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
# 0.509 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.509 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.895 (+/-0.003) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.509 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.509 (+/-0.000) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.895 (+/-0.003) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
# 0.530 (+/-0.008) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.509 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.922 (+/-0.003) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.509 (+/-0.000) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.509 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.922 (+/-0.003) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# 0.509 (+/-0.000) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.705 (+/-0.009) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.922 (+/-0.003) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# 0.822 (+/-0.005) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.509 (+/-0.000) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.922 (+/-0.003) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
# 0.665 (+/-0.020) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.510 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.935 (+/-0.001) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.509 (+/-0.000) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.860 (+/-0.007) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.935 (+/-0.001) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.841 (+/-0.006) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.894 (+/-0.008) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.935 (+/-0.001) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.763 (+/-0.011) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.516 (+/-0.002) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.935 (+/-0.001) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.619 (+/-0.021) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.863 (+/-0.007) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.941 (+/-0.004) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.842 (+/-0.008) for {'C': 1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.907 (+/-0.004) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.941 (+/-0.004) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.892 (+/-0.002) for {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.953 (+/-0.005) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.941 (+/-0.004) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.702 (+/-0.006) for {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 1.000 (+/-0.000) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.941 (+/-0.004) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.617 (+/-0.022) for {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.906 (+/-0.003) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.942 (+/-0.005) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.894 (+/-0.002) for {'C': 10, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.938 (+/-0.002) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.942 (+/-0.005) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.880 (+/-0.024) for {'C': 10, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.993 (+/-0.002) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.942 (+/-0.005) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
# 0.704 (+/-0.030) for {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 1.000 (+/-0.000) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.942 (+/-0.005) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
# 0.618 (+/-0.018) for {'C': 10, 'gamma': 0.1, 'kernel': 'sigmoid'}
#
# Validation scores:
#
# 0.509 (+/-0.001) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.889 (+/-0.011) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.509 (+/-0.001) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.509 (+/-0.001) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.889 (+/-0.011) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'linear'}
# 0.509 (+/-0.001) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.509 (+/-0.001) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.889 (+/-0.011) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'linear'}
# 0.509 (+/-0.001) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.509 (+/-0.001) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.889 (+/-0.011) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'linear'}
# 0.528 (+/-0.003) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.509 (+/-0.001) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.917 (+/-0.007) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.509 (+/-0.001) for {'C': 0.01, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.509 (+/-0.001) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.917 (+/-0.007) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'linear'}
# 0.509 (+/-0.001) for {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.705 (+/-0.010) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.917 (+/-0.007) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'linear'}
# 0.821 (+/-0.029) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.509 (+/-0.001) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.917 (+/-0.007) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'linear'}
# 0.679 (+/-0.021) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.509 (+/-0.001) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.924 (+/-0.010) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.509 (+/-0.001) for {'C': 0.1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.856 (+/-0.030) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.924 (+/-0.010) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.836 (+/-0.025) for {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.871 (+/-0.026) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.924 (+/-0.010) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.769 (+/-0.025) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.512 (+/-0.003) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.924 (+/-0.010) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.627 (+/-0.035) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.858 (+/-0.017) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.922 (+/-0.008) for {'C': 1, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.836 (+/-0.025) for {'C': 1, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.895 (+/-0.013) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.922 (+/-0.008) for {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
# 0.892 (+/-0.015) for {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.903 (+/-0.009) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.922 (+/-0.008) for {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
# 0.718 (+/-0.037) for {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.826 (+/-0.017) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.922 (+/-0.008) for {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
# 0.621 (+/-0.033) for {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.898 (+/-0.011) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.918 (+/-0.008) for {'C': 10, 'gamma': 0.0001, 'kernel': 'linear'}
# 0.888 (+/-0.016) for {'C': 10, 'gamma': 0.0001, 'kernel': 'sigmoid'}
# 0.917 (+/-0.013) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.918 (+/-0.008) for {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
# 0.881 (+/-0.025) for {'C': 10, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.904 (+/-0.016) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.918 (+/-0.008) for {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
# 0.699 (+/-0.038) for {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.830 (+/-0.017) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.918 (+/-0.008) for {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
# 0.623 (+/-0.033) for {'C': 10, 'gamma': 0.1, 'kernel': 'sigmoid'}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.92      0.91       596
#          1.0       0.92      0.91      0.92       604
#
#     accuracy                           0.92      1200
#    macro avg       0.92      0.92      0.91      1200
# weighted avg       0.92      0.92      0.92      1200
#
# Accuracy: 0.915
#
# Best parameters found on Dataset A:
#
# {'C': 0.1, 'gamma': 0.0001, 'kernel': 'linear'}
#
# Average runtime per test instance: 0.00019384582837422688
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# Random Forest result:
RFclf, RF_pseudo_test_score, RF_importance_indices = RF_GridSearch_PredictionCV(tr_X, tr_Y, te_X, te_Y, RF_tuned_parameters, cvfold)
# Out:
# -------------------------------------------------
# RF Grid search CV on Dataset A:
#
# Training scores:
#
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 64, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 128, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 256, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 512, 'n_estimators': 1024}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 64}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 128}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 256}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 512}
# 1.000 (+/-0.000) for {'max_depth': 1024, 'n_estimators': 1024}
#
# Validation scores:
#
# 0.856 (+/-0.010) for {'max_depth': 64, 'n_estimators': 64}
# 0.861 (+/-0.021) for {'max_depth': 64, 'n_estimators': 128}
# 0.861 (+/-0.016) for {'max_depth': 64, 'n_estimators': 256}
# 0.862 (+/-0.016) for {'max_depth': 64, 'n_estimators': 512}
# 0.864 (+/-0.016) for {'max_depth': 64, 'n_estimators': 1024}
# 0.856 (+/-0.017) for {'max_depth': 128, 'n_estimators': 64}
# 0.863 (+/-0.015) for {'max_depth': 128, 'n_estimators': 128}
# 0.862 (+/-0.011) for {'max_depth': 128, 'n_estimators': 256}
# 0.862 (+/-0.019) for {'max_depth': 128, 'n_estimators': 512}
# 0.862 (+/-0.024) for {'max_depth': 128, 'n_estimators': 1024}
# 0.860 (+/-0.019) for {'max_depth': 256, 'n_estimators': 64}
# 0.860 (+/-0.021) for {'max_depth': 256, 'n_estimators': 128}
# 0.862 (+/-0.013) for {'max_depth': 256, 'n_estimators': 256}
# 0.863 (+/-0.017) for {'max_depth': 256, 'n_estimators': 512}
# 0.864 (+/-0.017) for {'max_depth': 256, 'n_estimators': 1024}
# 0.852 (+/-0.016) for {'max_depth': 512, 'n_estimators': 64}
# 0.862 (+/-0.016) for {'max_depth': 512, 'n_estimators': 128}
# 0.864 (+/-0.012) for {'max_depth': 512, 'n_estimators': 256}
# 0.864 (+/-0.013) for {'max_depth': 512, 'n_estimators': 512}
# 0.864 (+/-0.015) for {'max_depth': 512, 'n_estimators': 1024}
# 0.859 (+/-0.023) for {'max_depth': 1024, 'n_estimators': 64}
# 0.861 (+/-0.020) for {'max_depth': 1024, 'n_estimators': 128}
# 0.859 (+/-0.022) for {'max_depth': 1024, 'n_estimators': 256}
# 0.863 (+/-0.015) for {'max_depth': 1024, 'n_estimators': 512}
# 0.863 (+/-0.019) for {'max_depth': 1024, 'n_estimators': 1024}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.89      0.87       596
#          1.0       0.89      0.84      0.86       604
#
#     accuracy                           0.87      1200
#    macro avg       0.87      0.87      0.87      1200
# weighted avg       0.87      0.87      0.87      1200
#
# Accuracy: 0.8666666666666667
#
# Best parameters found on Dataset A:
#
# {'max_depth': 512, 'n_estimators': 256}
#
# Average runtime per test instance: 0.00010508835315704345
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
# KNN result:

KNNclf, KNN_pseudo_test_score = KNN_Grid_search_Prediction_CV(tr_X, tr_Y, te_X, te_Y, KNN_tuned_parameters, cvfold)
# Out:
# -------------------------------------------------
# KNN Grid search CV on Dataset A:
#
# Training scores:
#
# 0.844 (+/-0.016) for {'n_neighbors': 8}
# 0.839 (+/-0.011) for {'n_neighbors': 16}
# 0.831 (+/-0.003) for {'n_neighbors': 32}
# 0.829 (+/-0.010) for {'n_neighbors': 64}
# 0.821 (+/-0.009) for {'n_neighbors': 128}
#
# Validation scores:
#
# 0.799 (+/-0.034) for {'n_neighbors': 8}
# 0.808 (+/-0.037) for {'n_neighbors': 16}
# 0.815 (+/-0.028) for {'n_neighbors': 32}
# 0.816 (+/-0.029) for {'n_neighbors': 64}
# 0.814 (+/-0.025) for {'n_neighbors': 128}
#
# Prediction on a pseudo test set (split from Dataset A):
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.93      0.84       596
#          1.0       0.91      0.72      0.80       604
#
#     accuracy                           0.82      1200
#    macro avg       0.84      0.82      0.82      1200
# weighted avg       0.84      0.82      0.82      1200
#
# Accuracy: 0.8241666666666667
#
# Best parameters found on Dataset A:
#
# {'n_neighbors': 64}
#
# Average runtime per test instance: 0.0016922666629155478
# -------------------------------------------------
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
#Sequential model results:
Seqmodel, Seq_pseudo_test_score = Sequential_Prediction_GridSearch_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)
# Out:
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 2176)              298112
# _________________________________________________________________
# dense_2 (Dense)              (None, 1088)              2368576
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1088)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 544)               592416
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 544)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 272)               148240
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 272)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 546
# =================================================================
# Total params: 3,407,890
# Trainable params: 3,407,890
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 3s 1ms/step - loss: 1.6804 - accuracy: 0.5646 - val_loss: 0.4894 - val_accuracy: 0.7653
# Epoch 2/50
# 2880/2880 [==============================] - 1s 514us/step - loss: 0.4644 - accuracy: 0.7847 - val_loss: 0.3805 - val_accuracy: 0.8375
# Epoch 3/50
# 2880/2880 [==============================] - 1s 512us/step - loss: 0.3222 - accuracy: 0.8604 - val_loss: 0.2752 - val_accuracy: 0.8931
# Epoch 4/50
# 2880/2880 [==============================] - 1s 514us/step - loss: 0.3226 - accuracy: 0.8628 - val_loss: 0.2600 - val_accuracy: 0.9056
# Epoch 5/50
# 2880/2880 [==============================] - 1s 515us/step - loss: 0.2859 - accuracy: 0.8826 - val_loss: 0.2617 - val_accuracy: 0.8861
# Epoch 6/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0.2612 - accuracy: 0.8889 - val_loss: 0.2362 - val_accuracy: 0.9028
# Epoch 7/50
# 2880/2880 [==============================] - 1s 512us/step - loss: 0.2643 - accuracy: 0.8896 - val_loss: 0.2578 - val_accuracy: 0.8958
# Epoch 8/50
# 2880/2880 [==============================] - 1s 513us/step - loss: 0.2380 - accuracy: 0.9111 - val_loss: 0.2352 - val_accuracy: 0.9097
# Epoch 9/50
# 2880/2880 [==============================] - 1s 512us/step - loss: 0.2597 - accuracy: 0.8990 - val_loss: 0.2426 - val_accuracy: 0.9083
# Epoch 10/50
# 2880/2880 [==============================] - 1s 512us/step - loss: 0.2053 - accuracy: 0.9174 - val_loss: 0.2799 - val_accuracy: 0.8958
# Epoch 11/50
# 2880/2880 [==============================] - 1s 521us/step - loss: 0.2556 - accuracy: 0.8976 - val_loss: 0.2213 - val_accuracy: 0.9194
# Epoch 12/50
# 2880/2880 [==============================] - 1s 513us/step - loss: 0.1843 - accuracy: 0.9295 - val_loss: 0.3573 - val_accuracy: 0.8458
# Epoch 13/50
# 2880/2880 [==============================] - 2s 569us/step - loss: 0.2122 - accuracy: 0.9087 - val_loss: 0.2784 - val_accuracy: 0.9028
# Epoch 14/50
# 2880/2880 [==============================] - 2s 546us/step - loss: 0.1866 - accuracy: 0.9247 - val_loss: 0.2569 - val_accuracy: 0.9042
# Epoch 15/50
# 2880/2880 [==============================] - 2s 532us/step - loss: 0.2078 - accuracy: 0.9212 - val_loss: 0.2827 - val_accuracy: 0.8764
# Epoch 16/50
50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1292 - accuracy: 0.9455 - val_loss: 0.3550 - val_accuracy: 0.9194
# Epoch 48/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1096 - accuracy: 0.9566 - val_loss: 0.4281 - val_accuracy: 0.8986
# Epoch 49/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1047 - accuracy: 0.9573 - val_loss: 0.4306 - val_accuracy: 0.9056
# Epoch 50/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1515 - accuracy: 0.9413 - val_loss: 0.3346 - val_accuracy: 0.9222
# 1200/1200 [==============================] - 1s 468us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 5 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Adding layer 4:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_50 (Dense)             (None, 4352)              596224
# _________________________________________________________________
# dense_51 (Dense)             (None, 2176)              9472128
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 2176)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 1088)              2368576
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 1088)              0
# _________________________________________________________________
# dense_53 (Dense)             (None, 544)               592416
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 544)               0
# _________________________________________________________________
# dense_54 (Dense)             (None, 272)               148240
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 272)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 2)                 546
# =================================================================
# Total params: 13,178,130
# Trainable params: 13,178,130
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 6s 2ms/step - loss: 3.2473 - accuracy: 0.5056 - val_loss: 0.7385 - val_accuracy: 0.4903
# Epoch 2/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.6757 - accuracy: 0.5924 - val_loss: 1.0845 - val_accuracy: 0.4903
# Epoch 3/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.6460 - accuracy: 0.7128 - val_loss: 0.3999 - val_accuracy: 0.8514
# Epoch 4/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.4064 - accuracy: 0.8524 - val_loss: 0.3393 - val_accuracy: 0.8583
# Epoch 5/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.3179 - accuracy: 0.8760 - val_loss: 0.5939 - val_accuracy: 0.7944
# Epoch 6/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.3688 - accuracy: 0.8698 - val_loss: 0.3101 - val_accuracy: 0.8694
# Epoch 7/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2974 - accuracy: 0.8847 - val_loss: 0.3649 - val_accuracy: 0.8736
# Epoch 8/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2738 - accuracy: 0.9014 - val_loss: 0.2473 - val_accuracy: 0.9042
# Epoch 9/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.3105 - accuracy: 0.8865 - val_loss: 0.2600 - val_accuracy: 0.9056
# Epoch 10/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2626 - accuracy: 0.9007 - val_loss: 0.4374 - val_accuracy: 0.8653
# Epoch 11/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2413 - accuracy: 0.9125 - val_loss: 0.2361 - val_accuracy: 0.9097
# Epoch 12/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2253 - accuracy: 0.9122 - val_loss: 0.2437 - val_accuracy: 0.9000
# Epoch 13/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.3235 - accuracy: 0.8813 - val_loss: 0.2945 - val_accuracy: 0.8986
# Epoch 14/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2108 - accuracy: 0.9201 - val_loss: 0.2344 - val_accuracy: 0.8903
# Epoch 15/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2365 - accuracy: 0.9111 - val_loss: 0.2104 - val_accuracy: 0.9125
# Epoch 16/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2399 - accuracy: 0.9097 - val_loss: 0.2378 - val_accuracy: 0.8931
# Epoch 17/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1974 - accuracy: 0.9312 - val_loss: 0.2737 - val_accuracy: 0.9097
# Epoch 18/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2240 - accuracy: 0.9156 - val_loss: 0.2301 - val_accuracy: 0.9056
# Epoch 19/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2103 - accuracy: 0.9260 - val_loss: 0.2320 - val_accuracy: 0.9250
# Epoch 20/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1990 - accuracy: 0.9243 - val_loss: 0.3296 - val_accuracy: 0.8542
# Epoch 21/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.
/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.8903333306312561 (+- 0.015675526879875862)
# > Loss: 0.37127765042086447
# > Avg runtime per test instance: 0.0011480089823404948
# ------------------------------------------------------------------------
# ########################################
# Opt model parameter found on the pseudo test set:
#
# {'num_hidden_layer': 3, 'hidden_layer_activation': ['relu', 'tanh', 'relu'], 'dropout': [0.5, 0.25, 0.125], 'last_activation': 'softmax'}
#
# Best average pseudo test set accuracy score with the opt model: 0.8958333373069763
# Average runtime per test instance: 0.0005788950125376384

# %%
#save models
save_model_to_disk(Logclf, "TaskA1_Logclf.sav")
save_model_to_disk(SVMclf, "TaskA1_SVMclf.sav")

save_model_to_disk(RFclf, "TaskA1_RFclf.sav")

save_model_to_disk(KNNclf, "TaskA1_KNNclf.sav")

save_model_to_disk(Seqmodel, "TaskA1_Seqclf.sav")

# %%
save_model_to_disk(Logclf, "TaskA1_Logclf.pkl")
save_model_to_disk(SVMclf, "TaskA1_SVMclf.pkl")

save_model_to_disk(RFclf, "TaskA1_RFclf.pkl")

save_model_to_disk(KNNclf, "TaskA1_KNNclf.pkl")

save_model_to_disk(Seqmodel, "TaskA1_Seqclf.pkl")

# %%
save_model_to_disk(landmark_features, "TaskA1_landmark_features.pickle")
save_model_to_disk(label_contents, "TaskA1_label_contents.pickle")
save_model_to_disk(no_features_sets, "TaskA1_no_features_sets.pickle")

# %%
#learning curve
LCSeqmodel, LCSeq_pseudo_test_score = Sequential_Prediction_GridSearch_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)
# Out:
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_105"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_571 (Dense)            (None, 2176)              298112
# _________________________________________________________________
# dense_572 (Dense)            (None, 1088)              2368576
# _________________________________________________________________
# dropout_363 (Dropout)        (None, 1088)              0
# _________________________________________________________________
# dense_573 (Dense)            (None, 544)               592416
# _________________________________________________________________
# dropout_364 (Dropout)        (None, 544)               0
# _________________________________________________________________
# dense_574 (Dense)            (None, 272)               148240
# _________________________________________________________________
# dropout_365 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_575 (Dense)            (None, 2)                 546
# =================================================================
# Total params: 3,407,890
# Trainable params: 3,407,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 6s 2ms/step - loss: 1.5878 - accuracy: 0.5719 - val_loss: 0.4728 - val_accuracy: 0.8097
# Epoch 2/50
# 2880/2880 [==============================] - 2s 599us/step - loss: 0.4372 - accuracy: 0.8028 - val_loss: 0.3664 - val_accuracy: 0.8292
# Epoch 3/50
# 2880/2880 [==============================] - 2s 640us/step - loss: 0.3428 - accuracy: 0.8503 - val_loss: 0.2903 - val_accuracy: 0.8708
# Epoch 4/50
# 2880/2880 [==============================] - 2s 573us/step - loss: 0.3222 - accuracy: 0.8656 - val_loss: 0.2968 - val_accuracy: 0.8819
# Epoch 5/50
# 2880/2880 [==============================] - 2s 543us/step - loss: 0.2664 - accuracy: 0.8920 - val_loss: 0.3533 - val_accuracy: 0.8486
# Epoch 44/50
# 2880/2880 [==============================] - 2s 544us/step - loss: 0.0943 - accuracy: 0.9615 - val_loss: 0.3315 - val_accuracy: 0.9167
# Epoch 45/50
# 2880/2880 [==============================] - 2s 535us/step - loss: 0.1007 - accuracy: 0.9625 - val_loss: 0.2844 - val_accuracy: 0.8847
# Epoch 46/50
# 2880/2880 [==============================] - 2s 529us/step - loss: 0.0778 - accuracy: 0.9701 - val_loss: 0.4998 - val_accuracy: 0.8903
# Epoch 47/50
# 2880/2880 [==============================] - 2s 545us/step - loss: 0.0839 - accuracy: 0.9608 - val_loss: 0.3604 - val_accuracy: 0.9194
# Epoch 48/50
# 2880/2880 [==============================] - 2s 531us/step - loss: 0.1188 - accuracy: 0.9483 - val_loss: 0.2594 - val_accuracy: 0.9250
# Epoch 49/50
# 2880/2880 [==============================] - 2s 533us/step - loss: 0.0658 - accuracy: 0.9736 - val_loss: 0.3737 - val_accuracy: 0.9181
# Epoch 50/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0.0683 - accuracy: 0.9715 - val_loss: 0.4821 - val_accuracy: 0.9125
# 1200/1200 [==============================] - 0s 279us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 2 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_106"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_576 (Dense)            (None, 2176)              298112
# _________________________________________________________________
# dense_577 (Dense)            (None, 1088)              2368576
# _________________________________________________________________
# dropout_366 (Dropout)        (None, 1088)              0
# _________________________________________________________________
# dense_578 (Dense)            (None, 544)               592416
# _________________________________________________________________
# dropout_367 (Dropout)        (None, 544)               0
# _________________________________________________________________
# dense_579 (Dense)            (None, 272)               148240
# _________________________________________________________________
# dropout_368 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_580 (Dense)            (None, 2)                 546
# =================================================================
# Total params: 3,407,890
# Trainable params: 3,407,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 1.6662 - accuracy: 0.5608 - val_loss: 0.5941 - val_accuracy: 0.6764
# Epoch 2/50
# 2880/2880 [==============================] - 2s 525us/step - loss: 0.4759 - accuracy: 0.7833 - val_loss: 0.5303 - val_accuracy: 0.7528
# Epoch 3/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.3372 - accuracy: 0.8615 - val_loss: 0.3047 - val_accuracy: 0.8653
# Epoch 4/50
# 2880/2880 [==============================] - 2s 524us/step - loss: 0.3172 - accuracy: 0.8684 - val_loss: 0.2931 - val_accuracy: 0.8792
# Epoch 5/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0.2584 - accuracy: 0.8969 - val_loss: 0.2864 - val_accuracy: 0.8819
# Epoch 6/50
# 2880/2880 [==============================] - 2s 524us/step - loss: 0.2734 - accuracy: 0.8813 - val_loss: 0.2854 - val_accuracy: 0.8847
# Epoch 7/50
# 2880/2880 [==============================] - 2s 529us/step - loss: 0.2481 - accuracy: 0.9007 - val_loss: 0.2945 - val_accuracy: 0.8750
# Epoch 8/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.2472 - accuracy: 0.9069 - val_loss: 0.3076 - val_accuracy: 0.8944
# Epoch 9/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.2290 - accuracy: 0.9073 - val_loss: 0.2581 - val_accuracy: 0.9042
# Epoch 10/50
# 2880/2880 [==============================] - 2s 529us/step - loss: 0.2145 - accuracy: 0.9125 - val_loss: 0.2647 - val_accuracy: 0.8944
# Epoch 11/50
# 2880/2880 [==============================] - 2s 529us/step - loss: 0.2191 - accuracy: 0.9115 - val_loss: 0.2624 - val_accuracy: 0.9056
# Epoch 12/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_581 (Dense)            (None, 2176)              298112
# _________________________________________________________________
# dense_582 (Dense)            (None, 1088)              2368576
# _________________________________________________________________
# dropout_369 (Dropout)        (None, 1088)              0
# _________________________________________________________________
# dense_583 (Dense)            (None, 544)               592416
# _________________________________________________________________
# dropout_370 (Dropout)        (None, 544)               0
# _________________________________________________________________
# dense_584 (Dense)            (None, 272)               148240
# _________________________________________________________________
# dropout_371 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_585 (Dense)            (None, 2)                 546
# =================================================================
# Total params: 3,407,890
# Trainable params: 3,407,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 6s 2ms/step - loss: 1.3215 - accuracy: 0.5326 - val_loss: 0.5590 - val_accuracy: 0.8181
# Epoch 2/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.5241 - accuracy: 0.7569 - val_loss: 0.3809 - val_accuracy: 0.8417
# Epoch 3/50
# 2880/2880 [==============================] - 2s 523us/step - loss: 0.3443 - accuracy: 0.8566 - val_loss: 0.3448 - val_accuracy: 0.8625
# Epoch 4/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0.3450 - accuracy: 0.8594 - val_loss: 0.2911 - val_accuracy: 0.8847
# Epoch 5/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.2612 - accuracy: 0.8934 - val_loss: 0.4552 - val_accuracy: 0.8306
# Epoch 6/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.2940 - accuracy: 0.8826 - val_loss: 0.3036 - val_accuracy: 0.8917
# Epoch 7/50
# 2880/2880 [==============================] - 2s 560us/step - loss: 0.2476 - accuracy: 0.9090 - val_loss: 0.3663 - val_accuracy: 0.8431
# Epoch 8/50
# 2880/2880 [==============================] - 2s 545us/step - loss: 0.2400 - accuracy: 0.9003 - val_loss: 0.2725 - val_accuracy: 0.8958
# Epoch 9/50
# 2880/2880 [==============================] - 2s 532us/step - loss: 0.2544 - accuracy: 0.8931 - val_loss: 0.3081 - val_accuracy: 0.8958
# Epoch 10/50
# 2880/2880 [==============================] - 2s 533us/step - loss: 0.2184 - accuracy: 0.9149 - val_loss: 0.3373 - val_accuracy: 0.8597
# Epoch 11/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.2282 - accuracy: 0.9073 - val_loss: 0.2809 - val_accuracy: 0.9000
# Epoch 12/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.2065 - accuracy: 0.9181 - val_loss: 0.2856 - val_accuracy: 0.8847
# Epoch 13/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.1993 - accuracy: 0.9240 - val_loss: 0.2948 - val_accuracy: 0.8875
# Epoch 14/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.1825 - accuracy: 0.9292 - val_loss: 0.2954 - val_accuracy: 0.8722
# Epoch 15/50
# 2880/2880 [==============================] - 2s 539us/step - loss: 0.1736 - accuracy: 0.9340 - val_loss: 0.4364 - val_accuracy: 0.8444
# Epoch 16/50
# 2880/2880 [==============================] - 2s 525us/step - loss: 0.1955 - accuracy: 0.9219 - val_loss: 0.2956 - val_accuracy: 0.8944
# Epoch 17/50
# 2880/2880 [==============================] - 2s 532us/step - loss: 0.1804 - accuracy: 0.9253 - val_loss: 0.2510 - val_accuracy: 0.9153
# Epoch 18/50
# 2880/2880 [==============================] - 2s 525us/step - loss: 0.1690 - accuracy: 0.9319 - val_loss: 0.2704 - val_accuracy: 0.9181
# Epoch 19/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.392954). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.196852). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 2880/2880 [==============================] - 2s 719us/step - loss: 0.0747 - accuracy: 0.9698 - val_loss: 0.5077 - val_accuracy: 0.8917
# Epoch 42/50
# 2880/2880 [==============================] - 2s 551us/step - loss: 0.0962 - accuracy: 0.9608 - val_loss: 0.5051 - val_accuracy: 0.8944
# Epoch 43/50
# 2880/2880 [==============================] - 2s 565us/step - loss: 0.0851 - accuracy: 0.9667 - val_loss: 0.4294 - val_accuracy: 0.9000
# Epoch 44/50
# 2880/2880 [==============================] - 2s 531us/step - loss: 0.1080 - accuracy: 0.9566 - val_loss: 0.3195 - val_accuracy: 0.9125
# Epoch 45/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.0552 - accuracy: 0.9771 - val_loss: 0.4413 - val_accuracy: 0.9028
# Epoch 46/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.0952 - accuracy: 0.9660 - val_loss: 0.6257 - val_accuracy: 0.8486
# Epoch 47/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.1098 - accuracy: 0.9601 - val_loss: 0.5507 - val_accuracy: 0.8694
# Epoch 48/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.0944 - accuracy: 0.9705 - val_loss: 0.3877 - val_accuracy: 0.9139
# Epoch 49/50
# 2880/2880 [==============================] - 2s 529us/step - loss: 0.0817 - accuracy: 0.9722 - val_loss: 0.5175 - val_accuracy: 0.8917
# Epoch 50/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0.0750 - accuracy: 0.9684 - val_loss: 0.4270 - val_accuracy: 0.8917
# 1200/1200 [==============================] - 0s 275us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 4 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Model: "sequential_108"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_586 (Dense)            (None, 2176)              298112
# _________________________________________________________________
# dense_587 (Dense)            (None, 1088)              2368576
# _________________________________________________________________
# dropout_372 (Dropout)        (None, 1088)              0
# _________________________________________________________________
# dense_588 (Dense)            (None, 544)               592416
# _________________________________________________________________
# dropout_373 (Dropout)        (None, 544)               0
# _________________________________________________________________
# dense_589 (Dense)            (None, 272)               148240
# _________________________________________________________________
# dropout_374 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_590 (Dense)            (None, 2)                 546
# =================================================================
# Total params: 3,407,890
# Trainable params: 3,407,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 1.7398 - accuracy: 0.5608 - val_loss: 0.4796 - val_accuracy: 0.7847
# Epoch 2/50
# 2880/2880 [==============================] - 2s 523us/step - loss: 0.4408 - accuracy: 0.8045 - val_loss: 0.2954 - val_accuracy: 0.8861
# Epoch 3/50
# 2880/2880 [==============================] - 2s 524us/step - loss: 0.3353 - accuracy: 0.8583 - val_loss: 0.2694 - val_accuracy: 0.8958
# Epoch 4/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.2803 - accuracy: 0.8906 - val_loss: 0.2818 - val_accuracy: 0.8833
# Epoch 5/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.2753 - accuracy: 0.8875 - val_loss: 0.2856 - val_accuracy: 0.8778
# Epoch 6/50
# 2880/2880 [==============================] - 2s 524us/step - loss: 0.2498 - accuracy: 0.9021 - val_loss: 0.2972 - val_accuracy: 0.8750
# Epoch 7/50
# 2880/2880 [==============================] - 2s 525us/step - loss: 0.2718 - accuracy: 0.8951 - val_loss: 0.3205 - val_accuracy: 0.8764
# Epoch 8/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_591 (Dense)            (None, 2176)              298112
# _________________________________________________________________
# dense_592 (Dense)            (None, 1088)              2368576
# _________________________________________________________________
# dropout_375 (Dropout)        (None, 1088)              0
# _________________________________________________________________
# dense_593 (Dense)            (None, 544)               592416
# _________________________________________________________________
# dropout_376 (Dropout)        (None, 544)               0
# _________________________________________________________________
# dense_594 (Dense)            (None, 272)               148240
# _________________________________________________________________
# dropout_377 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_595 (Dense)            (None, 2)                 546
# =================================================================
# Total params: 3,407,890
# Trainable params: 3,407,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 6s 2ms/step - loss: 2.0969 - accuracy: 0.5538 - val_loss: 0.5893 - val_accuracy: 0.6639
# Epoch 2/50
# 2880/2880 [==============================] - 2s 567us/step - loss: 0.4528 - accuracy: 0.8056 - val_loss: 0.4713 - val_accuracy: 0.7667
# Epoch 3/50
# 2880/2880 [==============================] - 2s 535us/step - loss: 0.3178 - accuracy: 0.8639 - val_loss: 0.2657 - val_accuracy: 0.8958
# Epoch 4/50
# 2880/2880 [==============================] - 2s 542us/step - loss: 0.3326 - accuracy: 0.8562 - val_loss: 0.2619 - val_accuracy: 0.8931
# Epoch 5/50
# 2880/2880 [==============================] - 2s 525us/step - loss: 0.2953 - accuracy: 0.8823 - val_loss: 0.2335 - val_accuracy: 0.9097
# Epoch 6/50
# 2880/2880 [==============================] - 2s 524us/step - loss: 0.2469 - accuracy: 0.9042 - val_loss: 0.3390 - val_accuracy: 0.8514
# Epoch 7/50
# 2880/2880 [==============================] - 2s 525us/step - loss: 0.2976 - accuracy: 0.8799 - val_loss: 0.3318 - val_accuracy: 0.8819
# Epoch 8/50
# 2880/2880 [==============================] - 2s 527us/step - loss: 0.2355 - accuracy: 0.9087 - val_loss: 0.2632 - val_accuracy: 0.8875
# Epoch 9/50
# 2880/2880 [==============================] - 2s 524us/step - loss: 0.2285 - accuracy: 0.9104 - val_loss: 0.3250 - val_accuracy: 0.8722
# Epoch 10/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.2357 - accuracy: 0.9097 - val_loss: 0.2627 - val_accuracy: 0.9000
# Epoch 11/50
# 2880/2880 [==============================] - 2s 522us/step - loss: 0.2193 - accuracy: 0.9187 - val_loss: 0.2453 - val_accuracy: 0.9097
# Epoch 12/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.2303 - accuracy: 0.9142 - val_loss: 0.2859 - val_accuracy: 0.8819
# Epoch 13/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0.2185 - accuracy: 0.9118 - val_loss: 0.2186 - val_accuracy: 0.9125
# Epoch 14/50
# 2880/2880 [==============================] - 2s 529us/step - loss: 0.1921 - accuracy: 0.9257 - val_loss: 0.2436 - val_accuracy: 0.9097
# Epoch 15/50
# 2880/2880 [==============================] - 2s 524us/step - loss: 0.1741 - accuracy: 0.9326 - val_loss: 0.2959 - val_accuracy: 0.9056
# Epoch 16/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0.2001 - accuracy: 0.9191 - val_loss: 0.2393 - val_accuracy: 0.9208
# Epoch 17/50
# 2880/2880 [==============================] - 2s 526us/step - loss: 0.1853 - accuracy: 0.9316 - val_loss: 0.3416 - val_accuracy: 0.8722
# Epoch 18/50
# 2880/2880 [==============================] - 2s 528us/step - loss: 0
# 2880/2880 [==============================] - 2s 536us/step - loss: 0.1339 - accuracy: 0.9521 - val_loss: 0.2588 - val_accuracy: 0.9153
# Epoch 38/50
# 2880/2880 [==============================] - 2s 544us/step - loss: 0.0920 - accuracy: 0.9628 - val_loss: 0.4140 - val_accuracy: 0.8931
# Epoch 39/50
# 2880/2880 [==============================] - 2s 539us/step - loss: 0.1078 - accuracy: 0.9528 - val_loss: 0.5645 - val_accuracy: 0.9042
# Epoch 40/50
# 2880/2880 [==============================] - 2s 539us/step - loss: 0.1057 - accuracy: 0.9615 - val_loss: 0.4060 - val_accuracy: 0.9111
# Epoch 41/50
# 2880/2880 [==============================] - 2s 542us/step - loss: 0.1072 - accuracy: 0.9628 - val_loss: 0.3453 - val_accuracy: 0.9097
# Epoch 42/50
# 2880/2880 [==============================] - 2s 539us/step - loss: 0.1326 - accuracy: 0.9531 - val_loss: 0.2645 - val_accuracy: 0.9153
# Epoch 43/50
# 2880/2880 [==============================] - 2s 539us/step - loss: 0.0913 - accuracy: 0.9656 - val_loss: 0.3166 - val_accuracy: 0.9042
# Epoch 44/50
# 2880/2880 [==============================] - 2s 546us/step - loss: 0.0787 - accuracy: 0.9708 - val_loss: 0.3508 - val_accuracy: 0.8792
# Epoch 45/50
# 2880/2880 [==============================] - 2s 540us/step - loss: 0.1195 - accuracy: 0.9559 - val_loss: 0.2871 - val_accuracy: 0.9167
# Epoch 46/50
# 2880/2880 [==============================] - 2s 536us/step - loss: 0.0657 - accuracy: 0.9726 - val_loss: 0.4272 - val_accuracy: 0.9083
# Epoch 47/50
# 2880/2880 [==============================] - 2s 541us/step - loss: 0.1259 - accuracy: 0.9549 - val_loss: 0.3436 - val_accuracy: 0.9097
# Epoch 48/50
# 2880/2880 [==============================] - 2s 546us/step - loss: 0.0967 - accuracy: 0.9639 - val_loss: 0.2934 - val_accuracy: 0.9056
# Epoch 49/50
# 2880/2880 [==============================] - 2s 535us/step - loss: 0.0653 - accuracy: 0.9733 - val_loss: 0.4341 - val_accuracy: 0.8931
# Epoch 50/50
# 2880/2880 [==============================] - 2s 541us/step - loss: 0.0892 - accuracy: 0.9639 - val_loss: 0.4511 - val_accuracy: 0.8958
# 1200/1200 [==============================] - 0s 288us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.8928333163261414 (+- 0.0072953492520192505)
# > Loss: 0.5054604837521911
# > Avg runtime per test instance: 0.0038374254703521724
# ------------------------------------------------------------------------
# ########################################
#
# ########################################
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 1 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Adding layer 4:
# Model: "sequential_110"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_596 (Dense)            (None, 4352)              596224
# _________________________________________________________________
# dense_597 (Dense)            (None, 2176)              9472128
# _________________________________________________________________
# dropout_378 (Dropout)        (None, 2176)              0
# _________________________________________________________________
# ...
# Epoch 12/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2804 - accuracy: 0.8944 - val_loss: 0.2233 - val_accuracy: 0.9208
# Epoch 13/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2429 - accuracy: 0.9045 - val_loss: 0.2546 - val_accuracy: 0.9139
# Epoch 14/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2246 - accuracy: 0.9208 - val_loss: 0.2444 - val_accuracy: 0.9069
# Epoch 15/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.
50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1661 - accuracy: 0.9312 - val_loss: 0.3329 - val_accuracy: 0.8861
# Epoch 47/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1235 - accuracy: 0.9517 - val_loss: 0.2392 - val_accuracy: 0.9236
# Epoch 48/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1413 - accuracy: 0.9476 - val_loss: 0.2999 - val_accuracy: 0.9125
# Epoch 49/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1344 - accuracy: 0.9479 - val_loss: 0.2658 - val_accuracy: 0.9111
# Epoch 50/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1379 - accuracy: 0.9462 - val_loss: 0.2886 - val_accuracy: 0.9250
# 1200/1200 [==============================] - 1s 569us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# ------------------------------------------------------------------------
# Squential with Kfold CV:
# Training for fold 5 ...
# Adding layer 1:
# Adding layer 2:
# Adding layer 3:
# Adding layer 4:
# Model: "sequential_114"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_620 (Dense)            (None, 4352)              596224
# _________________________________________________________________
# dense_621 (Dense)            (None, 2176)              9472128
# _________________________________________________________________
# dropout_394 (Dropout)        (None, 2176)              0
# _________________________________________________________________
# dense_622 (Dense)            (None, 1088)              2368576
# _________________________________________________________________
# dropout_395 (Dropout)        (None, 1088)              0
# _________________________________________________________________
# dense_623 (Dense)            (None, 544)               592416
# _________________________________________________________________
# dropout_396 (Dropout)        (None, 544)               0
# _________________________________________________________________
# dense_624 (Dense)            (None, 272)               148240
# _________________________________________________________________
# dropout_397 (Dropout)        (None, 272)               0
# _________________________________________________________________
# dense_625 (Dense)            (None, 2)                 546
# =================================================================
# Total params: 13,178,130
# Trainable params: 13,178,130
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2880 samples, validate on 720 samples
# Epoch 1/50
# 2880/2880 [==============================] - 9s 3ms/step - loss: 2.9663 - accuracy: 0.5191 - val_loss: 0.7068 - val_accuracy: 0.5014
# Epoch 2/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.7144 - accuracy: 0.5132 - val_loss: 0.6673 - val_accuracy: 0.7083
# Epoch 3/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.7592 - accuracy: 0.5823 - val_loss: 0.7206 - val_accuracy: 0.5875
# Epoch 4/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.5651 - accuracy: 0.7365 - val_loss: 0.3475 - val_accuracy: 0.8694
# Epoch 5/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.4147 - accuracy: 0.8375 - val_loss: 0.3502 - val_accuracy: 0.8681
# Epoch 6/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.3370 - accuracy: 0.8684 - val_loss: 0.3008 - val_accuracy: 0.8847
# Epoch 7/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.3347 - accuracy: 0.8788 - val_loss: 0.3613 - val_accuracy: 0.8639
# Epoch 8/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2742 - accuracy: 0.8972 - val_loss: 0.3516 - val_accuracy: 0.8597
# Epoch 9/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2750 - accuracy: 0.8976 - val_loss: 0.3351 - val_accuracy: 0.8500
# Epoch 10/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2928 - accuracy: 0.8903 - val_loss: 0.3021 - val_accuracy: 0.8722
# Epoch 11/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2622 - accuracy: 0.9035 - val_loss: 0.3763 - val_accuracy: 0.8653
# Epoch 12/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2423 - accuracy: 0.9049 - val_loss: 0.4062 - val_accuracy: 0.8833
# Epoch 13/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2785 - accuracy: 0.8962 - val_loss: 0.2691 - val_accuracy: 0.8903
# Epoch 14/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2012 - accuracy: 0.9288 - val_loss: 0.2279 - val_accuracy: 0.9167
# Epoch 15/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2652 - accuracy: 0.9069 - val_loss: 0.2589 - val_accuracy: 0.8944
# Epoch 16/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2360 - accuracy: 0.9135 - val_loss: 0.2251 - val_accuracy: 0.9111
# Epoch 17/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1930 - accuracy: 0.9295 - val_loss: 0.2419 - val_accuracy: 0.9097
# Epoch 18/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2182 - accuracy: 0.9236 - val_loss: 0.2539 - val_accuracy: 0.9125
# Epoch 19/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2392 - accuracy: 0.9139 - val_loss: 0.3109 - val_accuracy: 0.8667
# Epoch 20/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2179 - accuracy: 0.9187 - val_loss: 0.2457 - val_accuracy: 0.8972
# Epoch 21/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1806 - accuracy: 0.9299 - val_loss: 0.2359 - val_accuracy: 0.9083
# Epoch 22/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1925 - accuracy: 0.9278 - val_loss: 0.2599 - val_accuracy: 0.8833
# Epoch 23/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2024 - accuracy: 0.9260 - val_loss: 0.2414 - val_accuracy: 0.8986
# Epoch 24/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2128 - accuracy: 0.9153 - val_loss: 0.2280 - val_accuracy: 0.9097
# Epoch 25/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1696 - accuracy: 0.9330 - val_loss: 0.2589 - val_accuracy: 0.9083
# Epoch 26/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1812 - accuracy: 0.9378 - val_loss: 0.3267 - val_accuracy: 0.8889
# Epoch 27/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1992 - accuracy: 0.9170 - val_loss: 0.2968 - val_accuracy: 0.9014
# Epoch 28/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1682 - accuracy: 0.9396 - val_loss: 0.4064 - val_accuracy: 0.8653
# Epoch 29/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1826 - accuracy: 0.9260 - val_loss: 0.2441 - val_accuracy: 0.9194
# Epoch 30/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1760 - accuracy: 0.9375 - val_loss: 0.2621 - val_accuracy: 0.9069
# Epoch 31/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1852 - accuracy: 0.9181 - val_loss: 0.2810 - val_accuracy: 0.8819
# Epoch 32/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1448 - accuracy: 0.9420 - val_loss: 0.2174 - val_accuracy: 0.9056
# Epoch 33/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1736 - accuracy: 0.9243 - val_loss: 0.2557 - val_accuracy: 0.9167
# Epoch 34/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1512 - accuracy: 0.9413 - val_loss: 0.2453 - val_accuracy: 0.9056
# Epoch 35/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1551 - accuracy: 0.9403 - val_loss: 0.2186 - val_accuracy: 0.9167
# Epoch 36/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1353 - accuracy: 0.9434 - val_loss: 0.2781 - val_accuracy: 0.9153
# Epoch 37/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.2090 - accuracy: 0.9333 - val_loss: 0.2116 - val_accuracy: 0.9250
# Epoch 38/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1604 - accuracy: 0.9403 - val_loss: 0.2661 - val_accuracy: 0.8972
# Epoch 39/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1468 - accuracy: 0.9392 - val_loss: 0.2222 - val_accuracy: 0.9139
# Epoch 40/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1309 - accuracy: 0.9514 - val_loss: 0.2719 - val_accuracy: 0.9208
# Epoch 41/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1626 - accuracy: 0.9344 - val_loss: 0.2418 - val_accuracy: 0.9097
# Epoch 42/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1339 - accuracy: 0.9424 - val_loss: 0.2809 - val_accuracy: 0.9181
# Epoch 43/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1409 - accuracy: 0.9441 - val_loss: 0.2251 - val_accuracy: 0.9153
# Epoch 44/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1500 - accuracy: 0.9344 - val_loss: 0.2612 - val_accuracy: 0.9056
# Epoch 45/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1306 - accuracy: 0.9497 - val_loss: 0.2944 - val_accuracy: 0.8986
# Epoch 46/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1587 - accuracy: 0.9358 - val_loss: 0.2453 - val_accuracy: 0.9181
# Epoch 47/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1469 - accuracy: 0.9438 - val_loss: 0.2759 - val_accuracy: 0.9069
# Epoch 48/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1274 - accuracy: 0.9490 - val_loss: 0.2857 - val_accuracy: 0.9208
# Epoch 49/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1111 - accuracy: 0.9559 - val_loss: 0.2907 - val_accuracy: 0.8917
# Epoch 50/50
# 2880/2880 [==============================] - 5s 2ms/step - loss: 0.1494 - accuracy: 0.9299 - val_loss: 0.2634 - val_accuracy: 0.9194
# 1200/1200 [==============================] - 1s 572us/step
# /Users/apple/opt/anaconda3/envs/AMLS/lib/python3.6/site-packages/ipykernel_launcher.py:39: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Average scores for pesudo test set across all folds:
# > Accuracy: 0.9003333449363708 (+- 0.01946935597295958)
# > Loss: 0.39009879099329314
# > Avg runtime per test instance: 0.004368331631024678
# ------------------------------------------------------------------------
# ########################################
# Opt model parameter found on the pseudo test set:
#
# {'num_hidden_layer': 4, 'hidden_layer_activation': ['relu', 'tanh', 'relu', 'tanh'], 'dropout': [0.5, 0.25, 0.125, 0.0625], 'last_activation': 'softmax'}
#
# Best average pseudo test set accuracy score with the opt model: 0.9003333449363708
# Average runtime per test instance: 0.004368331631024678

# %%
with open('TaskA1_landmark_features.pickle', 'rb') as f:
    landmark_features = pickle.load(f)

with open('TaskA1_label_contents.pickle', 'rb') as f:
    label_contents = pickle.load(f)

with open('TaskA1_Logclf.pkl', 'rb') as f:
    lc_Logclf = pickle.load(f)

    
#number of unique classes to be predicted
num_class = len(np.unique(label_contents))
    
tr_X, te_X, tr_Y, te_Y, cat_tr_Y, cat_te_Y  = split_data(landmark_features, label_contents, split_ratio)

# %%
print(tr_X.shape)
# Out:
# (3600, 136)

# %%
train_sizes, train_scores, valid_scores = learning_curve(lc_Logclf, tr_X, tr_Y, train_sizes=np.linspace(0.1, 1.0, 5), cv=5)
plot_learning_curves_other(train_scores, valid_scores, 'LR')

# %%
with open('TaskA1_SVMclf.pkl', 'rb') as f:
    lc_SVMclf = pickle.load(f)

train_sizes, train_scores, valid_scores = learning_curve(lc_SVMclf, tr_X, tr_Y, train_sizes=np.linspace(0.1, 1.0, 5), cv=5)
plot_learning_curves_other(train_scores, valid_scores, 'SVM')

# %%
with open('TaskA1_RFclf.pkl', 'rb') as f:
    lc_RFclf = pickle.load(f)

train_sizes, train_scores, valid_scores = learning_curve(lc_RFclf, tr_X, tr_Y, train_sizes=np.linspace(0.1, 1.0, 5), cv=5)
plot_learning_curves_other(train_scores, valid_scores, 'RF')

# %%
with open('TaskA1_KNNclf.pkl', 'rb') as f:
    lc_KNNclf = pickle.load(f)

train_sizes, train_scores, valid_scores = learning_curve(lc_KNNclf, tr_X, tr_Y, train_sizes=np.linspace(0.1, 1.0, 5), cv=5)
plot_learning_curves_other(train_scores, valid_scores, 'KNN')

# %%
#

# %%
#Sequential_Prediction_CV(tr_X, cat_tr_Y, te_X, cat_te_Y, Squential_model_parameters, cvfold, num_class, num_epochs)
